# %% [markdown]
# <a href="https://colab.research.google.com/github/premstaller1/instagram-graph-api/blob/main/instagram_graph_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# # Als Code formatiert
# ```
#
# # Lets do some Coding

# %% [markdown]
# ```
# # Als Code formatiert
# ```
#
# # Get the Access to our API

# %%
# Import Libraries
import requests
import json
import datetime
import pandas as pd

# Define Parameters Dictionary
params = dict()
params['access_token'] = 'EAAG24jaJaYIBADjnpHtgRgQiK35UnuiFrax75idt1BONvtV69IutUjZBMHmZAFK6l7yyuo2CZAPusYprk7qdG06wkCmjkOL0PAHsZCBOZAkKcMlwl6aiLrXP96vvinZBCOFHZAjjO0BtlCigQPKlvVHszg4lccPZApvnBhUY4hqTg1FC2pFF0VMA'        # not an actual access token
params['client_id'] = '482557670549890'                  
params['client_secret'] = 'd62937e7f31973871d86b8242430b73e'     
params['graph_domain'] = 'https://graph.facebook.com'
params['graph_version'] = 'v16.0'
params['endpoint_base'] = params['graph_domain'] + '/' + params['graph_version'] + '/'
params['page_id'] = '482557670549890'                  
params['instagram_account_id'] = '17841447229527043'
params['ig_username'] = 'productminimal'

# Define Endpoint Parameters
endpointParams = dict()
endpointParams['input_token'] = params['access_token']
endpointParams['access_token'] = params['access_token']

# Define URL
url = params['graph_domain'] + '/debug_token'

# Requests Data
data = requests.get(url, endpointParams)
access_token_data = json.loads(data.content)
access_token_data
# Out:
# {'data': {'app_id': '482557670549890',
#   'type': 'USER',
#   'application': 'get.data',
#   'data_access_expires_at': 1688920215,
#   'expires_at': 1687019775,
#   'is_valid': True,
#   'issued_at': 1681835775,
#   'scopes': ['pages_show_list',
#    'instagram_basic',
#    'instagram_manage_insights',
#    'instagram_content_publish',
#    'pages_read_engagement',
#    'pages_manage_metadata',
#    'pages_manage_posts'],
#   'granular_scopes': [{'scope': 'pages_show_list',
#     'target_ids': ['697408977005943',
#      '117333094565741',
#      '115892009794535',
#      '114800188149572',
#      '107094705179146']},
#    {'scope': 'instagram_basic',
#     'target_ids': ['17841457334539061',
#      '17841457091187806',
#      '17841447229527043',
#      '17841419699397187',
#      '17841405953014103']},
#    {'scope': 'instagram_manage_insights',
#     'target_ids': ['17841457334539061',
#      '17841457091187806',
#      '17841447229527043',
#      '17841419699397187',
#      '17841405953014103']},
#    {'scope': 'instagram_content_publish',
#     'target_ids': ['17841457334539061',
#      '17841457091187806',
#      '17841447229527043',
#      '17841419699397187',
#      '17841405953014103']},
#    {'scope': 'pages_read_engagement',
#     'target_ids': ['697408977005943',
#      '117333094565741',
#      '115892009794535',
#      '114800188149572',
#      '107094705179146']},
#    {'scope': 'pages_manage_metadata',
#     'target_ids': ['697408977005943',
#      '117333094565741',
#      '115892009794535',
#      '114800188149572',
#      '107094705179146']},
#    {'scope': 'pages_manage_posts',
#     'target_ids': ['697408977005943',
#      '117333094565741',
#      '115892009794535',
#      '114800188149572',
#      '107094705179146']}],
#   'user_id': '991919581778381'}}

# %% [markdown]
# ## Creating a long lasting token

# %%
print("Token Expires: ", datetime.datetime.fromtimestamp(access_token_data['data']['expires_at']))
# Out:
# Token Expires:  2023-06-17 16:36:15

# %%
# Define URL
url = params['endpoint_base'] + 'oauth/access_token'

# Define Endpoint Parameters
endpointParams = dict() 
endpointParams['grant_type'] = 'fb_exchange_token'
endpointParams['client_id'] = params['client_id']
endpointParams['client_secret'] = params['client_secret']
endpointParams['fb_exchange_token'] = params['access_token']

# Requests Data
data = requests.get(url, endpointParams )
long_lived_token = json.loads(data.content)
long_lived_token
# Out:
# {'access_token': 'EAAG24jaJaYIBADjnpHtgRgQiK35UnuiFrax75idt1BONvtV69IutUjZBMHmZAFK6l7yyuo2CZAPusYprk7qdG06wkCmjkOL0PAHsZCBOZAkKcMlwl6aiLrXP96vvinZBCOFHZAjjO0BtlCigQPKlvVHszg4lccPZApvnBhUY4hqTg1FC2pFF0VMA',
#  'token_type': 'bearer',
#  'expires_in': 5184000}

# %% [markdown]
# # First try to get some image data

# %%
# Define URL
url = params['endpoint_base'] + params['instagram_account_id'] + '/media'

# Define Endpoint Parameters
endpointParams = dict()
endpointParams['fields'] = 'id,caption,media_type,media_url,permalink,thumbnail_url,timestamp,username,like_count,comments_count'
endpointParams['access_token'] = params['access_token']

# Requests Data
data = requests.get(url, endpointParams )
basic_insight = json.loads(data.content)
basic_insight

# %% [markdown]
# ## Putting Image data in a Table

# %%
df = pd.DataFrame(basic_insight['data'])
df.columns = ['id', 'Caption', 'Media_Type', 'Media_URL', 'Permalink', 'Timestamp', 'Username', 'Likes', 'Comments', 'thumbnail_url']
df.head()
# Out:
#                   id                                            Caption  \
# 0  17897485115788540  With @apple being expected to release a mixed-...
# 1  17950853369556215  Explore the heat right in front of your eyes 🔥...
# 2  18040537486453786  Robots are taking over the world, but at least...
# 3  17972780834486774  @audiofficial is further stepping towards the ...
# 4  17975130056033325  Wireless is getting more and more common in sm...
#
#        Media_Type                                          Media_URL  \
# 0  CAROUSEL_ALBUM  https://scontent.cdninstagram.com/v/t39.30808-...
# 1  CAROUSEL_ALBUM  https://scontent.cdninstagram.com/v/t39.30808-...
# 2  CAROUSEL_ALBUM  https://scontent.cdninstagram.com/v/t39.30808-...
# 3           VIDEO  https://scontent.cdninstagram.com/o1/v/t16/f1/...
# 4  CAROUSEL_ALBUM  https://scontent.cdninstagram.com/v/t39.30808-...
#
#                                      Permalink                 Timestamp  \
# 0     https://www.instagram.com/p/CrLofM8qFsn/  2023-04-18T15:00:51+0000
# 1     https://www.instagram.com/p/CrJJPeuKoBu/  2023-04-17T15:49:20+0000
# 2     https://www.instagram.com/p/CrEhugEKTbs/  2023-04-15T20:47:05+0000
# 3  https://www.instagram.com/reel/CrBG-GgoVvE/  2023-04-14T12:55:44+0000
# 4     https://www.instagram.com/p/CrBGItOKkst/  2023-04-14T12:48:17+0000
#
#          Username  Likes  Comments  \
# 0  productminimal    126         1
# 1  productminimal   2068         4
# 2  productminimal    691         4
# 3  productminimal    745         2
# 4  productminimal   2924         5
#
#                                        thumbnail_url
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  https://scontent.cdninstagram.com/v/t51.29350-...
# 4                                                NaN

# %%
media_insight = []

# Loop Over 'Media ID'
for i in basic_insight['data']:
    if i['media_type'] == "CAROUSEL_ALBUM":
      params['latest_media_id'] = i['id']
      print(i)
      # Define URL
      url = params['endpoint_base'] + params['latest_media_id'] + '/insights'

      # Define Endpoint Parameters
      endpointParams = dict() 
      endpointParams['metric'] = 'engagement,impressions,reach,saved'
      endpointParams['access_token'] = params['access_token'] 

      # Requests Data
      data = requests.get(url, endpointParams )
      json_data = json.loads(data.content)
      media_insight.append(list(json_data['data']))
    else:
      None
# Out:
# {'id': '18078017998355849', 'caption': 'The FREE HANDS DRYER, found on @designerdot_academy, is a concept that aims to allow multitasking while drying your hair 👀. Designer_Jung eun Jung\n\nOn a busy morning, while doing makeup, I wished someone could dry my hair.\nSo I thought about what it would be like to have a dryer that could be fixed where I wanted, so I started designing.\nThe grip has a tong structure that makes the dryer easy to attach and remove, and I wanted it to be placed anywhere in the house and approach it as an interior accessory rather than an appliance. To solve this, we designed it considering various patterns and organic tong shapes.\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/340658196_1369245293874591_4193395069615007471_n.jpg?_nc_cat=108&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=j4cnM8Od4YAAX-yYjoR&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfCWcyJqJ3dR0WY9AtCJ_Ca-m5ypL8DCa2uh04w45XzL7Q&oe=643949BD', 'permalink': 'https://www.instagram.com/p/Cq27eV7KX_1/', 'timestamp': '2023-04-10T14:02:42+0000', 'username': 'productminimal', 'like_count': 364, 'comments_count': 2}
# {'id': '17998195930776358', 'caption': '@design_leehanyoung and @design_hyunsub exploring new ways to support elders or impaired 👀\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent.cdninstagram.com/v/t51.29350-15/340334426_141793012183559_7218858731842789595_n.jpg?_nc_cat=102&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=LWst6X096hkAX9_xMJS&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfC_TwQknqEBnzXG5DLF3snGMFF9Fb9KSFATe9Bh-l6fOg&oe=64387296', 'permalink': 'https://www.instagram.com/p/Cq0dKlUofSI/', 'timestamp': '2023-04-09T14:59:23+0000', 'username': 'productminimal', 'like_count': 590, 'comments_count': 2}
# {'id': '17890206992748203', 'caption': "Vertically Guitar Pedal concept by @sushantvohra \n\nIn my opinion, this concept is a prime example of a design that does not necessarily aim to solve a specific problem but rather exists to play around with forms and ideas to come up with something stunning and beautiful - and that's definitely achieved here. Especially the amount of details that you can see here makes this design worth sharing - fantastic job!\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner", 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/
\n\nThis design got submitted to our website - check out our link in bio if you also want to be featured! 🔥👀\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesign', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/337887766_866854281278608_4456595115198341043_n.jpg?_nc_cat=108&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=M1naMed2GzMAX89hsHR&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfDKJm9EeMiBsjNdsLgb9srzlJlaxOGUY0SKkkf9ONojXg&oe=6438CB6D', 'permalink': 'https://www.instagram.com/p/CqLRTy6q6kw/', 'timestamp': '2023-03-24T15:06:55+0000', 'username': 'productminimal', 'like_count': 1334, 'comments_count': 4}
# {'id': '18074103715359109', 'caption': "Taekyung Kim and @designmu.co designed the Xii S&D's Final kitchen - enhancing your kitchen through technology and a minimal experience 💡\n\nXii S&D's FINAL KITCHEN focused on a design that harmonizes with the entire space in a kitchen with a variety of supplies. FINAL KITCHEN has a simple appearance that excludes excessive decoration and maintains a minimal look while adding an edged door design to give you a unique look.\n\nThis design got submitted to our website - check out our link in bio if you also want to be featured! 🔥👀\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesign", 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/337137893_527956086085434_2292933090715027627_n.jpg?_nc_cat=109&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=1bkkKwBsD_4AX_a41_4&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfC_xXam24hbMzgAmBBgXpjqik_HqKsoLrgvlXE1Razx2w&oe=6439259A', 'permalink': 'https://www.instagram.com/p/CqI86OBoeJK/', 'timestamp': '2023-03-23T17:30:11+0000', 'username': 'productminimal', 'like_count': 635, 'comments_count': 7}
# {'id': '18260985958180773', 'caption': "Designed by @fabio_verdelli_design_studio’s Manuel Frasson, the DUNE mouse retains the gently sculpted form of something like the Apple Magic Mouse, but is accentuated further by transparent slices of linear vents to conjure light. \n\nIt's pleasantly ergonomic and comfortably wireless. Its gentle lines accompany your hand in a new user experience, its fascinating finishing captures your curiosity and its reflections mislead you through a multiple play of refractions.\nDUNE is evoking the exotic allure of the sands of our intriguing dreams.\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesignersuk", 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/337157246_6318312711546610_4599346948514343748_n.jpg?_nc_cat=102&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=PN5rAlw0g_MAX84U7x6&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfBFp9FiDMvqiv3t6DfTrM8qH97oGLcbvAHFTouVEuFPlg&oe=6439E427', 'permalink': 'https://www.instagram.com/p/CqIy52UK1Fr/', 'timestamp': '2023-03-23T16:02:45+0000', 'username': 'productminimal', 'like_count': 1484, 'comments_count': 5}
# {'id': '17923808825675865', 'caption': 'Different Form explorations by @lepikdaniel\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesignersuk', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/336896880_870389144059729_2390138188988523942_n.jpg?_nc_cat=102&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=Bvggi_eMMu8AX_ClK5g&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfAgxvsSvuEr77AzB9sx05tnOscoRM7EHSAieKe8_XcC4Q&oe=64392D49', 'permalink': 'https://www.instagram.com/p/CqDk-NvqTPG/', 'timestamp': '2023-03-21T15:24:49+0000', 'username': 'productminimal', 'like_count': 947, 'comments_count': 1}

# %%
# Initialize Empty Container
engagement_list = []
impressions_list = []
reach_list = []
saved_list = []

# Loop Over Insights to Fill Container
for insight in media_insight:
    engagement_list.append(insight[0]['values'][0]['value'])
    impressions_list.append(insight[1]['values'][0]['value'])
    reach_list.append(insight[2]['values'][0]['value'])
    saved_list.append(insight[3]['values'][0]['value'])
    
# Create DataFrame
df_media_insight = pd.DataFrame(list(zip(engagement_list, impressions_list, reach_list, saved_list)), columns =['Engagement', 'Impressions', 'Reach', 'Saved'])
df_media_insight
# Out:
#     Engagement  Impressions  Reach  Saved
# 0          422         6423   6111     54
# 1          692        15183  13160    100
# 2         1480        25376  22382    236
# 3         1320        23596  21015    242
# 4          921        17651  15332    177
# 5         1350        20195  17337    257
# 6          636        13089  10744    116
# 7         1470        23154  20043    239
# 8         3242        35296  30190    687
# 9          623        13279  10741     76
# 10        1013        21226  18299    113
# 11         894        18591  15696    161
# 12        3412        47519  42583    782
# 13         464        13060  10545     94
# 14         388        11662   9780     43
# 15         728        14821  12025    114
# 16        1701        28888  25087    363
# 17         816        16364  13927    174
# 18        1749        24654  20995    260
# 19        1147        17106  13751    199

# %% [markdown]
# # Demographics data Lifetime

# %%
# Define URL
url = params['endpoint_base'] + params['instagram_account_id'] + '/insights'

# Define Endpoint Parameters
endpointParams = dict()
endpointParams['metric'] = 'audience_city,audience_country,audience_gender_age' 
endpointParams['period'] = 'lifetime' 
endpointParams['access_token'] = params['access_token'] 

# Requests Data
data = requests.get(url, endpointParams )
audience_insight = json.loads(data.content)
audience_insight
# Out:
# {'data': [{'name': 'audience_city',
#    'period': 'lifetime',
#    'values': [{'value': {'Sydney, New South Wales': 299,
#       'London, England': 748,
#       'São Paulo, São Paulo (state)': 513,
#       'Barcelona, Cataluña': 289,
#       'Hong Kong, Hong Kong': 523,
#       'Berlin, Berlin': 372,
#       'Karaj, Tehran Province': 314,
#       'Kyiv, Kyiv': 271,
#       'Lagos, Lagos State': 346,
#       'Seoul, Seoul': 1416,
#       'Pune, Maharashtra': 289,
#       'Ahmedabad, Gujarat': 276,
#       'Moscow, Moscow': 703,
#       'Bogotá, Distrito Especial': 570,
#       'Jakarta, Jakarta': 892,
#       'Paris, Île-de-France': 369,
#       'Buenos Aires, Ciudad Autónoma de Buenos Aires': 500,
#       'Taipei, Taipei': 568,
#       'Ho Chi Minh City, Ho Chi Minh City': 379,
#       'Xinbei, New Taipei City': 449,
#       'Shanghai, Shanghai': 2028,
#       'Melbourne, Victoria': 411,
#       'Delhi, Delhi': 482,
#       'Los Angeles, California': 324,
#       'Madrid, Comunidad de Madrid': 312,
#       'Lima, Lima Region': 266,
#       'Istanbul, Istanbul Province': 1783,
#       'Rome, Lazio': 255,
#       'Toronto, Ontario': 256,
#       'Chennai, Tamil Nadu': 336,
#       'Ankara, Ankara Province': 267,
#       'Milan, Lombardia': 414,
#       'Bangkok, Bangkok': 629,
#       'Mexico City, Distrito Federal': 771,
#       'Riyadh, Riyadh Region': 317,
#       'Saint Petersburg, Saint Petersburg': 309,
#       'New York, New York': 556,
#       'Tehran, Tehran Province': 2732,
#       'Cairo, Cairo Governorate': 360,
#       'Dubai, Dubai': 377,
#       'Santiago, Santiago Metropolitan Region': 434,
#       'Mumbai, Maharashtra': 593,
#       'Bangalore, Karnataka': 812,
#       'Singapore, Singapore': 401,
#       'Tashkent, Tashkent Region': 400}}],
#    'title': 'Stadt der Zielgruppe',
#    'description': 'Städte der Follower dieses Profils',
#    'id': '17841447229527043/insights/audience_city/lifetime'},
#   {'name': 'audience_country',
#    'period': 'lifetime',
#    'values': [{'value': {'DE': 2590,
#       'BE': 429,
#       'HK': 524,
#       'TW': 1743,
#       'RU': 2176,
#       'PT': 672,
#       'JP': 1195,
#       'UA': 817,
#       'FR': 2172,
#       'SA': 719,
#       'BR': 2750,
#       'SE': 567,
#       'MA': 424,
#       'ID': 2888,
#       'GB': 2916,
#       'CA': 1339,
#       'US': 6892,
#       'EG': 766,
#       'IL': 413,
#       'AE': 583,
#       'CH': 469,
#       'UZ': 530,
#       'IN': 7240,
#       'ZA': 593,
#       'KR': 2879,
#       'IQ': 433,
#       'CL': 661,
#       'IR': 5442,
#       'CN': 2296,
#       'MX': 2599,
#       'IT': 3469,
#       'MY': 752,
#       'CO': 1216,
#       'ES': 1939,
#       'KZ': 416,
#       'AR': 1774,
#       'TH': 970,
#       'AU': 1096,
#       'PH': 448,
#       'VN': 576,
#       'NG': 661,
#       'PK': 693,
#       'PL': 714,
#       'NL': 756,
#       'TR': 3430}}],
#    'title': 'Land der Zielgruppe',
#    'description': 'Länder der Follower dieses Profils',
#    'id': '17841447229527043/insights/audience_country/lifetime'},
#   {'name': 'audience_gender_age',
#    'period': 'lifetime',
#    'values': [{'value': {'F.13-17': 97,
#       'F.18-24': 2890,
#       'F.25-34': 3383,
#       'F.35-44': 1185,
#       'F.45-54': 367,
#       'F.55-64': 122,
#       'F.65+': 79,
#       'M.13-17': 607,
#       'M.18-24': 11827,
#       'M.25-34': 24788,
#       'M.35-44': 12618,
#       'M.45-54': 3800,
#       'M.55-64': 849,
#       'M.65+': 596,
#       'U.13-17': 602,
#       'U.18-24': 6898,
#       'U.25-34': 8121,
#       'U.35-44': 4162,
#       'U.45-54': 1452,
#       'U.55-64': 408,
#       'U.65+': 326}}],
#    'title': 'Geschlecht und Alter',
#    'description': 'Geschlecht und Alter der Follower dieses Profils',
#    'id': '17841447229527043/insights/audience_gender_age/lifetime'}]}

# %% [markdown]
# ## Algorithm to get the data into table format

# %%
#The variables that I search for

audience_city = []
audience_country = []
audience_genderage = []


#Variables for Country
country_short = []
country_number = []

#Variables for City
city_name = []
region_name = []
city_number = []

#Variables for Age and Gender
gender = []
age_bracket = []
age_number = []

for i in audience_insight["data"]:
    if i['name'] == "audience_country":
      for x in i['values']:
        for z in x["value"]:
          country_short.append(z)
          country_number.append(x['value'][z])
    if i['name'] == "audience_city":
      for x in i['values']:
        for z in x["value"]:
          xy = z.split(", ")
          city_name.append(xy[0])
          region_name.append(xy[1])
          city_number.append(x['value'][z])
    if i['name'] == "audience_gender_age":
      for x in i['values']:
        for z in x["value"]:
          gender_age_split = z.split(".")
          gender.append(gender_age_split[0])
          age_bracket.append(gender_age_split[1])
          age_number.append(x['value'][z])



audience_country = pd.DataFrame(list(zip(country_short, country_number)), columns =['Country_ID', 'Count'])
audience_city = pd.DataFrame(list(zip(city_name, region_name, city_number)), columns =['City', 'Region', 'Count'])
audience_genderage = pd.DataFrame(list(zip(gender, age_bracket, age_number)), columns =['Gender', 'Age Bracket', 'Count'])

#audience_country
#audience_city
audience_city = audience_city.sort_values(by = ['Count'],ascending=False)
audience_country = audience_country.sort_values(by = ['Count'],ascending=False)
audience_genderage = audience_genderage.sort_values(by = ['Count'],ascending=False)

audience_country
# Out:
#    Country_ID  Count
# 22         IN   7240
# 16         US   6892
# 27         IR   5442
# 30         IT   3469
# 44         TR   3430
# 14         GB   2916
# 13         ID   2888
# 24         KR   2879
# 10         BR   2750
# 29         MX   2599
# 0          DE   2590
# 28         CN   2296
# 4          RU   2176
# 8          FR   2172
# 33         ES   1939
# 35         AR   1774
# 3          TW   1743
# 15         CA   1339
# 32         CO   1216
# 6          JP   1195
# 37         AU   1096
# 36         TH    970
# 7          UA    817
# 17         EG    766
# 43         NL    756
# 31         MY    752
# 9          SA    719
# 42         PL    714
# 41         PK    693
# 5          PT    672
# 26         CL    661
# 40         NG    661
# 23         ZA    593
# 19         AE    583
# 39         VN    576
# 11         SE    567
# 21         UZ    530
# 2          HK    524
# 20         CH    469
# 38         PH    448
# 25         IQ    433
# 1          BE    429
# 12         MA    424
# 34         KZ    416
# 18         IL    413

# %% [markdown]
# ### Country Codes

# %%
# !pip install country_converter --upgrade
# !pip install pycountry
import country_converter as coco
import pycountry

country_dict = {country.alpha_2: country.name for country in pycountry.countries}
audience_country['Country'] = audience_country_test['Country_ID'].map(country_dict)
audience_country = audience_country.reindex(columns=['Country', 'Country_ID', 'Count'])
audience_country
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting country_converter
#   Downloading country_converter-1.0.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.9/dist-packages (from country_converter) (1.5.3)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0->country_converter) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0->country_converter) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0->country_converter) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas>=1.0->country_converter) (1.16.0)
# Installing collected packages: country_converter
# Successfully installed country_converter-1.0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pycountry
#   Downloading pycountry-22.3.5.tar.gz (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 52.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from pycountry) (67.6.1)
# Building wheels for collected packages: pycountry
#   Building wheel for pycountry (pyproject.toml) ... done
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681847 sha256=901a7999638b6f4d0ef63cbeb01dab9c21d774e5186eec0031d6e30c9b6fc1c0
#   Stored in directory: /root/.cache/pip/wheels/47/15/92/e6dc85fcb0686c82e1edbcfdf80cfe4808c058813fed0baa8f
# Successfully built pycountry
# Installing collected packages: pycountry
# Successfully installed pycountry-22.3.5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-0d954d26feda> in <cell line: 7>()
#       5
#       6 country_dict = {country.alpha_2: country.name for country in pycountry.countries}
# ----> 7 audience_country['Country'] = audience_country_test['Country_ID'].map(country_dict)
#       8 audience_country = audience_country.reindex(columns=['Country', 'Country_ID', 'Count'])
#       9 audience_country
#
# NameError: name 'audience_country_test' is not defined

# %%
audience_country

# %%
import pandas as pd
from datetime import datetime

# generate timestamp string for filename
timestamp_str = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# set the name of the CSV file to include the timestamp
filename = f"country_{timestamp_str}.csv"

# save the dataframe as a CSV file
audience_country.to_csv(filename, index=False)

# %% [markdown]
# # Playing around with time frames - for Day timeframe

# %%
# Define URL
url = params['endpoint_base'] + params['instagram_account_id'] + '/insights'

# Define Endpoint Parameters
endpointParams = dict()
endpointParams['metric'] = 'impressions, reach, likes, comments, profile_views' 
endpointParams['period'] = 'day'
endpointParams['metric_type'] = 'total_value'
endpointParams['access_token'] = params['access_token'] 

# Requests Data
day_account_insight_data = requests.get(url, endpointParams )
day_account_insight = json.loads(day_account_insight_data.content)
day_account_insight
# Out:
# {'data': [{'name': 'impressions',
#    'period': 'day',
#    'title': 'Impressionen',
#    'description': 'So oft wurden deine Beiträge, Stories, Reels, Videos und Live-Videos gezeigt (einschließlich Platzierungen in Anzeigen).',
#    'total_value': {'value': 74631},
#    'id': '17841447229527043/insights/impressions/day'},
#   {'name': 'reach',
#    'period': 'day',
#    'title': 'Erreichte Konten',
#    'description': 'So viele individuelle Konten haben deinen Content, auch in Werbeanzeigen, mindestens einmal gesehen. Dazu zählen Beiträge, Stories, Reels, Videos und Live-Videos. Reichweite unterscheidet sich von Impressionen, denn Letztere können auch mehrfache Aufrufe deines Contents durch dieselben Konten umfassen. Bei dieser Kennzahl handelt es sich um einen Schätzwert, der sich noch in der Entwicklung befindet.',
#    'total_value': {'value': 46986},
#    'id': '17841447229527043/insights/reach/day'},
#   {'name': 'likes',
#    'period': 'day',
#    'title': '„Gefällt mir“-Angaben',
#    'description': 'Die Anzahl der „Gefällt mir“-Angaben für deine Inhalte abzüglich der entfernten „Gefällt mir“-Angaben.',
#    'total_value': {'value': 3158},
#    'id': '17841447229527043/insights/likes/day'},
#   {'name': 'comments',
#    'period': 'day',
#    'title': 'Kommentare',
#    'description': 'Die Anzahl der Kommentare zu deinen Inhalten abzüglich der Anzahl der gelöschten Kommentare.',
#    'total_value': {'value': 10},
#    'id': '17841447229527043/insights/comments/day'},
#   {'name': 'profile_views',
#    'period': 'day',
#    'title': 'Profilaufrufe',
#    'description': 'So oft wurde dein Profil besucht.',
#    'total_value': {'value': 909},
#    'id': '17841447229527043/insights/profile_views/day'}],
#  'paging': {'previous': 'https://graph.facebook.com/v16.0/17841447229527043/insights?access_token=EAAG24jaJaYIBADjnpHtgRgQiK35UnuiFrax75idt1BONvtV69IutUjZBMHmZAFK6l7yyuo2CZAPusYprk7qdG06wkCmjkOL0PAHsZCBOZAkKcMlwl6aiLrXP96vvinZBCOFHZAjjO0BtlCigQPKlvVHszg4lccPZApvnBhUY4hqTg1FC2pFF0VMA&metric=impressions%2C+reach%2C+likes%2C+comments%2C+profile_views&metric_type=total_value&period=day&since=1681490986&until=1681663786',
#   'next': 'https://graph.facebook.com/v16.0/17841447229527043/insights?access_token=EAAG24jaJaYIBADjnpHtgRgQiK35UnuiFrax75idt1BONvtV69IutUjZBMHmZAFK6l7yyuo2CZAPusYprk7qdG06wkCmjkOL0PAHsZCBOZAkKcMlwl6aiLrXP96vvinZBCOFHZAjjO0BtlCigQPKlvVHszg4lccPZApvnBhUY4hqTg1FC2pFF0VMA&metric=impressions%2C+reach%2C+likes%2C+comments%2C+profile_views&metric_type=total_value&period=day&since=1681836588&until=1682009388'}}

# %%
for i in day_account_insight:
  for x in day_account_insight[i]:
    print(x)
    if x['name'] == 'impressions':
      print(x['total_value']['value'])
# Out:
# {'name': 'impressions', 'period': 'day', 'title': 'Impressionen', 'description': 'So oft wurden deine Beiträge, Stories, Reels, Videos und Live-Videos gezeigt (einschließlich Platzierungen in Anzeigen).', 'total_value': {'value': 74631}, 'id': '17841447229527043/insights/impressions/day'}
# 74631
# {'name': 'reach', 'period': 'day', 'title': 'Erreichte Konten', 'description': 'So viele individuelle Konten haben deinen Content, auch in Werbeanzeigen, mindestens einmal gesehen. Dazu zählen Beiträge, Stories, Reels, Videos und Live-Videos. Reichweite unterscheidet sich von Impressionen, denn Letztere können auch mehrfache Aufrufe deines Contents durch dieselben Konten umfassen. Bei dieser Kennzahl handelt es sich um einen Schätzwert, der sich noch in der Entwicklung befindet.', 'total_value': {'value': 46986}, 'id': '17841447229527043/insights/reach/day'}
# {'name': 'likes', 'period': 'day', 'title': '„Gefällt mir“-Angaben', 'description': 'Die Anzahl der „Gefällt mir“-Angaben für deine Inhalte abzüglich der entfernten „Gefällt mir“-Angaben.', 'total_value': {'value': 3158}, 'id': '17841447229527043/insights/likes/day'}
# {'name': 'comments', 'period': 'day', 'title': 'Kommentare', 'description': 'Die Anzahl der Kommentare zu deinen Inhalten abzüglich der Anzahl der gelöschten Kommentare.', 'total_value': {'value': 10}, 'id': '17841447229527043/insights/comments/day'}
# {'name': 'profile_views', 'period': 'day', 'title': 'Profilaufrufe', 'description': 'So oft wurde dein Profil besucht.', 'total_value': {'value': 909}, 'id': '17841447229527043/insights/profile_views/day'}
# previous
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-ba9500ae8e98> in <cell line: 1>()
#       2   for x in day_account_insight[i]:
#       3     print(x)
# ----> 4     if x['name'] == 'impressions':
#       5       print(x['total_value']['value'])
#
# TypeError: string indices must be integers
