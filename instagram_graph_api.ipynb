# %% [markdown]
# <a href="https://colab.research.google.com/github/premstaller1/instagram-graph-api/blob/main/instagram_graph_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# # Als Code formatiert
# ```
#
# # Lets do some Coding

# %% [markdown]
# ```
# # Als Code formatiert
# ```
#
# # Get the Access to our API

# %%
# Import Libraries
import requests
import json
import datetime
import pandas as pd

# Define Parameters Dictionary
params = dict()
params['access_token'] = 'EAAG24jaJaYIBAJnJTbRCkiq7lyr6QGczbxTl92uNxgqxtqYGvvu22VkbZBmmuVvBl1OGng4vbaZBgxjjipOBbotaNCyPoUGQANkDkhaTgoejvu06B4JsZBGUZAIuzwLpKLM3QVCnOYrJmBkZARZA66Didy3X0VbEsodxQfrWMcEfWKaBsCPZC5s'        # not an actual access token
params['client_id'] = '482557670549890'                  
params['client_secret'] = 'd62937e7f31973871d86b8242430b73e'     
params['graph_domain'] = 'https://graph.facebook.com'
params['graph_version'] = 'v16.0'
params['endpoint_base'] = params['graph_domain'] + '/' + params['graph_version'] + '/'
params['page_id'] = '482557670549890'                  
params['instagram_account_id'] = '17841447229527043'
params['ig_username'] = 'productminimal'

# Define Endpoint Parameters
endpointParams = dict()
endpointParams['input_token'] = params['access_token']
endpointParams['access_token'] = params['access_token']

# Define URL
url = params['graph_domain'] + '/debug_token'

# Requests Data
data = requests.get(url, endpointParams)
access_token_data = json.loads(data.content)
access_token_data
# Out:
# {'data': {'app_id': '482557670549890',
#   'type': 'USER',
#   'application': 'get.data',
#   'data_access_expires_at': 1688920215,
#   'expires_at': 1687023503,
#   'is_valid': True,
#   'issued_at': 1681839503,
#   'scopes': ['pages_show_list',
#    'instagram_basic',
#    'instagram_manage_insights',
#    'instagram_content_publish',
#    'pages_read_engagement',
#    'pages_manage_metadata',
#    'pages_manage_posts'],
#   'granular_scopes': [{'scope': 'pages_show_list',
#     'target_ids': ['697408977005943',
#      '117333094565741',
#      '115892009794535',
#      '114800188149572',
#      '107094705179146']},
#    {'scope': 'instagram_basic',
#     'target_ids': ['17841457334539061',
#      '17841457091187806',
#      '17841447229527043',
#      '17841419699397187',
#      '17841405953014103']},
#    {'scope': 'instagram_manage_insights',
#     'target_ids': ['17841457334539061',
#      '17841457091187806',
#      '17841447229527043',
#      '17841419699397187',
#      '17841405953014103']},
#    {'scope': 'instagram_content_publish',
#     'target_ids': ['17841457334539061',
#      '17841457091187806',
#      '17841447229527043',
#      '17841419699397187',
#      '17841405953014103']},
#    {'scope': 'pages_read_engagement',
#     'target_ids': ['697408977005943',
#      '117333094565741',
#      '115892009794535',
#      '114800188149572',
#      '107094705179146']},
#    {'scope': 'pages_manage_metadata',
#     'target_ids': ['697408977005943',
#      '117333094565741',
#      '115892009794535',
#      '114800188149572',
#      '107094705179146']},
#    {'scope': 'pages_manage_posts',
#     'target_ids': ['697408977005943',
#      '117333094565741',
#      '115892009794535',
#      '114800188149572',
#      '107094705179146']}],
#   'user_id': '991919581778381'}}

# %% [markdown]
# ## Creating a long lasting token

# %%
print("Token Expires: ", datetime.datetime.fromtimestamp(access_token_data['data']['expires_at']))
# Out:
# Token Expires:  2023-04-18 19:00:00

# %%
# Define URL
url = params['endpoint_base'] + 'oauth/access_token'

# Define Endpoint Parameters
endpointParams = dict() 
endpointParams['grant_type'] = 'fb_exchange_token'
endpointParams['client_id'] = params['client_id']
endpointParams['client_secret'] = params['client_secret']
endpointParams['fb_exchange_token'] = params['access_token']

# Requests Data
data = requests.get(url, endpointParams )
long_lived_token = json.loads(data.content)
long_lived_token
# Out:
# {'access_token': 'EAAG24jaJaYIBAJnJTbRCkiq7lyr6QGczbxTl92uNxgqxtqYGvvu22VkbZBmmuVvBl1OGng4vbaZBgxjjipOBbotaNCyPoUGQANkDkhaTgoejvu06B4JsZBGUZAIuzwLpKLM3QVCnOYrJmBkZARZA66Didy3X0VbEsodxQfrWMcEfWKaBsCPZC5s',
#  'token_type': 'bearer',
#  'expires_in': 5184000}

# %% [markdown]
# # First try to get some image data

# %%
# Define URL
url = params['endpoint_base'] + params['instagram_account_id'] + '/media'

# Define Endpoint Parameters
endpointParams = dict()
endpointParams['fields'] = 'id,caption,media_type,media_url,permalink,thumbnail_url,timestamp,username,like_count,comments_count'
endpointParams['access_token'] = params['access_token']

# Requests Data
data = requests.get(url, endpointParams )
basic_insight = json.loads(data.content)
basic_insight
# Out:
# {'data': [{'id': '17897485115788540',
#    'caption': "With @apple being expected to release a mixed-reality headset and @facebook being stubborn about their VR/Metaverse strategy, VR Headsets are probably here to stay - making designs like these by @seoul_id not only nice to look at, but also relevant!\n\n“SWP is a wearable strabismus treatment device that promotes active and effective cure for childhood strabismus patients who are difficult to treat through surgery and other methods.\n\nThe motorized prism lens mounted inside the product continuously adapts the distortion angle according to the user's severity of strabismus. Accordingly, the treatment of strabismus can be further promoted by strengthening the eye movement effect.”\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner",
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/337747778_727882099089390_4991700846347472542_n.jpg?_nc_cat=107&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=-bZIf5OZrhYAX_Hpr1q&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfDJWYVkIlCgyqdlSenuI4DC0fqgkTrlIvqkhhoqMcsncA&oe=6443F935',
#    'permalink': 'https://www.instagram.com/p/CrLofM8qFsn/',
#    'timestamp': '2023-04-18T15:00:51+0000',
#    'username': 'productminimal',
#    'like_count': 167,
#    'comments_count': 1},
#   {'id': '17950853369556215',
#    'caption': 'Explore the heat right in front of your eyes 🔥 Definitely a cool idea, although I can imagine that material resistance can be a problem here. Desgined by @pb_designs__ for @renderweekly \n\nCMF (Color-Material-Finish) is a tactical step in the design process of each Industrial Design project, that gives a deeper understanding of our target group, user experience and plays a major factor in how products AND brands stand out.\n\n„I am always curious how things are working, therefore it’s so exciting to see moving parts, blinking lights and get a deep understanding of the functionality.“\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/336918685_6120004631368136_1511933705726781811_n.jpg?_nc_cat=108&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=qgIf6KUNGSQAX8gUHek&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfAsztKQ8G6_QOApXWci9W2m9RS7kbrcSupS9p7gxOjSJw&oe=64443457',
#    'permalink': 'https://www.instagram.com/p/CrJJPeuKoBu/',
#    'timestamp': '2023-04-17T15:49:20+0000',
#    'username': 'productminimal',
#    'like_count': 2109,
#    'comments_count': 4},
#   {'id': '18040537486453786',
#    'caption': 'Robots are taking over the world, but at least they look fancy. This concept here is called Symbion and is designed by the talented @alpcakindesign\n\nMany different construction machines are used in the construction of a building. But hand tools are generally used to facilitate the work in the interior works of the construction. Since these works are done by people, occupational accidents are frequently experienced in workspace. It also causes cost and time loss. Symbion product family performs floor levelling, drilling holes and wall chasing for installations in the interior of the construction autonomously with bim files. It prevents various work accidents while applying these processes.\n\nThe problems to be encountered during manufacturing are determined previously and corrected in the bim application. Bim file is uploaded to robots then the revisions made in this file are transferred to the robots simultaneously. Thus, the possibility of error is minimized and cost, energy and time savings are achieved.\n\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/336661866_251909807501842_3215654569570654572_n.jpg?_nc_cat=101&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=3i3JC8uzbZoAX9bzNcP&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfBAlO-ENVgRGNbuX2SKd7guaTc41RSJaECE8zUwb9HWUg&oe=64441B62',
#    'permalink': 'https://www.instagram.com/p/CrEhugEKTbs/',
#    'timestamp': '2023-04-15T20:47:05+0000',
#    'username': 'productminimal',
#    'like_count': 691,
#    'comments_count': 4},
#   {'id': '17972780834486774',
#    'caption': '@audiofficial is further stepping towards the modern automotive era with this fantastic concept car - check it out\n\n_______\n\nDiscover more on @productminimal',
#    'media_type': 'VIDEO',
#    'media_url': 'https://scontent.cdninstagram.com/o1/v/t16/f1/m82/654A824F5F29C0917AF7020E1D2DD092_video_dashinit.mp4?efg=eyJ2ZW5jb2RlX3RhZyI6InZ0c192b2RfdXJsZ2VuLjcyMC5jbGlwcyJ9&_nc_ht=scontent.cdninstagram.com&_nc_cat=104&vs=1614136058994856_3925677679&_nc_vs=HBksFQIYT2lnX3hwdl9yZWVsc19wZXJtYW5lbnRfcHJvZC82NTRBODI0RjVGMjlDMDkxN0FGNzAyMEUxRDJERDA5Ml92aWRlb19kYXNoaW5pdC5tcDQVAALIAQAVABgkR0pGc1FCUXlLU0NVc0RFRUFLekRPd3owaFlGQWJxX0VBQUFGFQICyAEAKAAYABsBiAd1c2Vfb2lsATEVAAAmpPT6z8eE5T8VAigCQzMsF0A%2BDAgxJul5GBJkYXNoX2Jhc2VsaW5lXzFfdjERAHUAAA%3D%3D&ccb=9-4&oh=00_AfCHrS4iopnCbOHkvFwQ0SFRXLO50H5VYY8egTqlq0YSCg&oe=64409229&_nc_sid=ea0b6e&_nc_rid=d4987675b7',
#    'permalink': 'https://www.instagram.com/reel/CrBG-GgoVvE/',
#    'thumbnail_url': 'https://scontent.cdninstagram.com/v/t51.29350-15/341002054_779478956714573_4406294360423637234_n.jpg?_nc_cat=109&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=TU4sa25hFTEAX8v4SXt&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfCnMqGJ-2R1SSyMrdoZvJZBDOHRkH7SxB49zn-rFCOZhA&oe=644414C7',
#    'timestamp': '2023-04-14T12:55:44+0000',
#    'username': 'productminimal',
#    'like_count': 746,
#    'comments_count': 2},
#   {'id': '17975130056033325',
#    'caption': 'Wireless is getting more and more common in smartphones and gadgets - and these chargers definitely make them even more attractive to buy 😉 CHAU - Wireless & Portable charger, design by @yyoung_design 🔥\n\n"Wireless chargers freed electronic devices from wires and brought convenience to our daily lives. \nHowever, while wired charging allows movement in a certain space, wireless chargers cannot move the smart phone while charging. Therefore, it is more suitable as a vehicle or office product with relatively little movement of the smart phone.\nA time when telecommuting became commonplace due to the pandemic and the boundary between office and home became blurred, I wondered what if wireless chargers, which are office supplies, come home? And this project started with the question."\n\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/341088244_140342085649853_1207520435377662030_n.jpg?_nc_cat=105&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=_ztFeQF1ED0AX-BRQ1T&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfBSoVytpTU1A-B44BMoqXszR8TnDBFW3W_keK7cp6ZHOA&oe=6443083E',
#    'permalink': 'https://www.instagram.com/p/CrBGItOKkst/',
#    'timestamp': '2023-04-14T12:48:17+0000',
#    'username': 'productminimal',
#    'like_count': 2925,
#    'comments_count': 5},
#   {'id': '17853854579921301',
#    'caption': 'Lightning up the dark with the this transparent flashlight by @studiocoolberlin ⛓️ for @renderweekly \n-\n"Double lens flashlight for @renderweekly #rwcloudy\nThis season\'s prompts are great :)"\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/336252746_1301347363748064_7867792272100530033_n.jpg?_nc_cat=103&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=JEfmjLR1sbIAX8dVrFc&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfAGAtOlgcPetH__W4pRw6zKQoNc-hnSga6DrHhIrvRQjg&oe=6443B14A',
#    'permalink': 'https://www.instagram.com/p/Cq-5rCzKyK5/',
#    'timestamp': '2023-04-13T16:20:53+0000',
#    'username': 'productminimal',
#    'like_count': 1216,
#    'comments_count': 4},
#   {'id': '18015505108510870',
#    'caption': 'Electric scooter concept by @anthony.kaha - in my opinion a bit too round, but still a great concept!\n\nDue to on demand scooter services by Lyft, Brid or similar E-Scooters seem to be pretty unpopular in the general population, but they are still a good alternative to going by foot or bikes!\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/340911223_245309347885240_8541317450348171318_n.jpg?_nc_cat=109&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=qgutC8wlSOIAX8ni2Ga&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfBidj0S1RWqf_XTVzk0Xp8zDFOYpjbW2n-djjUgAPkTqA&oe=644459E6',
#    'permalink': 'https://www.instagram.com/p/Cq8GYHwIo6D/',
#    'timestamp': '2023-04-12T14:14:11+0000',
#    'username': 'productminimal',
#    'like_count': 1220,
#    'comments_count': 4},
#   {'id': '17992252096892775',
#    'caption': 'Simple video by @nothing - but it got all you need 🔥',
#    'media_type': 'VIDEO',
#    'media_url': 'https://scontent.cdninstagram.com/o1/v/t16/f1/m82/674C2CF7BF2EC14B8E709467A95DB395_video_dashinit.mp4?efg=eyJ2ZW5jb2RlX3RhZyI6InZ0c192b2RfdXJsZ2VuLjcyMC5jbGlwcyJ9&_nc_ht=scontent.cdninstagram.com&_nc_cat=111&vs=561067666010281_1031780601&_nc_vs=HBksFQIYT2lnX3hwdl9yZWVsc19wZXJtYW5lbnRfcHJvZC82NzRDMkNGN0JGMkVDMTRCOEU3MDk0NjdBOTVEQjM5NV92aWRlb19kYXNoaW5pdC5tcDQVAALIAQAVABgkR0NyWU1CUjd3YXlHczlNQ0FKYTJ0WlgxMHA1ZGJxX0VBQUFGFQICyAEAKAAYABsBiAd1c2Vfb2lsATEVAAAm4uGQoKC1%2Bj8VAigCQzMsF0Ar7xqfvnbJGBJkYXNoX2Jhc2VsaW5lXzFfdjERAHUAAA%3D%3D&ccb=9-4&oh=00_AfDhOJsTUE2rbC1OpkNf6toL-knBs3iv4hvQ049KGD782A&oe=64403C0B&_nc_sid=ea0b6e&_nc_rid=c551c40bf6',
#    'permalink': 'https://www.instagram.com/reel/Cq50n_7Ie-N/',
#    'thumbnail_url': 'https://scontent.cdninstagram.com/v/t51.29350-15/340361323_166498853003910_5267689521804130678_n.jpg?_nc_cat=106&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=c4MgJHj6zZQAX_bgXUy&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfB19_tNoyASI9mvwc64PPt4gwiSFq-P6qnrDfMoa9q0cQ&oe=64432BC5',
#    'timestamp': '2023-04-11T17:00:54+0000',
#    'username': 'productminimal',
#    'like_count': 1112,
#    'comments_count': 8},
#   {'id': '18001735933670766',
#    'caption': '@scottyujan perfectly showcases how 3D printing will slowly change how we create and shop furniture - at least in small dimensions 🙌🏻\n\n_____\n\nMore on @productminimal \n\n#design #3dprint #printing #productdesign #minimal #techshow #tech',
#    'media_type': 'VIDEO',
#    'media_url': 'https://scontent.cdninstagram.com/o1/v/t16/f1/m82/4E44A20DDA32E51B5FC6AF392D4DC495_video_dashinit.mp4?efg=eyJ2ZW5jb2RlX3RhZyI6InZ0c192b2RfdXJsZ2VuLjcyMC5jbGlwcyJ9&_nc_ht=scontent.cdninstagram.com&_nc_cat=111&vs=1247683559507103_4205174899&_nc_vs=%3D%3D&ccb=9-4&oh=00_AfBWSg_BRPoAa5Ke2kpq6mHpYUtJb2x9eJVOYX5bZOYEAw&oe=64408D54&_nc_sid=ea0b6e&_nc_rid=c32cac01c4',
#    'permalink': 'https://www.instagram.com/reel/Cq3BvA2Iqvu/',
#    'thumbnail_url': 'https://scontent.cdninstagram.com/v/t51.29350-15/340466089_189547263856425_8765373856045546907_n.jpg?_nc_cat=109&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=PTOKK1XwYPgAX_G8eG7&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfAWPurNoDr61tGqwaXW_wKLvkOnQSuQeQkRbrSaSPAWdA&oe=6444638C',
#    'timestamp': '2023-04-10T14:59:29+0000',
#    'username': 'productminimal',
#    'like_count': 4050,
#    'comments_count': 25},
#   {'id': '18078017998355849',
#    'caption': 'The FREE HANDS DRYER, found on @designerdot_academy, is a concept that aims to allow multitasking while drying your hair 👀. Designer_Jung eun Jung\n\nOn a busy morning, while doing makeup, I wished someone could dry my hair.\nSo I thought about what it would be like to have a dryer that could be fixed where I wanted, so I started designing.\nThe grip has a tong structure that makes the dryer easy to attach and remove, and I wanted it to be placed anywhere in the house and approach it as an interior accessory rather than an appliance. To solve this, we designed it considering various patterns and organic tong shapes.\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/340658196_1369245293874591_4193395069615007471_n.jpg?_nc_cat=108&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=p5LIAb1gv0wAX_u31V7&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfBIKskmuKMJgwWxSayWmvSbl386yqeymh3TtPsZcdVT8w&oe=64432CFD',
#    'permalink': 'https://www.instagram.com/p/Cq27eV7KX_1/',
#    'timestamp': '2023-04-10T14:02:42+0000',
#    'username': 'productminimal',
#    'like_count': 1426,
#    'comments_count': 7},
#   {'id': '17998195930776358',
#    'caption': '@design_leehanyoung and @design_hyunsub exploring new ways to support elders or impaired 👀\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent.cdninstagram.com/v/t51.29350-15/340334426_141793012183559_7218858731842789595_n.jpg?_nc_cat=102&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=rjOmWNEuGz0AX9ou3Yr&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfCsbOclBGYcfSucehSBZgBFmS_uAY5oPR8gNigdCqIrXA&oe=64445016',
#    'permalink': 'https://www.instagram.com/p/Cq0dKlUofSI/',
#    'timestamp': '2023-04-09T14:59:23+0000',
#    'username': 'productminimal',
#    'like_count': 752,
#    'comments_count': 2},
#   {'id': '17890206992748203',
#    'caption': "Vertically Guitar Pedal concept by @sushantvohra \n\nIn my opinion, this concept is a prime example of a design that does not necessarily aim to solve a specific problem but rather exists to play around with forms and ideas to come up with something stunning and beautiful - and that's definitely achieved here. Especially the amount of details that you can see here makes this design worth sharing - fantastic job!\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner",
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/339422516_953478835662790_2422555732961043046_n.jpg?_nc_cat=108&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=WCwsuPoGjG8AX9DXtZM&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfBpYhOKyFuZjCXORhwLMQvHLXfmq2OFCu7TNViLmFc6YA&oe=6444531A',
#    'permalink': 'https://www.instagram.com/p/Cqx1mdRIUn7/',
#    'timestamp': '2023-04-08T14:35:11+0000',
#    'username': 'productminimal',
#    'like_count': 1585,
#    'comments_count': 6},
#   {'id': '18002208748662256',
#    'caption': '@glen.cordle created these goggles for the @renderweekly challenge. Normally occupied with designing cars, he\'s taking a break from it and delivering a banger goggle submission. The perfect goggles to explore glaciers 👀🔥\n\n"So, these goggles are an original design. The Creamcar branding is also original although influenced in all the right places. You may remember it from my NFT excursion.\n\nThis was about 4 hours from the point I scribbled a basic sketch to when I hit "go" on the rendering queue. Modeled using Creo, rendered in Keyshot 10. Hope you can dig it."\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/339308425_1347486902697653_269948326246758929_n.jpg?_nc_cat=111&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=8vytsTJAeUUAX8Hs5i8&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfAooqgOngYi8aLvN6TECExUORxo4X6H4jvQB1IcPtDcug&oe=6442CBA6',
#    'permalink': 'https://www.instagram.com/p/CqxlHQ1Kwnz/',
#    'timestamp': '2023-04-08T12:11:07+0000',
#    'username': 'productminimal',
#    'like_count': 2089,
#    'comments_count': 8},
#   {'id': '18003194719655579',
#    'caption': 'The longer you look at it, the more details you can discover - fantastic work by @geometrieva\n\nSpecial edition Japanese-made iPhone 59E. Part of the Cinderella 2059 series of futuristic superglass objects presented as vintage ads.\n\n_________\n\nDiscover more on @productminimal',
#    'media_type': 'VIDEO',
#    'media_url': 'https://scontent.cdninstagram.com/o1/v/t16/f1/m82/EC40F3FD08BC2A3C2EFF10746C0C5796_video_dashinit.mp4?efg=eyJ2ZW5jb2RlX3RhZyI6InZ0c192b2RfdXJsZ2VuLjcyMC5jbGlwcyJ9&_nc_ht=scontent.cdninstagram.com&_nc_cat=107&vs=644617804093823_405273086&_nc_vs=HBksFQIYT2lnX3hwdl9yZWVsc19wZXJtYW5lbnRfcHJvZC9FQzQwRjNGRDA4QkMyQTNDMkVGRjEwNzQ2QzBDNTc5Nl92aWRlb19kYXNoaW5pdC5tcDQVAALIAQAVABgkR052cE1SU2NoQnJTRVU4REFGdlFWdEk5NmxJMWJxX0VBQUFGFQICyAEAKAAYABsBiAd1c2Vfb2lsATEVAAAmwJXT5%2B2J%2BD8VAigCQzMsF0ATTtkWhysCGBJkYXNoX2Jhc2VsaW5lXzFfdjERAHUAAA%3D%3D&ccb=9-4&oh=00_AfAd8Ue3vA6H0Qs33giXOj69-nMTm39UiUODzVSExso9Vw&oe=644032CF&_nc_sid=ea0b6e&_nc_rid=cd5aeb7c03',
#    'permalink': 'https://www.instagram.com/reel/Cqxk0Xsoa68/',
#    'thumbnail_url': 'https://scontent.cdninstagram.com/v/t51.29350-15/340027740_2210281752514186_8524181770435153408_n.jpg?_nc_cat=101&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=pahV_aluewsAX-UxRai&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfBx5JsMKZZKctuukg5SaCenRAFV9gkUYJXFeg4e8A9IIA&oe=6442E2E2',
#    'timestamp': '2023-04-08T12:08:39+0000',
#    'username': 'productminimal',
#    'like_count': 3608,
#    'comments_count': 7},
#   {'id': '18013644661560875',
#    'caption': 'A smart head/foot steering system for electric-powered wheelchairs, – developed by @_comoveit_ in collaboration with the team of engineers at @comateengineering and the creative people at @voyager.be\n\nThis innovation turns an ordinary powered wheelchair into a life-changing mobility device for people with complex movement disorders as they gain maximum independence in terms of mobility. The smart product from the @kuleuven spin-off uses sensors and artificial intelligence to adapt to the user’s ability.\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/339152965_1256720208276897_8929167749615613759_n.jpg?_nc_cat=110&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=K_b4_naK070AX-qG2nl&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfB0jRyCqWXzoabYTQ0hFfZStkPjjrFaJwM6zppZTGDA5g&oe=6443EC21',
#    'permalink': 'https://www.instagram.com/p/Cqs5qlIKCmq/',
#    'timestamp': '2023-04-06T16:34:30+0000',
#    'username': 'productminimal',
#    'like_count': 765,
#    'comments_count': 2},
#   {'id': '17970371858489105',
#    'caption': 'Exploring the fine details in our technical world - video by @sooshipasta \n\n_____\n\nDiscover more on @productminimal',
#    'media_type': 'VIDEO',
#    'permalink': 'https://www.instagram.com/reel/CqqjHfyovSz/',
#    'thumbnail_url': 'https://scontent.cdninstagram.com/v/t51.29350-15/339698887_746452763774586_66444183275674595_n.jpg?_nc_cat=108&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=iMj1YnkxjGsAX_LfR-g&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfDv_AuSqLXK3DeCGx3XCH_rrV2pLheI3_RnMTFFNUlU0Q&oe=6443F03D',
#    'timestamp': '2023-04-05T18:39:12+0000',
#    'username': 'productminimal',
#    'like_count': 1252,
#    'comments_count': 2},
#   {'id': '18001392361673074',
#    'caption': '@sooshipasta explores the small details in his recent experimentation around a project named "Tiny Interactions" \n\nThe devil lies in the detail, and this perfectly showcases that, proving once again how much effort can go in into the smallest parts of our everyday life and beyond!\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/339150517_776799053840310_5279525912738271054_n.jpg?_nc_cat=101&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=cGHzfemdVKoAX_Dn6Qv&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfD12HHbcXMWpzkSVfEKAVwFi6FX_J-SzdFpYK6brqiqeg&oe=6444962A',
#    'permalink': 'https://www.instagram.com/p/CqqXGJ-K5Bi/',
#    'timestamp': '2023-04-05T16:53:57+0000',
#    'username': 'productminimal',
#    'like_count': 1127,
#    'comments_count': 3},
#   {'id': '17883955985818741',
#    'caption': 'The Dual Vibe - A fantastic Personal project by @kimwootae_e\n-\nWhen the earphone unit and the main body perform their functions, we sketched various shapes to make them easy to use and attractive to people.\nTouch the earphone to set playback, stop, next song, volume, etc. The finger touch area is designed in a flat shape to make it more intuitive and easy to use when touching.\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/338161327_1257467925194544_6766331115909196189_n.jpg?_nc_cat=110&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=rpKqMI2kWF8AX8tZbkA&_nc_oc=AQkTLV4egwbX_iraMlBPd7eNRNoFPmWAheMNCIAgWBdiqNN6tGApHTyNLooGR-7wIKs&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfB_FQcmhrqwYQgvVmPNdLrf16ByQXg8g-LHW7-YLM-Scw&oe=6442F853',
#    'permalink': 'https://www.instagram.com/p/CqnjG-5oRBj/',
#    'timestamp': '2023-04-04T14:41:12+0000',
#    'username': 'productminimal',
#    'like_count': 530,
#    'comments_count': 1},
#   {'id': '17999889454706748',
#    'caption': '@arrival.uk - a company that tries to show everyone that the impossible can indeed be possible!\n\n"ICYMI – the first production verification vehicle drove out of the Microfactory. We think it looks 🤩"\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/338388977_742955687500920_8506040115046477943_n.jpg?_nc_cat=105&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=Uir80BPPQNkAX9pohM6&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfDL1gmPJwxAEzdnrZup04zBAt51OegI7eOKD8mCWjD3jw&oe=6442EE45',
#    'permalink': 'https://www.instagram.com/p/Cqk9-MBI_UW/',
#    'timestamp': '2023-04-03T14:38:12+0000',
#    'username': 'productminimal',
#    'like_count': 1243,
#    'comments_count': 4},
#   {'id': '18337818442069958',
#    'caption': 'Seems like @ridecake started a whole new aesthetic in the bike industry - almost like @teslamotors did in the automotive industry and we are definitely here for it! Just shows how important emerging start-ups are for competition and development.\n\n"Thrilled to see our drivetrain technology and parts inspire to new aspects of functionality and design, contributing to our mission to accelerate towards zero-emissions.\n\nBuild and PC:\n@hookieco\n@elsolitariomc @thelineup_sainttropez + @vincentprat__________ \n"\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/338212993_2392005737633864_4131434154364987737_n.jpg?_nc_cat=105&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=0opA7VLAL3sAX8AhDVl&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfCEqoH48D636veDlN7EfLNf7Dr2M0-NMPiEjXgFVFe25w&oe=6443CAA1',
#    'permalink': 'https://www.instagram.com/p/CqiY1J4IjVs/',
#    'timestamp': '2023-04-02T14:35:10+0000',
#    'username': 'productminimal',
#    'like_count': 2563,
#    'comments_count': 15},
#   {'id': '18016754743544354',
#    'caption': '@lego can definitely take some ideas from this fantastic illustration by @shanespencedesign !\n\n"Some colour variations and stills from the Lego animation 🧱🌈 Rendered in @keyshot3d using the @almond.school Essential Materials pack."\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/338135726_228259613081519_1251989083036706498_n.jpg?_nc_cat=109&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=zBbZ9f8rEYkAX-407bD&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfAFrH4y1JOwOq9Y_HnL5FVyVhi6W0663Ov4yX7PHue_4w&oe=644359EE',
#    'permalink': 'https://www.instagram.com/p/CqfzsWZoVSN/',
#    'timestamp': '2023-04-01T14:32:11+0000',
#    'username': 'productminimal',
#    'like_count': 555,
#    'comments_count': 0},
#   {'id': '18093539473320610',
#    'caption': '@samirsdesigns showcasing the Side profile with hard top on has a proper mafiosa outlaw character.\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/338172641_1375526716635175_3773804419740896739_n.jpg?_nc_cat=110&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=PhdHFZAK3_IAX9dKZan&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfAl-UHFZHxTv2ZmOsiKiWSiAc0IbFAG9oCW53IIoRireg&oe=64447B35',
#    'permalink': 'https://www.instagram.com/p/CqdOq-7qWM_/',
#    'timestamp': '2023-03-31T14:30:12+0000',
#    'username': 'productminimal',
#    'like_count': 904,
#    'comments_count': 3},
#   {'id': '17978065511129637',
#    'caption': 'B!POD - A vacuum system that protects the food you love for longer, fighting food waste from home. Designed by the talented team at @playback.design for the team at @hello_bipod 👏🏼🥙\n\nMade by the material science company SAES which pioneers applications and advanced materials, this device allows the creation of a vacuum inside its containers and preserves food five times longer with its vacuum performance. In less than 30 seconds per process, it removes 95% of the oxygen from the container.\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/338006185_1382176442635777_9004348427902487377_n.jpg?_nc_cat=104&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=bNtEydWrEjsAX_GiPjZ&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfAMUp_z4dPDtwi_7OSmTlaetSvtB3NoEi8u2JeMbXYlfQ&oe=644397BA',
#    'permalink': 'https://www.instagram.com/p/CqappeJoqFc/',
#    'timestamp': '2023-03-30T14:28:12+0000',
#    'username': 'productminimal',
#    'like_count': 737,
#    'comments_count': 2},
#   {'id': '17907045812738850',
#    'caption': 'Step by Step dissecting a camera concept by @design_leehanyoung - definitely something that Samsung should take a look at 😉\n\nThere are more detailed pictures in the last slides \n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/338174627_613116440248172_6419565210366370451_n.jpg?_nc_cat=111&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=Chzi3qT2drkAX8tT3ax&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfAB2L12bYWyDAXqpluH2yOvBk19UyV5fQjev2fxI33t6A&oe=6443E429',
#    'permalink': 'https://www.instagram.com/p/CqYER4dICai/',
#    'timestamp': '2023-03-29T14:23:11+0000',
#    'username': 'productminimal',
#    'like_count': 2647,
#    'comments_count': 9},
#   {'id': '17992395460867428',
#    'caption': 'Wade - the Personal water transportation concept by the talented @brendan_mudddesign. The design is focused on the question "What does personal transportation look like in a world adapted to higher sea levels? " which, with the rising temperatures around the world, seems to get more and more relevant.\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesignersuk',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/338200967_763814098405832_1287963587384892594_n.jpg?_nc_cat=102&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=LB890dLt03cAX8g9zUg&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfCFJG-V5BKqo9FDtXYyRy1HNN9XGt0WJOzm5ppvmuXVdQ&oe=6443C8D3',
#    'permalink': 'https://www.instagram.com/p/CqVtGXVqEkh/',
#    'timestamp': '2023-03-28T16:22:10+0000',
#    'username': 'productminimal',
#    'like_count': 375,
#    'comments_count': 2}],
#  'paging': {'cursors': {'before': 'QVFIUk9ZAR0ZATbG93S3l1VUgzQ0N5S3R6cUNrZAk82by1DazhMNHpUcklsN1M4NFVZAOXJSVmNPOWdnU09VaGVtVUlNWG5ZAV3R0Y0xvWnJUY3ZAJOUxCc0NHTFZAB',
#    'after': 'QVFIUjlDLXlZAV2Fad3BkNnlURTJuVXRzMWlGbWp2MHJoRHhUejlHWEFBRGJTeTR0VzhkNVZAfbXpQZA3NDUDdWejBlY3NaY1JXM0cyRTlITk9Bc1RyM2s5ak13'},
#   'next': 'https://graph.facebook.com/v16.0/17841447229527043/media?access_token=EAAG24jaJaYIBAJnJTbRCkiq7lyr6QGczbxTl92uNxgqxtqYGvvu22VkbZBmmuVvBl1OGng4vbaZBgxjjipOBbotaNCyPoUGQANkDkhaTgoejvu06B4JsZBGUZAIuzwLpKLM3QVCnOYrJmBkZARZA66Didy3X0VbEsodxQfrWMcEfWKaBsCPZC5s&fields=id%2Ccaption%2Cmedia_type%2Cmedia_url%2Cpermalink%2Cthumbnail_url%2Ctimestamp%2Cusername%2Clike_count%2Ccomments_count&limit=25&after=QVFIUjlDLXlZAV2Fad3BkNnlURTJuVXRzMWlGbWp2MHJoRHhUejlHWEFBRGJTeTR0VzhkNVZAfbXpQZA3NDUDdWejBlY3NaY1JXM0cyRTlITk9Bc1RyM2s5ak13'}}

# %% [markdown]
# ## Putting Image data in a Table

# %%
df = pd.DataFrame(basic_insight['data'])
df.columns = ['id', 'Caption', 'Media_Type', 'Media_URL', 'Permalink', 'Timestamp', 'Username', 'Likes', 'Comments', 'thumbnail_url']
df.head()
# Out:
#                   id                                            Caption  \
# 0  17897485115788540  With @apple being expected to release a mixed-...
# 1  17950853369556215  Explore the heat right in front of your eyes 🔥...
# 2  18040537486453786  Robots are taking over the world, but at least...
# 3  17972780834486774  @audiofficial is further stepping towards the ...
# 4  17975130056033325  Wireless is getting more and more common in sm...
#
#        Media_Type                                          Media_URL  \
# 0  CAROUSEL_ALBUM  https://scontent.cdninstagram.com/v/t39.30808-...
# 1  CAROUSEL_ALBUM  https://scontent.cdninstagram.com/v/t39.30808-...
# 2  CAROUSEL_ALBUM  https://scontent.cdninstagram.com/v/t39.30808-...
# 3           VIDEO  https://scontent.cdninstagram.com/o1/v/t16/f1/...
# 4  CAROUSEL_ALBUM  https://scontent.cdninstagram.com/v/t39.30808-...
#
#                                      Permalink                 Timestamp  \
# 0     https://www.instagram.com/p/CrLofM8qFsn/  2023-04-18T15:00:51+0000
# 1     https://www.instagram.com/p/CrJJPeuKoBu/  2023-04-17T15:49:20+0000
# 2     https://www.instagram.com/p/CrEhugEKTbs/  2023-04-15T20:47:05+0000
# 3  https://www.instagram.com/reel/CrBG-GgoVvE/  2023-04-14T12:55:44+0000
# 4     https://www.instagram.com/p/CrBGItOKkst/  2023-04-14T12:48:17+0000
#
#          Username  Likes  Comments  \
# 0  productminimal    167         1
# 1  productminimal   2109         4
# 2  productminimal    691         4
# 3  productminimal    746         2
# 4  productminimal   2925         5
#
#                                        thumbnail_url
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  https://scontent.cdninstagram.com/v/t51.29350-...
# 4                                                NaN

# %%
media_insight = []

# Loop Over 'Media ID'
for i in basic_insight['data']:
    if i['media_type'] == "CAROUSEL_ALBUM":
      params['latest_media_id'] = i['id']
      print(i)
      # Define URL
      url = params['endpoint_base'] + params['latest_media_id'] + '/insights'

      # Define Endpoint Parameters
      endpointParams = dict() 
      endpointParams['metric'] = 'engagement,impressions,reach,saved'
      endpointParams['access_token'] = params['access_token'] 

      # Requests Data
      data = requests.get(url, endpointParams )
      json_data = json.loads(data.content)
      media_insight.append(list(json_data['data']))
    else:
      None
# Out:
# {'id': '17897485115788540', 'caption': "With @apple being expected to release a mixed-reality headset and @facebook being stubborn about their VR/Metaverse strategy, VR Headsets are probably here to stay - making designs like these by @seoul_id not only nice to look at, but also relevant!\n\n“SWP is a wearable strabismus treatment device that promotes active and effective cure for childhood strabismus patients who are difficult to treat through surgery and other methods.\n\nThe motorized prism lens mounted inside the product continuously adapts the distortion angle according to the user's severity of strabismus. Accordingly, the treatment of strabismus can be further promoted by strengthening the eye movement effect.”\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner", 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/337747778_727882099089390_4991700846347472542_n.jpg?_nc_cat=107&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=-bZIf5OZrhYAX_Hpr1q&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfDJWYVkIlCgyqdlSenuI4DC0fqgkTrlIvqkhhoqMcsncA&oe=6443F935', 'permalink': 'https://www.instagram.com/p/CrLofM8qFsn/', 'timestamp': '2023-04-18T15:00:51+0000', 'username': 'productminimal', 'like_count': 167, 'comments_count': 1}
# {'id': '17950853369556215', 'caption': 'Explore the heat right in front of your eyes 🔥 Definitely a cool idea, although I can imagine that material resistance can be a problem here. Desgined by @pb_designs__ for @renderweekly \n\nCMF (Color-Material-Finish) is a tactical step in the design process of each Industrial Design project, that gives a deeper understanding of our target group, user experience and plays a major factor in how products AND brands stand out.\n\n„I am always curious how things are working, therefore it’s so exciting to see moving parts, blinking lights and get a deep understanding of the functionality.“\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/336918685_6120004631368136_1511933705726781811_n.jpg?_nc_cat=108&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=qgIf6KUNGSQAX8gUHek&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfAsztKQ8G6_QOApXWci9W2m9RS7kbrcSupS9p7gxOjSJw&oe=64443457', 'permalink': 'https://www.instagram.com/p/CrJJPeuKoBu/', 'timestamp': '2023-04-17T15:49:20+0000', 'username': 'productminimal', 'like_count': 2109, 'comments_count': 4}
# {'id': '18040537486453786', 'caption': 'Robots are taking over the world, but at least they look fancy. This concept here is called Symbion and is designed by the talented @alpcakindesign\n\nMany different construction machines are used in the construction of a building. But hand tools are generally used to facilitate the work in the interior works of the construction. Since these works are done by people, occupational accidents are frequently experienced in workspace. It also causes cost and time loss. Symbion product family performs floor levelling, drilling holes and wall chasing for installations in the interior of the construction autonomously with bim files. It prevents various work accidents while applying these processes.\n\nThe problems to be encountered during manufacturing are determined previously and corrected in the bim application. Bim file is uploaded to robots then the revisions made in this file are transferred to the robots simultaneously. Thus, the possibility of error is minimized and cost, energy and time savings are achieved.\n\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/336661866_251909807501842_3215654569570654572_n.jpg?_nc_cat=101&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=3i3JC8uzbZoAX9bzNcP&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfBAlO-ENVgRGNbuX2SKd7guaTc41RSJaECE8zUwb9HWUg&oe=64441B62', 'permalink': 'https://www.instagram.com/p/CrEhugEKTbs/', 'timestamp': '2023-04-15T20:47:05+0000', 'username': 'productminimal', 'like_count': 691, 'comments_count': 4}
# {'id': '17975130056033325', 'caption': 'Wireless is getting more and more common in smartphones and gadgets - and these chargers definitely make them even more attractive to buy 😉 CHAU - Wireless & Portable charger, design by @yyoung_design 🔥\n\n"Wireless chargers freed electronic devices from wires and brought convenience to our daily lives. \nHowever, while wired charging allows movement in a certain space, wireless chargers cannot move the smart phone while charging. Therefore, it is more suitable as a vehicle or office product with relatively little movement of the smart phone.\nA time when telecommuting became commonplace due to the pandemic and the boundary between office and home became blurred, I wondered what if wireless chargers, which are office supplies, come home? And this project started with the question."\n\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/341088244_140342085649853_1207520435377662030_n.jpg?_nc_cat=105&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=_ztFeQF1ED0AX-BRQ1T&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfBSoVytpTU1A-B44BMoqXszR8TnDBFW3W_keK7cp6ZHOA&oe=6443083E', 'permalink': 'https://www.instagram.com/p/CrBGItOKkst/', 'timestamp': '2023-04-14T12:48:17+0000', 'username': 'productminimal', 'like_count': 2925, 'comments_count': 5}
# {'id': '17853854579921301', 'caption': 'Lightning up the dark with the this transparent flashlight by @studiocoolberlin ⛓️ for @renderweekly \n-\n"Double lens flashlight for @renderweekly #rwcloudy\nThis season\'s prompts are great :)"\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/336252746_1301347363748064_7867792272100530033_n.jpg?_nc_cat=103&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=JEfmjLR1sbIAX8dVrFc&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfAGAtOlgcPetH__W4pRw6zKQoNc-hnSga6DrHhIrvRQjg&oe=6443B14A', 'permalink': 'https://www.instagram.com/p/Cq-5rCzKyK5/', 'timestamp': '2023-04-13T16:20:53+0000', 'username': 'productminimal', 'like_count': 1216, 'comments_count': 4}
# {'id': '18015505108510870', 'caption': 'Electric scooter concept by @anthony.kaha - in my opinion a bit too round, but still a great concept!\n\nDue to on demand scooter services by Lyft, Brid or similar E-Scooters seem to be pretty unpopular in the general population, but they are still a good alternative to going by foot or bikes!\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/340911223_245309347885240_8541317450348171318_n.jpg?_nc_cat=109&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=qgutC8wlSOIAX8ni2Ga&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfBidj0S1RWqf_XTVzk0Xp8zDFOYpjbW2n-djjUgAPkTqA&oe=644459E6', 'permalink': 'https://www.instagram.com/p/Cq8GYHwIo6D/', 'timestamp': '2023-04-12T14:14:11+0000', 'username': 'productminimal', 'like_count': 1220, 'comments_count': 4}
# {'id': '18078017998355849', 'caption': 'The FREE HANDS DRYER, found on @designerdot_academy, is a concept that aims to allow multitasking while drying your hair 👀. Designer_Jung eun Jung\n\nOn a busy morning, while doing makeup, I wished someone could dry my hair.\nSo I thought about what it would be like to have a dryer that could be fixed where I wanted, so I started designing.\nThe grip has a tong structure that makes the dryer easy to attach and remove, and I wanted it to be placed anywhere in the house and approach it as an interior accessory rather than an appliance. To solve this, we designed it considering various patterns and organic tong shapes.\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/340658196_1369245293874591_4193395069615007471_n.jpg?_nc_cat=108&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=p5LIAb1gv0wAX_u31V7&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfBIKskmuKMJgwWxSayWmvSbl386yqeymh3TtPsZcdVT8w&oe=64432CFD', 'permalink': 'https://www.instagram.com/p/Cq27eV7KX_1/', 'timestamp': '2023-04-10T14:02:42+0000', 'username': 'productminimal', 'like_count': 1426, 'comments_count': 7}
# {'id': '17998195930776358', 'caption': '@design_leehanyoung and @design_hyunsub exploring new ways to support elders or impaired 👀\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent.cdninstagram.com/v/t51.29350-15/340334426_141793012183559_7218858731842789595_n.jpg?_nc_cat=102&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=rjOmWNEuGz0AX9ou3Yr&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfCsbOclBGYcfSucehSBZgBFmS_uAY5oPR8gNigdCqIrXA&oe=64445016', 'permalink': 'https://www.instagram.com/p/Cq0dKlUofSI/', 'timestamp': '2023-04-09T14:59:23+0000', 'username': 'productminimal', 'like_count': 752, 'comments_count': 2}
# {'id': '17890206992748203', 'caption': "Vertically Guitar Pedal concept by @sushantvohra \n\nIn my opinion, this concept is a prime example of a design that does not necessarily aim to solve a specific problem but rather exists to play around with forms and ideas to come up with something stunning and beautiful - and that's definitely achieved here. Especially the amount of details that you can see here makes this design worth sharing - fantastic job!\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner", 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/339422516_953478835662790_2422555732961043046_n.jpg?_nc_cat=108&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=WCwsuPoGjG8AX9DXtZM&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfBpYhOKyFuZjCXORhwLMQvHLXfmq2OFCu7TNViLmFc6YA&oe=6444531A', 'permalink': 'https://www.instagram.com/p/Cqx1mdRIUn7/', 'timestamp': '2023-04-08T14:35:11+0000', 'username': 'productminimal', 'like_count': 1585, 'comments_count': 6}
# {'id': '18002208748662256', 'caption': '@glen.cordle created these goggles for the @renderweekly challenge. Normally occupied with designing cars, he\'s taking a break from it and delivering a banger goggle submission. The perfect goggles to explore glaciers 👀🔥\n\n"So, these goggles are an original design. The Creamcar branding is also original although influenced in all the right places. You may remember it from my NFT excursion.\n\nThis was about 4 hours from the point I scribbled a basic sketch to when I hit "go" on the rendering queue. Modeled using Creo, rendered in Keyshot 10. Hope you can dig it."\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/339308425_1347486902697653_269948326246758929_n.jpg?_nc_cat=111&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=8vytsTJAeUUAX8Hs5i8&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfAooqgOngYi8aLvN6TECExUORxo4X6H4jvQB1IcPtDcug&oe=6442CBA6', 'permalink': 'https://www.instagram.com/p/CqxlHQ1Kwnz/', 'timestamp': '2023-04-08T12:11:07+0000', 'username': 'productminimal', 'like_count': 2089, 'comments_count': 8}
# {'id': '18013644661560875', 'caption': 'A smart head/foot steering system for electric-powered wheelchairs, – developed by @_comoveit_ in collaboration with the team of engineers at @comateengineering and the creative people at @voyager.be\n\nThis innovation turns an ordinary powered wheelchair into a life-changing mobility device for people with complex movement disorders as they gain maximum independence in terms of mobility. The smart product from the @kuleuven spin-off uses sensors and artificial intelligence to adapt to the user’s ability.\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/339152965_1256720208276897_8929167749615613759_n.jpg?_nc_cat=110&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=K_b4_naK070AX-qG2nl&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfB0jRyCqWXzoabYTQ0hFfZStkPjjrFaJwM6zppZTGDA5g&oe=6443EC21', 'permalink': 'https://www.instagram.com/p/Cqs5qlIKCmq/', 'timestamp': '2023-04-06T16:34:30+0000', 'username': 'productminimal', 'like_count': 765, 'comments_count': 2}
# {'id': '18001392361673074', 'caption': '@sooshipasta explores the small details in his recent experimentation around a project named "Tiny Interactions" \n\nThe devil lies in the detail, and this perfectly showcases that, proving once again how much effort can go in into the smallest parts of our everyday life and beyond!\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/339150517_776799053840310_5279525912738271054_n.jpg?_nc_cat=101&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=cGHzfemdVKoAX_Dn6Qv&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfD12HHbcXMWpzkSVfEKAVwFi6FX_J-SzdFpYK6brqiqeg&oe=6444962A', 'permalink': 'https://www.instagram.com/p/CqqXGJ-K5Bi/', 'timestamp': '2023-04-05T16:53:57+0000', 'username': 'productminimal', 'like_count': 1127, 'comments_count': 3}
# {'id': '17883955985818741', 'caption': 'The Dual Vibe - A fantastic Personal project by @kimwootae_e\n-\nWhen the earphone unit and the main body perform their functions, we sketched various shapes to make them easy to use and attractive to people.\nTouch the earphone to set playback, stop, next song, volume, etc. The finger touch area is designed in a flat shape to make it more intuitive and easy to use when touching.\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/338161327_1257467925194544_6766331115909196189_n.jpg?_nc_cat=110&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=rpKqMI2kWF8AX8tZbkA&_nc_oc=AQkTLV4egwbX_iraMlBPd7eNRNoFPmWAheMNCIAgWBdiqNN6tGApHTyNLooGR-7wIKs&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfB_FQcmhrqwYQgvVmPNdLrf16ByQXg8g-LHW7-YLM-Scw&oe=6442F853', 'permalink': 'https://www.instagram.com/p/CqnjG-5oRBj/', 'timestamp': '2023-04-04T14:41:12+0000', 'username': 'productminimal', 'like_count': 530, 'comments_count': 1}
# {'id': '17999889454706748', 'caption': '@arrival.uk - a company that tries to show everyone that the impossible can indeed be possible!\n\n"ICYMI – the first production verification vehicle drove out of the Microfactory. We think it looks 🤩"\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/338388977_742955687500920_8506040115046477943_n.jpg?_nc_cat=105&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=Uir80BPPQNkAX9pohM6&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfDL1gmPJwxAEzdnrZup04zBAt51OegI7eOKD8mCWjD3jw&oe=6442EE45', 'permalink': 'https://www.instagram.com/p/Cqk9-MBI_UW/', 'timestamp': '2023-04-03T14:38:12+0000', 'username': 'productminimal', 'like_count': 1243, 'comments_count': 4}
# {'id': '18337818442069958', 'caption': 'Seems like @ridecake started a whole new aesthetic in the bike industry - almost like @teslamotors did in the automotive industry and we are definitely here for it! Just shows how important emerging start-ups are for competition and development.\n\n"Thrilled to see our drivetrain technology and parts inspire to new aspects of functionality and design, contributing to our mission to accelerate towards zero-emissions.\n\nBuild and PC:\n@hookieco\n@elsolitariomc @thelineup_sainttropez + @vincentprat__________ \n"\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/338212993_2392005737633864_4131434154364987737_n.jpg?_nc_cat=105&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=0opA7VLAL3sAX8AhDVl&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfCEqoH48D636veDlN7EfLNf7Dr2M0-NMPiEjXgFVFe25w&oe=6443CAA1', 'permalink': 'https://www.instagram.com/p/CqiY1J4IjVs/', 'timestamp': '2023-04-02T14:35:10+0000', 'username': 'productminimal', 'like_count': 2563, 'comments_count': 15}
# {'id': '18016754743544354', 'caption': '@lego can definitely take some ideas from this fantastic illustration by @shanespencedesign !\n\n"Some colour variations and stills from the Lego animation 🧱🌈 Rendered in @keyshot3d using the @almond.school Essential Materials pack."\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/338135726_228259613081519_1251989083036706498_n.jpg?_nc_cat=109&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=zBbZ9f8rEYkAX-407bD&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfAFrH4y1JOwOq9Y_HnL5FVyVhi6W0663Ov4yX7PHue_4w&oe=644359EE', 'permalink': 'https://www.instagram.com/p/CqfzsWZoVSN/', 'timestamp': '2023-04-01T14:32:11+0000', 'username': 'productminimal', 'like_count': 555, 'comments_count': 0}
# {'id': '18093539473320610', 'caption': '@samirsdesigns showcasing the Side profile with hard top on has a proper mafiosa outlaw character.\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/338172641_1375526716635175_3773804419740896739_n.jpg?_nc_cat=110&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=PhdHFZAK3_IAX9dKZan&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfAl-UHFZHxTv2ZmOsiKiWSiAc0IbFAG9oCW53IIoRireg&oe=64447B35', 'permalink': 'https://www.instagram.com/p/CqdOq-7qWM_/', 'timestamp': '2023-03-31T14:30:12+0000', 'username': 'productminimal', 'like_count': 904, 'comments_count': 3}
# {'id': '17978065511129637', 'caption': 'B!POD - A vacuum system that protects the food you love for longer, fighting food waste from home. Designed by the talented team at @playback.design for the team at @hello_bipod 👏🏼🥙\n\nMade by the material science company SAES which pioneers applications and advanced materials, this device allows the creation of a vacuum inside its containers and preserves food five times longer with its vacuum performance. In less than 30 seconds per process, it removes 95% of the oxygen from the container.\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/338006185_1382176442635777_9004348427902487377_n.jpg?_nc_cat=104&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=bNtEydWrEjsAX_GiPjZ&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfAMUp_z4dPDtwi_7OSmTlaetSvtB3NoEi8u2JeMbXYlfQ&oe=644397BA', 'permalink': 'https://www.instagram.com/p/CqappeJoqFc/', 'timestamp': '2023-03-30T14:28:12+0000', 'username': 'productminimal', 'like_count': 737, 'comments_count': 2}
# {'id': '17907045812738850', 'caption': 'Step by Step dissecting a camera concept by @design_leehanyoung - definitely something that Samsung should take a look at 😉\n\nThere are more detailed pictures in the last slides \n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/338174627_613116440248172_6419565210366370451_n.jpg?_nc_cat=111&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=Chzi3qT2drkAX8tT3ax&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfAB2L12bYWyDAXqpluH2yOvBk19UyV5fQjev2fxI33t6A&oe=6443E429', 'permalink': 'https://www.instagram.com/p/CqYER4dICai/', 'timestamp': '2023-03-29T14:23:11+0000', 'username': 'productminimal', 'like_count': 2647, 'comments_count': 9}
# {'id': '17992395460867428', 'caption': 'Wade - the Personal water transportation concept by the talented @brendan_mudddesign. The design is focused on the question "What does personal transportation look like in a world adapted to higher sea levels? " which, with the rising temperatures around the world, seems to get more and more relevant.\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesignersuk', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent.cdninstagram.com/v/t39.30808-6/338200967_763814098405832_1287963587384892594_n.jpg?_nc_cat=102&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=LB890dLt03cAX8g9zUg&_nc_ht=scontent.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfCFJG-V5BKqo9FDtXYyRy1HNN9XGt0WJOzm5ppvmuXVdQ&oe=6443C8D3', 'permalink': 'https://www.instagram.com/p/CqVtGXVqEkh/', 'timestamp': '2023-03-28T16:22:10+0000', 'username': 'productminimal', 'like_count': 375, 'comments_count': 2}

# %%
# Initialize Empty Container
engagement_list = []
impressions_list = []
reach_list = []
saved_list = []

# Loop Over Insights to Fill Container
for insight in media_insight:
    engagement_list.append(insight[0]['values'][0]['value'])
    impressions_list.append(insight[1]['values'][0]['value'])
    reach_list.append(insight[2]['values'][0]['value'])
    saved_list.append(insight[3]['values'][0]['value'])
    
# Create DataFrame
df_media_insight = pd.DataFrame(list(zip(engagement_list, impressions_list, reach_list, saved_list)), columns =['Engagement', 'Impressions', 'Reach', 'Saved'])
df_media_insight
# Out:
#     Engagement  Impressions  Reach  Saved
# 0          194         3562   3345     26
# 1         2611        30835  27845    498
# 2          888        16678  13850    193
# 3         3874        71375  66121    944
# 4         1474        23420  20292    254
# 5         1496        23452  21070    272
# 6         1811        39070  35821    378
# 7          905        21025  17860    151
# 8         1947        33890  30475    356
# 9         2842        40530  38943    745
# 10         953        18736  16215    186
# 11        1405        21410  18489    275
# 12         654        13777  11219    123
# 13        1490        23816  20757    243
# 14        3276        36037  30885    698
# 15         632        13770  11131     77
# 16        1025        21763  18887    118
# 17         904        19113  16254    165
# 18        3458        48332  43457    802
# 19         475        13527  10922     98

# %% [markdown]
# # Demographics data Lifetime

# %%
# Define URL
url = params['endpoint_base'] + params['instagram_account_id'] + '/insights'

# Define Endpoint Parameters
endpointParams = dict()
endpointParams['metric'] = 'audience_city,audience_country,audience_gender_age' 
endpointParams['period'] = 'lifetime' 
endpointParams['access_token'] = params['access_token'] 

# Requests Data
data = requests.get(url, endpointParams )
audience_insight = json.loads(data.content)
audience_insight
# Out:
# {'data': [{'name': 'audience_city',
#    'period': 'lifetime',
#    'values': [{'value': {'Sydney, New South Wales': 303,
#       'London, England': 745,
#       'São Paulo, São Paulo (state)': 511,
#       'Barcelona, Cataluña': 280,
#       'Hong Kong, Hong Kong': 530,
#       'Berlin, Berlin': 374,
#       'Kyiv, Kyiv': 269,
#       'Lagos, Lagos State': 301,
#       'Seoul, Seoul': 1451,
#       'Pune, Maharashtra': 291,
#       'Ahmedabad, Gujarat': 286,
#       'Moscow, Moscow': 678,
#       'Bogotá, Distrito Especial': 574,
#       'Jakarta, Jakarta': 916,
#       'Paris, Île-de-France': 354,
#       'Buenos Aires, Ciudad Autónoma de Buenos Aires': 515,
#       'Taipei, Taipei': 572,
#       'Ho Chi Minh City, Ho Chi Minh City': 387,
#       'Xinbei, New Taipei City': 447,
#       'Shanghai, Shanghai': 2031,
#       'Melbourne, Victoria': 408,
#       'Delhi, Delhi': 480,
#       'Los Angeles, California': 330,
#       'Madrid, Comunidad de Madrid': 315,
#       'Shahriyar, Tehran Province': 265,
#       'Lima, Lima Region': 271,
#       'Istanbul, Istanbul Province': 1761,
#       'Toronto, Ontario': 262,
#       'Chennai, Tamil Nadu': 388,
#       'Ankara, Ankara Province': 270,
#       'Milan, Lombardia': 424,
#       'Bangkok, Bangkok': 616,
#       'Mexico City, Distrito Federal': 791,
#       'Mashhad, Razavi Khorasan Province': 299,
#       'Riyadh, Riyadh Region': 315,
#       'Saint Petersburg, Saint Petersburg': 314,
#       'New York, New York': 556,
#       'Tehran, Tehran Province': 2563,
#       'Cairo, Cairo Governorate': 371,
#       'Dubai, Dubai': 377,
#       'Santiago, Santiago Metropolitan Region': 442,
#       'Mumbai, Maharashtra': 581,
#       'Bangalore, Karnataka': 806,
#       'Singapore, Singapore': 409,
#       'Tashkent, Tashkent Region': 402}}],
#    'title': 'Stadt der Zielgruppe',
#    'description': 'Städte der Follower dieses Profils',
#    'id': '17841447229527043/insights/audience_city/lifetime'},
#   {'name': 'audience_country',
#    'period': 'lifetime',
#    'values': [{'value': {'DE': 2598,
#       'BE': 424,
#       'HK': 531,
#       'TW': 1747,
#       'RU': 2172,
#       'PT': 673,
#       'JP': 1196,
#       'UA': 817,
#       'FR': 2169,
#       'SA': 718,
#       'BR': 2743,
#       'SE': 579,
#       'MA': 428,
#       'ID': 2883,
#       'GB': 2914,
#       'CA': 1340,
#       'US': 6911,
#       'EG': 771,
#       'IL': 414,
#       'AE': 588,
#       'CH': 466,
#       'UZ': 531,
#       'IN': 7240,
#       'ZA': 598,
#       'KR': 2893,
#       'IQ': 428,
#       'CL': 661,
#       'IR': 5466,
#       'CN': 2303,
#       'MX': 2602,
#       'IT': 3478,
#       'MY': 753,
#       'CO': 1220,
#       'ES': 1951,
#       'KZ': 419,
#       'AR': 1781,
#       'TH': 963,
#       'AU': 1101,
#       'PH': 443,
#       'VN': 572,
#       'NG': 667,
#       'PK': 686,
#       'PL': 716,
#       'NL': 749,
#       'TR': 3421}}],
#    'title': 'Land der Zielgruppe',
#    'description': 'Länder der Follower dieses Profils',
#    'id': '17841447229527043/insights/audience_country/lifetime'},
#   {'name': 'audience_gender_age',
#    'period': 'lifetime',
#    'values': [{'value': {'F.13-17': 97,
#       'F.18-24': 2899,
#       'F.25-34': 3399,
#       'F.35-44': 1196,
#       'F.45-54': 370,
#       'F.55-64': 122,
#       'F.65+': 79,
#       'M.13-17': 605,
#       'M.18-24': 11800,
#       'M.25-34': 24852,
#       'M.35-44': 12661,
#       'M.45-54': 3814,
#       'M.55-64': 853,
#       'M.65+': 595,
#       'U.13-17': 596,
#       'U.18-24': 6889,
#       'U.25-34': 8151,
#       'U.35-44': 4166,
#       'U.45-54': 1453,
#       'U.55-64': 412,
#       'U.65+': 330}}],
#    'title': 'Geschlecht und Alter',
#    'description': 'Geschlecht und Alter der Follower dieses Profils',
#    'id': '17841447229527043/insights/audience_gender_age/lifetime'}]}

# %% [markdown]
# ## Algorithm to get the data into table format

# %%
#The variables that I search for

audience_city = []
audience_country = []
audience_genderage = []


#Variables for Country
country_short = []
country_number = []

#Variables for City
city_name = []
region_name = []
city_number = []

#Variables for Age and Gender
gender = []
age_bracket = []
age_number = []

for i in audience_insight["data"]:
    if i['name'] == "audience_country":
      for x in i['values']:
        for z in x["value"]:
          country_short.append(z)
          country_number.append(x['value'][z])
    if i['name'] == "audience_city":
      for x in i['values']:
        for z in x["value"]:
          xy = z.split(", ")
          city_name.append(xy[0])
          region_name.append(xy[1])
          city_number.append(x['value'][z])
    if i['name'] == "audience_gender_age":
      for x in i['values']:
        for z in x["value"]:
          gender_age_split = z.split(".")
          gender.append(gender_age_split[0])
          age_bracket.append(gender_age_split[1])
          age_number.append(x['value'][z])



audience_country = pd.DataFrame(list(zip(country_short, country_number)), columns =['Country_ID', 'Count'])
audience_city = pd.DataFrame(list(zip(city_name, region_name, city_number)), columns =['City', 'Region', 'Count'])
audience_genderage = pd.DataFrame(list(zip(gender, age_bracket, age_number)), columns =['Gender', 'Age Bracket', 'Count'])

#audience_country
#audience_city
audience_city = audience_city.sort_values(by = ['Count'],ascending=False)
audience_country = audience_country.sort_values(by = ['Count'],ascending=False)
audience_genderage = audience_genderage.sort_values(by = ['Count'],ascending=False)

audience_country
# Out:
#    Country_ID  Count
# 22         IN   7240
# 16         US   6911
# 27         IR   5466
# 30         IT   3478
# 44         TR   3421
# 14         GB   2914
# 24         KR   2893
# 13         ID   2883
# 10         BR   2743
# 29         MX   2602
# 0          DE   2598
# 28         CN   2303
# 4          RU   2172
# 8          FR   2169
# 33         ES   1951
# 35         AR   1781
# 3          TW   1747
# 15         CA   1340
# 32         CO   1220
# 6          JP   1196
# 37         AU   1101
# 36         TH    963
# 7          UA    817
# 17         EG    771
# 31         MY    753
# 43         NL    749
# 9          SA    718
# 42         PL    716
# 41         PK    686
# 5          PT    673
# 40         NG    667
# 26         CL    661
# 23         ZA    598
# 19         AE    588
# 11         SE    579
# 39         VN    572
# 2          HK    531
# 21         UZ    531
# 20         CH    466
# 38         PH    443
# 12         MA    428
# 25         IQ    428
# 1          BE    424
# 34         KZ    419
# 18         IL    414

# %% [markdown]
# ### Country Codes

# %%
import country_converter as coco
import pycountry

country_dict = {country.alpha_2: country.name for country in pycountry.countries}
audience_country['Country'] = audience_country['Country_ID'].map(country_dict)
audience_country = audience_country.reindex(columns=['Country', 'Country_ID', 'Count'])
audience_country
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: country_converter in /usr/local/lib/python3.9/dist-packages (1.0.0)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.9/dist-packages (from country_converter) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0->country_converter) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0->country_converter) (1.22.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0->country_converter) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas>=1.0->country_converter) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pycountry in /usr/local/lib/python3.9/dist-packages (22.3.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from pycountry) (67.6.1)
#                       Country Country_ID  Count
# 22                      India         IN   7240
# 16              United States         US   6911
# 27  Iran, Islamic Republic of         IR   5466
# 30                      Italy         IT   3478
# 44                     Turkey         TR   3421
# 14             United Kingdom         GB   2914
# 24         Korea, Republic of         KR   2893
# 13                  Indonesia         ID   2883
# 10                     Brazil         BR   2743
# 29                     Mexico         MX   2602
# 0                     Germany         DE   2598
# 28                      China         CN   2303
# 4          Russian Federation         RU   2172
# 8                      France         FR   2169
# 33                      Spain         ES   1951
# 35                  Argentina         AR   1781
# 3   Taiwan, Province of China         TW   1747
# 15                     Canada         CA   1340
# 32                   Colombia         CO   1220
# 6                       Japan         JP   1196
# 37                  Australia         AU   1101
# 36                   Thailand         TH    963
# 7                     Ukraine         UA    817
# 17                      Egypt         EG    771
# 31                   Malaysia         MY    753
# 43                Netherlands         NL    749
# 9                Saudi Arabia         SA    718
# 42                     Poland         PL    716
# 41                   Pakistan         PK    686
# 5                    Portugal         PT    673
# 40                    Nigeria         NG    667
# 26                      Chile         CL    661
# 23               South Africa         ZA    598
# 19       United Arab Emirates         AE    588
# 11                     Sweden         SE    579
# 39                   Viet Nam         VN    572
# 2                   Hong Kong         HK    531
# 21                 Uzbekistan         UZ    531
# 20                Switzerland         CH    466
# 38                Philippines         PH    443
# 12                    Morocco         MA    428
# 25                       Iraq         IQ    428
# 1                     Belgium         BE    424
# 34                 Kazakhstan         KZ    419
# 18                     Israel         IL    414

# %%
audience_country
# Out:
#                       Country Country_ID  Count
# 22                      India         IN   7240
# 16              United States         US   6911
# 27  Iran, Islamic Republic of         IR   5466
# 30                      Italy         IT   3478
# 44                     Turkey         TR   3421
# 14             United Kingdom         GB   2914
# 24         Korea, Republic of         KR   2893
# 13                  Indonesia         ID   2883
# 10                     Brazil         BR   2743
# 29                     Mexico         MX   2602
# 0                     Germany         DE   2598
# 28                      China         CN   2303
# 4          Russian Federation         RU   2172
# 8                      France         FR   2169
# 33                      Spain         ES   1951
# 35                  Argentina         AR   1781
# 3   Taiwan, Province of China         TW   1747
# 15                     Canada         CA   1340
# 32                   Colombia         CO   1220
# 6                       Japan         JP   1196
# 37                  Australia         AU   1101
# 36                   Thailand         TH    963
# 7                     Ukraine         UA    817
# 17                      Egypt         EG    771
# 31                   Malaysia         MY    753
# 43                Netherlands         NL    749
# 9                Saudi Arabia         SA    718
# 42                     Poland         PL    716
# 41                   Pakistan         PK    686
# 5                    Portugal         PT    673
# 40                    Nigeria         NG    667
# 26                      Chile         CL    661
# 23               South Africa         ZA    598
# 19       United Arab Emirates         AE    588
# 11                     Sweden         SE    579
# 39                   Viet Nam         VN    572
# 2                   Hong Kong         HK    531
# 21                 Uzbekistan         UZ    531
# 20                Switzerland         CH    466
# 38                Philippines         PH    443
# 12                    Morocco         MA    428
# 25                       Iraq         IQ    428
# 1                     Belgium         BE    424
# 34                 Kazakhstan         KZ    419
# 18                     Israel         IL    414

# %%
import pandas as pd
from datetime import datetime

# generate timestamp string for filename
timestamp_str = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# set the name of the CSV file to include the timestamp
filename = f"country_{timestamp_str}.csv"

# save the dataframe as a CSV file
audience_country.to_csv(filename, index=False)

# %% [markdown]
# # Playing around with time frames - for Day timeframe

# %%
# Define URL
url = params['endpoint_base'] + params['instagram_account_id'] + '/insights'

# Define Endpoint Parameters
endpointParams = dict()
endpointParams['metric'] = 'impressions, reach, likes, comments, profile_views' 
endpointParams['period'] = 'day'
endpointParams['metric_type'] = 'total_value'
endpointParams['access_token'] = params['access_token'] 

# Requests Data
day_account_insight_data = requests.get(url, endpointParams )
day_account_insight = json.loads(day_account_insight_data.content)
day_account_insight

# %%
for i in day_account_insight:
  for x in day_account_insight[i]:
    print(x)
    if x['name'] == 'impressions':
      print(x['total_value']['value'])

# %%
audience_country.to_csv('country_data.csv', index=False)

# %% [markdown]
# # Connecting with BigQuery

# %%
from google.colab import auth
from google.cloud import bigquery
auth.authenticate_user()

#Replace 'project_id' with your BigQuery project ID

# %%
client = bigquery.Client(project='instagram-analytics-384117')

# %%
table_id = 'instagram-analytics-384117.instagramanalyticsdata.analytics'
schema = [{'name': 'Country', 'type': 'STRING'},		
 {'name': 'Country_ID', 'type': 'STRING'},
 {'name': 'Count', 'type': 'INTEGER'}]
table = bigquery.Table(table_id, schema=schema)
table = client.create_table(table)  # Make an API request.
print(f'Created table {table.project}.{table.dataset_id}.{table.table_id}')
# Out:
# Created table instagram-analytics-384117.instagramanalyticsdata.analytics

# %%
job_config = bigquery.LoadJobConfig(schema=schema)
job = client.load_table_from_dataframe(audience_country, table_id, job_config=job_config)
job.result()  # Wait for the job to complete.
print(f'Loaded {len(df)} rows into {table_id}')
# Out:
# Loaded 25 rows into instagram-analytics-384117.instagramanalyticsdata.analytics
