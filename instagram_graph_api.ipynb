# %% [markdown]
# <a href="https://colab.research.google.com/github/premstaller1/instagram-graph-api/blob/main/instagram_graph_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# # Als Code formatiert
# ```
#
# # Lets do some Coding

# %% [markdown]
# # Neuer Abschnitt

# %%
# Import Libraries
import requests
import json
import datetime
import pandas as pd

# Define Parameters Dictionary
params = dict()
params['access_token'] = 'EAAG24jaJaYIBAPdBNZCt4WQfuoospdeTsDvtdZAzqF5kHHkkc6t9kiR91NQRIuBkWrTRtjhpYELLMYqyYwr7HqDFPwZCVyCSc2n7vyt1xiyx5RaE23ZAU6DhdoqJ5kYkTPhqNyz8sxdTijSytxNIoo4yFfZCbMpzhsjwTpkDZCbSVCHZALbkxZC0977Po18hDNAZD'        # not an actual access token
params['client_id'] = '482557670549890'                  # not an actual client id
params['client_secret'] = 'd62937e7f31973871d86b8242430b73e'     # not an actual client secret
params['graph_domain'] = 'https://graph.facebook.com'
params['graph_version'] = 'v16.0'
params['endpoint_base'] = params['graph_domain'] + '/' + params['graph_version'] + '/'
params['page_id'] = '482557670549890'                  # not an actual page id
params['instagram_account_id'] = '17841447229527043'        # not an actual instagram business account id
params['ig_username'] = 'productminimal'

# Define Endpoint Parameters
endpointParams = dict()
endpointParams['input_token'] = params['access_token']
endpointParams['access_token'] = params['access_token']

# Define URL
url = params['graph_domain'] + '/debug_token'

# Requests Data
data = requests.get(url, endpointParams)
access_token_data = json.loads(data.content)
access_token_data
# Out:
# {'data': {'app_id': '482557670549890',
#   'type': 'USER',
#   'application': 'get.data',
#   'data_access_expires_at': 1683566062,
#   'expires_at': 1680969789,
#   'is_valid': True,
#   'issued_at': 1675785789,
#   'scopes': ['pages_show_list',
#    'instagram_basic',
#    'instagram_manage_insights',
#    'instagram_content_publish',
#    'pages_read_engagement',
#    'pages_manage_metadata',
#    'pages_manage_posts'],
#   'granular_scopes': [{'scope': 'pages_show_list'},
#    {'scope': 'instagram_basic'},
#    {'scope': 'instagram_manage_insights'},
#    {'scope': 'instagram_content_publish'},
#    {'scope': 'pages_read_engagement'},
#    {'scope': 'pages_manage_metadata'},
#    {'scope': 'pages_manage_posts'}],
#   'user_id': '991919581778381'}}

# %% [markdown]
# # Neuer Abschnitt

# %%
print("Token Expires: ", datetime.datetime.fromtimestamp(access_token_data['data']['expires_at']))
# Out:
# Token Expires:  2023-04-08 16:03:09

# %%
# Define URL
url = params['endpoint_base'] + 'oauth/access_token'

# Define Endpoint Parameters
endpointParams = dict() 
endpointParams['grant_type'] = 'fb_exchange_token'
endpointParams['client_id'] = params['client_id']
endpointParams['client_secret'] = params['client_secret']
endpointParams['fb_exchange_token'] = params['access_token']

# Requests Data
data = requests.get(url, endpointParams )
long_lived_token = json.loads(data.content)
long_lived_token
# Out:
# {'access_token': 'EAAG24jaJaYIBAPdBNZCt4WQfuoospdeTsDvtdZAzqF5kHHkkc6t9kiR91NQRIuBkWrTRtjhpYELLMYqyYwr7HqDFPwZCVyCSc2n7vyt1xiyx5RaE23ZAU6DhdoqJ5kYkTPhqNyz8sxdTijSytxNIoo4yFfZCbMpzhsjwTpkDZCbSVCHZALbkxZC0977Po18hDNAZD',
#  'token_type': 'bearer',
#  'expires_in': 1035491}

# %%
# Define URL
url = params['endpoint_base'] + params['instagram_account_id'] + '/media'

# Define Endpoint Parameters
endpointParams = dict()
endpointParams['fields'] = 'id,caption,media_type,media_url,permalink,thumbnail_url,timestamp,username,like_count,comments_count'
endpointParams['access_token'] = params['access_token']

# Requests Data
data = requests.get(url, endpointParams )
basic_insight = json.loads(data.content)
basic_insight

# %%
df = pd.DataFrame(basic_insight['data'])
df.columns = ['id', 'Caption', 'Media_Type', 'Media_URL', 'Permalink', 'Timestamp', 'Username', 'Likes', 'Comments', 'thumbnail_url']
df.head()
# Out:
#                   id                                            Caption  \
# 0  17952963872352371  @emanuelmino.xyz decided that the @@adidas Sup...
# 1  18048398167416176  Let the robot revolution happen...in style. 🤖 ...
# 2  17959713611264905  @logitech has dropped some fantastic-looking s...
# 3  17970470756070522  Fearing of your time running out? Well, @bored...
# 4  18074103715359109  Taekyung Kim and @designmu.co designed the Xii...
#
#        Media_Type                                          Media_URL  \
# 0  CAROUSEL_ALBUM  https://scontent-mia3-1.cdninstagram.com/v/t39...
# 1  CAROUSEL_ALBUM  https://scontent-mia3-1.cdninstagram.com/v/t39...
# 2           VIDEO  https://video-mia3-2.cdninstagram.com/o1/v/t16...
# 3  CAROUSEL_ALBUM  https://scontent-mia3-1.cdninstagram.com/v/t39...
# 4  CAROUSEL_ALBUM  https://scontent-mia3-2.cdninstagram.com/v/t39...
#
#                                      Permalink                 Timestamp  \
# 0     https://www.instagram.com/p/CqS92HjqlPO/  2023-03-27T14:50:46+0000
# 1     https://www.instagram.com/p/CqOLgjLqVil/  2023-03-25T18:13:57+0000
# 2  https://www.instagram.com/reel/CqOLASSoV66/  2023-03-25T18:09:56+0000
# 3     https://www.instagram.com/p/CqLRTy6q6kw/  2023-03-24T15:06:55+0000
# 4     https://www.instagram.com/p/CqI86OBoeJK/  2023-03-23T17:30:11+0000
#
#          Username  Likes  Comments  \
# 0  productminimal     96         1
# 1  productminimal    526         2
# 2  productminimal   2377        13
# 3  productminimal   1220         3
# 4  productminimal    618         4
#
#                                        thumbnail_url
# 0                                                NaN
# 1                                                NaN
# 2  https://scontent-mia3-2.cdninstagram.com/v/t51...
# 3                                                NaN
# 4                                                NaN

# %%
media_insight = []

# Loop Over 'Media ID'
for i in basic_insight['data']:
    if i['media_type'] == "CAROUSEL_ALBUM":
      params['latest_media_id'] = i['id']
      print(i)
      # Define URL
      url = params['endpoint_base'] + params['latest_media_id'] + '/insights'

      # Define Endpoint Parameters
      endpointParams = dict() 
      endpointParams['metric'] = 'engagement,impressions,reach,saved'
      endpointParams['access_token'] = params['access_token'] 

      # Requests Data
      data = requests.get(url, endpointParams )
      json_data = json.loads(data.content)
      media_insight.append(list(json_data['data']))
    else:
      None
# Out:
# {'id': '17952963872352371', 'caption': '@emanuelmino.xyz decided that the @@adidas Superstar needs a re-design with his personal touch - and he totally nailed it 🔥\n\nSome renders of the iconic Adidas Superstar shoes with transparent sides! Created with Blender and rendered with the powerful Octane Renderer. (personal project)\n\nThis design got submitted to our website - check out our link in bio if you also want to be featured! 🔥👀\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesign', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent-mia3-1.cdninstagram.com/v/t39.30808-6/338011131_585672580166815_8828289811258789220_n.jpg?_nc_cat=101&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=4UF1B47zuQcAX9kke-k&_nc_oc=AQlg1ySCWnsI4apC7fHzUn4k1z8_a9RG7iCtJztBGxez0vtC9sVqqyz6l9hyZD0O40g&_nc_ht=scontent-mia3-1.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_Af
n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent-mia3-2.cdninstagram.com/v/t39.30808-6/335863937_188067967267307_8751089545365122971_n.jpg?_nc_cat=105&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=m0EM7ognSOUAX8c2zI-&_nc_ht=scontent-mia3-2.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfArMwxyJHkroOZHFBB1SNAkWUu91LyKLHNVOJ2k4SGYKA&oe=6425E4C7', 'permalink': 'https://www.instagram.com/p/Cp0Le4fIoH-/', 'timestamp': '2023-03-15T15:53:28+0000', 'username': 'productminimal', 'like_count': 536, 'comments_count': 0}
# {'id': '18088720108323799', 'caption': 'Trailon, designed by @raakdesign, is a universal bike community trailer that easily attaches to any bicycle\n\nIt allows everyday cyclists to carry a larger load without having to buy an expensive cargo bike or trailer. Moreover, this sharing principle eliminates the problem of riding around with an empty cargo box. The layout and use of Trailon can be modularised in order to safely and responsibly transport your groceries, goods, children, etc.\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent-mia3-2.cdninstagram.com/v/t39.30808-6/335685755_1321803538378543_2924361849268776105_n.jpg?_nc_cat=110&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=pRBfnE9YzLQAX-EV-Rk&_nc_ht=scontent-mia3-2.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfC6HJ2Gb-8w1awLIuE5MXWBTqF5F6boIuCZ2WQ1VHsprA&oe=642622F9', 'permalink': 'https://www.instagram.com/p/Cp0AzecqnCC/', 'timestamp': '2023-03-15T14:20:10+0000', 'username': 'productminimal', 'like_count': 1270, 'comments_count': 8}
# {'id': '18211624453209533', 'caption': "@_yeounzoo created this concept with the main thought being: 'Clean the ocean again'. Definitely a serious matter and fantastic design, too!🔥\n\nThe increasing use of disposable products is increasing the use of wet wipes, and the resulting marine microplastic problem is becoming serious. Most wet wipes are used without realizing that they are plastic and not properly separated. Unrecycled wipes take 500 years to decompose in the ocean. It becomes microplastic in the process. This has the same ripple effect as dumping waste into the sea, so an alternative to this problem is urgently needed. Therefore, I propose the Re:clean project, which is a reusable tissue cleaner.\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner", 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent-mia3-2.cdninstagram.com/v/t39.30808-6/333572647_740303814356620_168101174483246508_n.jpg?_nc_cat=103&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=ZQ-FEurarEIAX9WmsVM&_nc_ht=scontent-mia3-2.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfDfkJ2ukREQsOzHEHGFvSSYLd5jtCEISJ8qrGwKCX06nw&oe=6425E065', 'permalink': 'https://www.instagram.com/p/Cpuul1Mqrqb/', 'timestamp': '2023-03-13T13:04:49+0000', 'username': 'productminimal', 'like_count': 364, 'comments_count': 5}
# {'id': '17968947896222793', 'caption': 'A mouse concept, inspired by stingrays, by @hrissshab\n\n"Mylio - Exploration of stingrays form and movement"\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent-mia3-2.cdninstagram.com/v/t39.30808-6/331774506_606110767612177_8638124856811531856_n.jpg?_nc_cat=110&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=6gVxSOZp7WMAX93EARg&_nc_ht=scontent-mia3-2.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfCsnBLH1FIyksBct6kn4eXnObcuASRzdSTe2pEwe6f1KQ&oe=64265640', 'permalink': 'https://www.instagram.com/p/CppzJKeKejF/', 'timestamp': '2023-03-11T15:08:23+0000', 'username': 'productminimal', 'like_count': 2357, 'comments_count': 13}
# {'id': '18037743274449850', 'caption': 'Argia is a Light Epilator concept by the talented @briceetempier \n\nArgia is an Intense Pulsed Light Epilator that I designed based on the legacy of Braun epilators following the design principles of Dieter Rams.\n“Past, present and future, Braun are designed to stand the test of life”\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent-mia3-2.cdninstagram.com/v/t39.30808-6/331518149_790274015763558_2026546354727816271_n.jpg?_nc_cat=107&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=5fJqd3XgXbUAX_72gLe&_nc_ht=scontent-mia3-2.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfBBsPJzXwnoPjWhxvULYOZdT6B1cPthf4TyhRQYT15qTA&oe=6425F521', 'permalink': 'https://www.instagram.com/p/CpnLsJSqE82/', 'timestamp': '2023-03-10T14:45:09+0000', 'username': 'productminimal', 'like_count': 1045, 'comments_count': 4}
# {'id': '17851607540936606', 'caption': 'ECO - designed by @lucapersico.design\n\nClassic electrolarynx are characterized by a sense of discomfort and unnaturalness in their use, but medical devices don’t necessarily have to be perceived with anxiety or shame by their user.\nEco is a wearable and handfree electrolarynx with a revolutionary user experience and an aesthetic close to tech products so as to be perceived as belonging to this category and not like a simple health device.\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent-mia3-2.cdninstagram.com/v/t39.30808-6/330441755_867207424572711_2348046563104120221_n.jpg?_nc_cat=109&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=7-eJJ-ZN9D8AX9OXhGm&_nc_ht=scontent-mia3-2.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfBoZFiRInt2VWO3TkvZ_B0jA8LBp1jhdrMl8FRRZzcB3g&oe=6425FBC7', 'permalink': 'https://www.instagram.com/p/Cpk2FIgqZEz/', 'timestamp': '2023-03-09T16:57:51+0000', 'username': 'productminimal', 'like_count': 563, 'comments_count': 3}
# {'id': '17981287018962901', 'caption': '@nike says "JUST DO IT" and @design_byungjun just did that (😉). The glasses seen here are named AIR BOOST and are a Sports Mask concept design, combined with the well known nike brand identity and whoosh!\n\nIt\'s a sports electronic mask design that replenishes oxygen and helps you breathe in aerobic exercise.\n\nContinue to circulate clean air and supply oxygen from oxygen capsules as needed.\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent-mia3-2.cdninstagram.com/v/t39.30808-6/330292836_596455435381366_5395092653105098362_n.jpg?_nc_cat=102&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=44YUxmg6WIsAX9lu9Md&_nc_ht=scontent-mia3-2.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfCIvgc0oxZ54dpCIxYTMCKJ_xYRxqFcLqdfEDUfPFhrAg&oe=642632CA', 'permalink': 'https://www.instagram.com/p/CpiFpTwqRwE/', 'timestamp': '2023-03-08T15:16:08+0000', 'username': 'productminimal', 'like_count': 446, 'comments_count': 0}
# {'id': '17963414582152894', 'caption': '@alvaro____navarro created these selected images and showcases some detials of his work with @akqa and @volvocars \n\n"Working with one of the best teams ever, we created a full CGI campaign in collaboration with @akqa and @volvocars. Watch the full project on behance and mvsm.com. Here’s some design explorations done @man.vs.machine" \n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent-mia3-1.cdninstagram.com/v/t39.30808-6/333022439_1053094746093460_4093245907380739614_n.jpg?_nc_cat=108&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=OlKfy_4G-SEAX9EIJgA&_nc_ht=scontent-mia3-1.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfDYXdjxTDg8Mjz3WEdcpKMUGqV2OjLmh677pVyj7hTX3w&oe=64279D26', 'permalink': 'https://www.instagram.com/p/CpfqlwGKDKz/', 'timestamp': '2023-03-07T16:41:14+0000', 'username': 'productminimal', 'like_count': 2869, 'comments_count': 4}
# {'id': '18041294797426138', 'caption': '@moonshake3d is working on a fantastic VR setup, in which not only the exterior is looking good 👀\n\nFeel the freedom of wireless technology with the new untethered controllers for the Stereoscopic Display System.\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent-mia3-2.cdninstagram.com/v/t39.30808-6/332708717_1413181729218270_385436871323482662_n.jpg?_nc_cat=102&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=NvIx1BIhn2AAX-Qe3JD&_nc_ht=scontent-mia3-2.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfB_8WTv5GJ2t4OnmPRL8jh6Ip1nyi-mH3Fa9OuifzS8OQ&oe=64276C36', 'permalink': 'https://www.instagram.com/p/CpdOfVLq2eT/', 'timestamp': '2023-03-06T17:57:13+0000', 'username': 'productminimal', 'like_count': 1517, 'comments_count': 7}

# %%
# Initialize Empty Container
engagement_list = []
impressions_list = []
reach_list = []
saved_list = []

# Loop Over Insights to Fill Container
for insight in media_insight:
    engagement_list.append(insight[0]['values'][0]['value'])
    impressions_list.append(insight[1]['values'][0]['value'])
    reach_list.append(insight[2]['values'][0]['value'])
    saved_list.append(insight[3]['values'][0]['value'])
    
# Create DataFrame
df_media_insight = pd.DataFrame(list(zip(engagement_list, impressions_list, reach_list, saved_list)), columns =['Engagement', 'Impressions', 'Reach', 'Saved'])
df_media_insight
# Out:
#     Engagement  Impressions  Reach  Saved
# 0          108         2286   2184     10
# 1          623        12262  10079     95
# 2         1528        25569  22269    304
# 3          783        15472  13274    161
# 4         1703        23641  20115    251
# 5         1130        16607  13384    194
# 6         1235        23287  19666    178
# 7         4534        39988  33680    999
# 8         1855        32218  29800    428
# 9         1139        17066  14283    181
# 10         611         9617   7796     75
# 11        1591        25349  20748    313
# 12         421        12882  10549     52
# 13        2935        33607  27028    565
# 14        1272        19224  16046    223
# 15         684        13753  11231    118
# 16         516        11570   9067     70
# 17        3587        42592  34877    714
# 18        1890        25982  21663    366

# %%
# Define URL
url = params['endpoint_base'] + params['instagram_account_id'] + '/insights'

# Define Endpoint Parameters
endpointParams = dict()
endpointParams['metric'] = 'audience_city,audience_country,audience_gender_age' 
endpointParams['period'] = 'lifetime' 
endpointParams['access_token'] = params['access_token'] 

# Requests Data
data = requests.get(url, endpointParams )
audience_insight = json.loads(data.content)
audience_insight
# Out:
# {'data': [{'name': 'audience_city',
#    'period': 'lifetime',
#    'values': [{'value': {'Sydney, New South Wales': 299,
#       'London, England': 748,
#       'São Paulo, São Paulo (state)': 513,
#       'Barcelona, Cataluña': 289,
#       'Hong Kong, Hong Kong': 523,
#       'Berlin, Berlin': 372,
#       'Karaj, Tehran Province': 314,
#       'Kyiv, Kyiv': 271,
#       'Lagos, Lagos State': 346,
#       'Seoul, Seoul': 1416,
#       'Pune, Maharashtra': 289,
#       'Ahmedabad, Gujarat': 276,
#       'Moscow, Moscow': 703,
#       'Bogotá, Distrito Especial': 570,
#       'Jakarta, Jakarta': 892,
#       'Paris, Île-de-France': 369,
#       'Buenos Aires, Ciudad Autónoma de Buenos Aires': 500,
#       'Taipei, Taipei': 568,
#       'Ho Chi Minh City, Ho Chi Minh City': 379,
#       'Xinbei, New Taipei City': 449,
#       'Shanghai, Shanghai': 2028,
#       'Melbourne, Victoria': 411,
#       'Delhi, Delhi': 482,
#       'Los Angeles, California': 324,
#       'Madrid, Comunidad de Madrid': 312,
#       'Lima, Lima Region': 266,
#       'Istanbul, Istanbul Province': 1783,
#       'Rome, Lazio': 255,
#       'Toronto, Ontario': 256,
#       'Chennai, Tamil Nadu': 336,
#       'Ankara, Ankara Province': 267,
#       'Milan, Lombardia': 414,
#       'Bangkok, Bangkok': 629,
#       'Mexico City, Distrito Federal': 771,
#       'Riyadh, Riyadh Region': 317,
#       'Saint Petersburg, Saint Petersburg': 309,
#       'New York, New York': 556,
#       'Tehran, Tehran Province': 2732,
#       'Cairo, Cairo Governorate': 360,
#       'Dubai, Dubai': 377,
#       'Santiago, Santiago Metropolitan Region': 434,
#       'Mumbai, Maharashtra': 593,
#       'Bangalore, Karnataka': 812,
#       'Singapore, Singapore': 401,
#       'Tashkent, Tashkent Region': 400}}],
#    'title': 'Stadt der Zielgruppe',
#    'description': 'Städte der Follower dieses Profils',
#    'id': '17841447229527043/insights/audience_city/lifetime'},
#   {'name': 'audience_country',
#    'period': 'lifetime',
#    'values': [{'value': {'DE': 2590,
#       'BE': 429,
#       'HK': 524,
#       'TW': 1743,
#       'RU': 2176,
#       'PT': 672,
#       'JP': 1195,
#       'UA': 817,
#       'FR': 2172,
#       'SA': 719,
#       'BR': 2750,
#       'SE': 567,
#       'MA': 424,
#       'ID': 2888,
#       'GB': 2916,
#       'CA': 1339,
#       'US': 6892,
#       'EG': 766,
#       'IL': 413,
#       'AE': 583,
#       'CH': 469,
#       'UZ': 530,
#       'IN': 7240,
#       'ZA': 593,
#       'KR': 2879,
#       'IQ': 433,
#       'CL': 661,
#       'IR': 5442,
#       'CN': 2296,
#       'MX': 2599,
#       'IT': 3469,
#       'MY': 752,
#       'CO': 1216,
#       'ES': 1939,
#       'KZ': 416,
#       'AR': 1774,
#       'TH': 970,
#       'AU': 1096,
#       'PH': 448,
#       'VN': 576,
#       'NG': 661,
#       'PK': 693,
#       'PL': 714,
#       'NL': 756,
#       'TR': 3430}}],
#    'title': 'Land der Zielgruppe',
#    'description': 'Länder der Follower dieses Profils',
#    'id': '17841447229527043/insights/audience_country/lifetime'},
#   {'name': 'audience_gender_age',
#    'period': 'lifetime',
#    'values': [{'value': {'F.13-17': 97,
#       'F.18-24': 2890,
#       'F.25-34': 3383,
#       'F.35-44': 1185,
#       'F.45-54': 367,
#       'F.55-64': 122,
#       'F.65+': 79,
#       'M.13-17': 607,
#       'M.18-24': 11827,
#       'M.25-34': 24788,
#       'M.35-44': 12618,
#       'M.45-54': 3800,
#       'M.55-64': 849,
#       'M.65+': 596,
#       'U.13-17': 602,
#       'U.18-24': 6898,
#       'U.25-34': 8121,
#       'U.35-44': 4162,
#       'U.45-54': 1452,
#       'U.55-64': 408,
#       'U.65+': 326}}],
#    'title': 'Geschlecht und Alter',
#    'description': 'Geschlecht und Alter der Follower dieses Profils',
#    'id': '17841447229527043/insights/audience_gender_age/lifetime'}]}

# %%
#The variables that I search for

audience_city = []
audience_country = []
audience_genderage = []


#Variables for Country
country_short = []
country_number = []

#Variables for City
city_name = []
region_name = []
city_number = []

#Variables for Age and Gender
gender = []
age_bracket = []
age_number = []

for i in audience_insight["data"]:
    if i['name'] == "audience_country":
      for x in i['values']:
        for z in x["value"]:
          country_short.append(z)
          country_number.append(x['value'][z])
    if i['name'] == "audience_city":
      for x in i['values']:
        for z in x["value"]:
          xy = z.split(", ")
          city_name.append(xy[0])
          region_name.append(xy[1])
          city_number.append(x['value'][z])
    if i['name'] == "audience_gender_age":
      for x in i['values']:
        for z in x["value"]:
          gender_age_split = z.split(".")
          gender.append(gender_age_split[0])
          age_bracket.append(gender_age_split[1])
          age_number.append(x['value'][z])



audience_country = pd.DataFrame(list(zip(country_short, country_number)), columns =['Country_ID', 'Count'])
audience_city = pd.DataFrame(list(zip(city_name, region_name, city_number)), columns =['City', 'Region', 'Count'])
audience_genderage = pd.DataFrame(list(zip(gender, age_bracket, age_number)), columns =['Gender', 'Age Bracket', 'Count'])

#audience_country
#audience_city
audience_city = audience_city.sort_values(by = ['Count'],ascending=False)
audience_country = audience_country.sort_values(by = ['Count'],ascending=False)
audience_genderage = audience_genderage.sort_values(by = ['Count'],ascending=False)

audience_country
# Out:
#    Country_ID  Count
# 22         IN   7240
# 16         US   6892
# 27         IR   5442
# 30         IT   3469
# 44         TR   3430
# 14         GB   2916
# 13         ID   2888
# 24         KR   2879
# 10         BR   2750
# 29         MX   2599
# 0          DE   2590
# 28         CN   2296
# 4          RU   2176
# 8          FR   2172
# 33         ES   1939
# 35         AR   1774
# 3          TW   1743
# 15         CA   1339
# 32         CO   1216
# 6          JP   1195
# 37         AU   1096
# 36         TH    970
# 7          UA    817
# 17         EG    766
# 43         NL    756
# 31         MY    752
# 9          SA    719
# 42         PL    714
# 41         PK    693
# 5          PT    672
# 26         CL    661
# 40         NG    661
# 23         ZA    593
# 19         AE    583
# 39         VN    576
# 11         SE    567
# 21         UZ    530
# 2          HK    524
# 20         CH    469
# 38         PH    448
# 25         IQ    433
# 1          BE    429
# 12         MA    424
# 34         KZ    416
# 18         IL    413

# %%
# !pip install country_converter --upgrade
# !pip install pycountry
import country_converter as coco
import pycountry

country_dict = {country.alpha_2: country.name for country in pycountry.countries}
audience_country['Country'] = audience_country_test['Country_ID'].map(country_dict)
audience_country = audience_country.reindex(columns=['Country', 'Country_ID', 'Count'])
audience_country
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: country_converter in /usr/local/lib/python3.9/dist-packages (1.0.0)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.9/dist-packages (from country_converter) (1.4.4)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0->country_converter) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0->country_converter) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0->country_converter) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas>=1.0->country_converter) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pycountry
#   Downloading pycountry-22.3.5.tar.gz (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 52.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from pycountry) (67.6.0)
# Building wheels for collected packages: pycountry
#   Building wheel for pycountry (pyproject.toml) ... done
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681847 sha256=fbbe0c2b4a44d6d911f6739c0fccf346ae4a06a56326eaf26b6c311976fac98d
#   Stored in directory: /root/.cache/pip/wheels/47/15/92/e6dc85fcb0686c82e1edbcfdf80cfe4808c058813fed0baa8f
# Successfully built pycountry
# Installing collected packages: pycountry
# Successfully installed pycountry-22.3.5

# %%
audience_country
# Out:
#                       Country Country_ID  Count
# 22                      India         IN   7240
# 16              United States         US   6892
# 27  Iran, Islamic Republic of         IR   5442
# 30                      Italy         IT   3469
# 44                     Turkey         TR   3430
# 14             United Kingdom         GB   2916
# 13                  Indonesia         ID   2888
# 24         Korea, Republic of         KR   2879
# 10                     Brazil         BR   2750
# 29                     Mexico         MX   2599
# 0                     Germany         DE   2590
# 28                      China         CN   2296
# 4          Russian Federation         RU   2176
# 8                      France         FR   2172
# 33                      Spain         ES   1939
# 35                  Argentina         AR   1774
# 3   Taiwan, Province of China         TW   1743
# 15                     Canada         CA   1339
# 32                   Colombia         CO   1216
# 6                       Japan         JP   1195
# 37                  Australia         AU   1096
# 36                   Thailand         TH    970
# 7                     Ukraine         UA    817
# 17                      Egypt         EG    766
# 43                Netherlands         NL    756
# 31                   Malaysia         MY    752
# 9                Saudi Arabia         SA    719
# 42                     Poland         PL    714
# 41                   Pakistan         PK    693
# 5                    Portugal         PT    672
# 26                      Chile         CL    661
# 40                    Nigeria         NG    661
# 23               South Africa         ZA    593
# 19       United Arab Emirates         AE    583
# 39                   Viet Nam         VN    576
# 11                     Sweden         SE    567
# 21                 Uzbekistan         UZ    530
# 2                   Hong Kong         HK    524
# 20                Switzerland         CH    469
# 38                Philippines         PH    448
# 25                       Iraq         IQ    433
# 1                     Belgium         BE    429
# 12                    Morocco         MA    424
# 34                 Kazakhstan         KZ    416
# 18                     Israel         IL    413

# %%
import pandas as pd
from datetime import datetime

# generate timestamp string for filename
timestamp_str = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# set the name of the CSV file to include the timestamp
filename = f"country_{timestamp_str}.csv"

# save the dataframe as a CSV file
audience_country.to_csv(filename, index=False)
