# %% [markdown]
# <a href="https://colab.research.google.com/github/premstaller1/instagram-graph-api/blob/main/instagram_graph_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# # Als Code formatiert
# ```
#
# # Lets do some Coding

# %% [markdown]
# ```
# # Als Code formatiert
# ```
#
# # Get the Access to our API

# %%
# Import Libraries
import requests
import json
import datetime
import pandas as pd

# Define Parameters Dictionary
params = dict()
params['access_token'] = 'EAAG24jaJaYIBAIr6BRiA2dvrC7ppqbyFvvnZB64ZAZChVRXkGU6ZAF5TXZAoWGSvI5SU3S4tZA7RXDDbl18KJX1j833wmISzUMpZB3BvlW6npImwE9zOtzcsX9AyeFFl4AYwaUzGnuAI3XFTSl5PbrLTCAVYZCPq5ZBdtQcgcyllT0GG6IuHGHq0h'        # not an actual access token
params['client_id'] = '482557670549890'                  
params['client_secret'] = 'd62937e7f31973871d86b8242430b73e'     
params['graph_domain'] = 'https://graph.facebook.com'
params['graph_version'] = 'v16.0'
params['endpoint_base'] = params['graph_domain'] + '/' + params['graph_version'] + '/'
params['page_id'] = '482557670549890'                  
params['instagram_account_id'] = '17841447229527043'
params['ig_username'] = 'productminimal'

# Define Endpoint Parameters
endpointParams = dict()
endpointParams['input_token'] = params['access_token']
endpointParams['access_token'] = params['access_token']

# Define URL
url = params['graph_domain'] + '/debug_token'

# Requests Data
data = requests.get(url, endpointParams)
access_token_data = json.loads(data.content)
access_token_data
# Out:
# {'data': {'app_id': '482557670549890',
#   'type': 'USER',
#   'application': 'get.data',
#   'data_access_expires_at': 1688920215,
#   'expires_at': 1688825038,
#   'is_valid': True,
#   'issued_at': 1683641038,
#   'scopes': ['pages_show_list',
#    'instagram_basic',
#    'instagram_manage_insights',
#    'instagram_content_publish',
#    'pages_read_engagement',
#    'pages_manage_metadata',
#    'pages_manage_posts'],
#   'granular_scopes': [{'scope': 'pages_show_list',
#     'target_ids': ['697408977005943',
#      '117333094565741',
#      '115892009794535',
#      '114800188149572',
#      '107094705179146']},
#    {'scope': 'instagram_basic',
#     'target_ids': ['17841457334539061',
#      '17841457091187806',
#      '17841447229527043',
#      '17841419699397187',
#      '17841405953014103']},
#    {'scope': 'instagram_manage_insights',
#     'target_ids': ['17841457334539061',
#      '17841457091187806',
#      '17841447229527043',
#      '17841419699397187',
#      '17841405953014103']},
#    {'scope': 'instagram_content_publish',
#     'target_ids': ['17841457334539061',
#      '17841457091187806',
#      '17841447229527043',
#      '17841419699397187',
#      '17841405953014103']},
#    {'scope': 'pages_read_engagement',
#     'target_ids': ['697408977005943',
#      '117333094565741',
#      '115892009794535',
#      '114800188149572',
#      '107094705179146']},
#    {'scope': 'pages_manage_metadata',
#     'target_ids': ['697408977005943',
#      '117333094565741',
#      '115892009794535',
#      '114800188149572',
#      '107094705179146']},
#    {'scope': 'pages_manage_posts',
#     'target_ids': ['697408977005943',
#      '117333094565741',
#      '115892009794535',
#      '114800188149572',
#      '107094705179146']}],
#   'user_id': '991919581778381'}}

# %% [markdown]
# ## Creating a long lasting token

# %%
print("Token Expires: ", datetime.datetime.fromtimestamp(access_token_data['data']['expires_at']))
# Out:
# Token Expires:  2023-07-08 14:03:58

# %%
# Define URL
url = params['endpoint_base'] + 'oauth/access_token'

# Define Endpoint Parameters
endpointParams = dict() 
endpointParams['grant_type'] = 'fb_exchange_token'
endpointParams['client_id'] = params['client_id']
endpointParams['client_secret'] = params['client_secret']
endpointParams['fb_exchange_token'] = params['access_token']

# Requests Data
data = requests.get(url, endpointParams )
long_lived_token = json.loads(data.content)
long_lived_token
# Out:
# {'access_token': 'EAAG24jaJaYIBAIr6BRiA2dvrC7ppqbyFvvnZB64ZAZChVRXkGU6ZAF5TXZAoWGSvI5SU3S4tZA7RXDDbl18KJX1j833wmISzUMpZB3BvlW6npImwE9zOtzcsX9AyeFFl4AYwaUzGnuAI3XFTSl5PbrLTCAVYZCPq5ZBdtQcgcyllT0GG6IuHGHq0h',
#  'token_type': 'bearer',
#  'expires_in': 5184000}

# %% [markdown]
# # First try to get some image data

# %%
# Define URL
url = params['endpoint_base'] + params['instagram_account_id'] + '/media'

# Define Endpoint Parameters
endpointParams = dict()
endpointParams['fields'] = 'id,caption,media_type,media_url,permalink,thumbnail_url,timestamp,username,like_count,comments_count'
endpointParams['access_token'] = params['access_token']

# Requests Data
data = requests.get(url, endpointParams )
basic_insight = json.loads(data.content)
basic_insight
# Out:
# {'data': [{'id': '17909947517755871',
#    'caption': 'Explore the recent @blender.official project by @harryibzdesign 🔥\n\nLearning is a slow but a rewarding process and harry is perfectly demonstrating this here: "I’ve been learning Blender recently to improve my topology workflow when poly modelling. Still learning, but really enjoying it, more to come on this…"\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent-ord5-1.cdninstagram.com/v/t39.30808-6/345622025_239704598736691_9074636169292671434_n.jpg?_nc_cat=109&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=bQvvqrKdu0cAX8h_Aj3&_nc_ht=scontent-ord5-1.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfB1mHC3Bm79_HY_w37C5AS-s4jIzmxmnd2Dl2sBm-cjXw&oe=645EFCC9',
#    'permalink': 'https://www.instagram.com/p/Cr_LTUJKgqG/',
#    'timestamp': '2023-05-08T15:26:20+0000',
#    'username': 'productminimal',
#    'like_count': 503,
#    'comments_count': 3},
#   {'id': '17975672708217381',
#    'caption': 'Magnificant unboxing by @oliursvisuals fir this similar fantastic looking keyboard from @melgeek_official 🔥\n\nThey definitely nailed the “unboxing experience”! 📦 \n\n______\n\nDiscover more on @productminimal \n\n#keyboard #keyboarddesign #desksetup #unboxing #techdesign #productsdesign #productminimal',
#    'media_type': 'VIDEO',
#    'media_url': 'https://scontent-ord5-2.cdninstagram.com/o1/v/t16/f1/m82/33467B03BD513B2E77E382A15B7B7398_video_dashinit.mp4?efg=eyJ2ZW5jb2RlX3RhZyI6InZ0c192b2RfdXJsZ2VuLjcyMC5jbGlwcyJ9&_nc_ht=scontent-ord5-2.cdninstagram.com&_nc_cat=108&vs=787478295989791_1058609865&_nc_vs=%3D%3D&ccb=9-4&oh=00_AfAGZgV6DN7o9ki2HLPU0a-qZbvpG7mgHI2J3usmlSA-4g&oe=645BE85D&_nc_sid=ea0b6e&_nc_rid=4276d43882',
#    'permalink': 'https://www.instagram.com/reel/Cr9MQJiIm_L/',
#    'thumbnail_url': 'https://scontent-ord5-2.cdninstagram.com/v/t51.36329-15/345046740_6772956566052615_4212084979490962114_n.jpg?_nc_cat=105&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=kF1V02HdjRIAX_NISZC&_nc_ht=scontent-ord5-2.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfBCvm7Bwz6sNvX4If9UoeYT9pZC3Xe6cQywVAwQT289Ag&oe=645ED8D4',
#    'timestamp': '2023-05-07T20:58:05+0000',
#    'username': 'productminimal',
#    'like_count': 2401,
#    'comments_count': 13},
#   {'id': '18008280769630676',
#    'caption': 'Clean silver - reminds me of the F1 McLaren in 2008 with the silver and red details. You can see here the MNL MK-I, a Premium Film Camera Concept designed by the well-known and talented @acasso_official\u2063\u2063 for Manual NYC\n\n@manual_nyc  is a photography company based in New York that specializes in analogue photography. Unlike most modern camera brands that focus exclusively on digital photography, Manual is dedicated to film photography and has its own lineup of films and reusable film cameras. The high demand for the analogue taste of their film photography in fashion and social media has led them to collaborate with globally renowned brands such as Nike. In 2021, Manual approached us to design an iconic camera to enhance their product line.\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent-ord5-2.cdninstagram.com/v/t39.30808-6/345451210_623191276519707_496282433299896223_n.jpg?_nc_cat=102&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=u54PzBuA9PUAX-7qy3B&_nc_ht=scontent-ord5-2.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfB52sAT-EjuZ55gN8HM2UKoeTi2GPZwDujZ5WrMw8SGgQ&oe=645E5C09',
#    'permalink': 'https://www.instagram.com/p/Cr55ADToQx6/',
#    'timestamp': '2023-05-06T14:10:12+0000',
#    'username': 'productminimal',
#    'like_count': 3016,
#    'comments_count': 13},
#   {'id': '18175144231287171',
#    'caption': 'You can have different opinions about @teslamotors - but their interior just looks great and sticks out!\n\nVideo by @trackslayers',
#    'media_type': 'VIDEO',
#    'media_url': 'https://scontent-ord5-2.cdninstagram.com/o1/v/t16/f1/m82/4E49B2D6B3EE6D8CE914B9F6B86935A4_video_dashinit.mp4?efg=eyJ2ZW5jb2RlX3RhZyI6InZ0c192b2RfdXJsZ2VuLjcyMC5jbGlwcyJ9&_nc_ht=scontent-ord5-2.cdninstagram.com&_nc_cat=100&vs=943788437072011_4119743128&_nc_vs=%3D%3D&ccb=9-4&oh=00_AfDon2dC_C_ddtPALe8_F2lQqFmBqD6sfiT1LEgqlGCSlQ&oe=645BFC6B&_nc_sid=ea0b6e&_nc_rid=0dd84460c3',
#    'permalink': 'https://www.instagram.com/reel/Cr3kT9ToSRl/',
#    'thumbnail_url': 'https://scontent-ord5-2.cdninstagram.com/v/t51.36329-15/345052337_785157936425024_2508019666891676186_n.jpg?_nc_cat=110&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=OYT3CPzEKNQAX9jqf1i&_nc_ht=scontent-ord5-2.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfBxxMhjHmNVn__xfvxxG5-NgbNguPlmp_genbj0rC1AQA&oe=645FF327',
#    'timestamp': '2023-05-05T16:31:42+0000',
#    'username': 'productminimal',
#    'like_count': 971,
#    'comments_count': 16},
#   {'id': '18187056487253958',
#    'caption': "As part of an ongoing collaboration between me and @inktank.academy, I also wanted to share with you the possibility to share your work and portfolio on their website to get feedback from experienced designers!\n\nI'm also going to stroll through the shared designs on their platform to occasionally pick some designs to share on here - so take a look, they have offers for both experienced designers and beginners 💡👀\n\nYou can find the link to their website in my bio!\n\n___________\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner",
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent-ord5-2.cdninstagram.com/v/t39.30808-6/345156268_201203685687000_5784977349248684459_n.jpg?_nc_cat=102&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=enSTHo5sslEAX99LjaF&_nc_ht=scontent-ord5-2.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfBOF86YPgqwm_vJ8KsWMDqHozWLLy3osWzohixOQZngBQ&oe=645FC22A',
#    'permalink': 'https://www.instagram.com/p/Cr23jK3qccH/',
#    'timestamp': '2023-05-05T09:59:48+0000',
#    'username': 'productminimal',
#    'like_count': 101,
#    'comments_count': 0},
#   {'id': '17996204701888805',
#    'caption': '@matdilisio with his stunning new Mechanical Keyboard by @modekeyboards 😭\n\nThere should be an extended YouTube video about it on his channel, so take a look at his profile! \n\n_________________\n\nDiscover more on @productminimal\n\n#keyboard #mechanicalkeyboard #mechanicalkeyboards #unboxing #asmr #deskaccessories #desksetup #homeoffice #office #workfromhome #setup #homestudio #workspace #workstation',
#    'media_type': 'VIDEO',
#    'media_url': 'https://scontent-ord5-2.cdninstagram.com/o1/v/t16/f1/m82/824020F7ADCA4B8680C922D9B4031DB3_video_dashinit.mp4?efg=eyJ2ZW5jb2RlX3RhZyI6InZ0c192b2RfdXJsZ2VuLjcyMC5jbGlwcyJ9&_nc_ht=scontent-ord5-2.cdninstagram.com&_nc_cat=105&vs=1588697094972080_3034243080&_nc_vs=%3D%3D&ccb=9-4&oh=00_AfANj6FLC3Wkvh1-9v-E-of4RGQl18PyzIG7AdZmLcgs2Q&oe=645BB970&_nc_sid=ea0b6e&_nc_rid=236b2ff34b',
#    'permalink': 'https://www.instagram.com/reel/Cr0yzbyoYlV/',
#    'thumbnail_url': 'https://scontent-ord5-2.cdninstagram.com/v/t51.36329-15/344595905_1396360577816516_2615205395468491092_n.jpg?_nc_cat=100&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=Lpn_pmk52SkAX9m8Rwt&_nc_ht=scontent-ord5-2.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfBx4jD0iyPnucjJZynztl3dhd9-pY5YasrAzgIDkMaLng&oe=645E6E27',
#    'timestamp': '2023-05-04T14:40:03+0000',
#    'username': 'productminimal',
#    'like_count': 893,
#    'comments_count': 9},
#   {'id': '18265650850183643',
#    'caption': 'Lumia by @mm_products_and_doodles / @matteovilardostudio\n\nLUMIA is a brand new web-based HMI modular system that allows customers to choose among many electronic package solutions to attach to different display size.\nLUMIA family is divided into CABIN PANEL and VESA ARM mounting, both thought as modular system to give extreme personalization based on customer needs\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent-ord5-1.cdninstagram.com/v/t39.30808-6/344821027_2428664713955020_2581272817949503493_n.jpg?_nc_cat=108&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=sBQIAyxgbhYAX9XNXq-&_nc_ht=scontent-ord5-1.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfBE42jTzbb1kdRAmhyob3HrcJFk2xIbm4LEMlOwOzTn4Q&oe=645FA9FD',
#    'permalink': 'https://www.instagram.com/p/CryjAHpKAuh/',
#    'timestamp': '2023-05-03T17:43:18+0000',
#    'username': 'productminimal',
#    'like_count': 272,
#    'comments_count': 3},
#   {'id': '17860867289937524',
#    'caption': '@denis___zhuravlev is not only father and traveller, he also creates some stunning designs for Nevs - an automotive company based in Stockholm, Sweden 🔥 \n\nIn this slidedeck you can explore the interior of the Emily GT - their recently shared new car. " I joined #Nevs team where we worked together at the highest pace. Sleepless nights and great team effort to build emily from the sketch to several running prototypes in just 8 months while the design process took only 5 months. Finally can share it today!"\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent-ord5-1.cdninstagram.com/v/t39.30808-6/344743743_780088763424963_5145686029768258844_n.jpg?_nc_cat=108&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=J2w0vZl8guUAX_H0_On&_nc_ht=scontent-ord5-1.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfB12PFbgNU54smi9YGx64fyrekMTaN3iNsa_TRUjZ7yOQ&oe=645FFCB8',
#    'permalink': 'https://www.instagram.com/p/CrwCiloqOSw/',
#    'timestamp': '2023-05-02T18:21:10+0000',
#    'username': 'productminimal',
#    'like_count': 349,
#    'comments_count': 2},
#   {'id': '17953806527404984',
#    'caption': 'The Mercedes-Benz Avatar inspired concept car, ‚VISION AVTR‘ - a view into the future 🔥\n\n____\n\nDiscover more on @productminimal 🔥\n\n#cardesign #evcars #technologydesign',
#    'media_type': 'VIDEO',
#    'media_url': 'https://scontent-ord5-2.cdninstagram.com/o1/v/t16/f1/m82/78408C9D56454B38A061243C67E23B83_video_dashinit.mp4?efg=eyJ2ZW5jb2RlX3RhZyI6InZ0c192b2RfdXJsZ2VuLjcyMC5jbGlwcyJ9&_nc_ht=scontent-ord5-2.cdninstagram.com&_nc_cat=101&vs=186279987215599_3763163547&_nc_vs=%3D%3D&ccb=9-4&oh=00_AfBtIXkVcEznWGGWSHTzuSp4VYlLILiPDj2j8F9dvrmhaw&oe=645BE8F1&_nc_sid=ea0b6e&_nc_rid=bea9213ae3',
#    'permalink': 'https://www.instagram.com/reel/CrtG_7VIDCR/',
#    'thumbnail_url': 'https://scontent-ord5-1.cdninstagram.com/v/t51.36329-15/343980848_725791749550070_7584146074410378440_n.jpg?_nc_cat=101&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=Ok7QTNLD9iQAX8mfjbr&_nc_ht=scontent-ord5-1.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfDvySQdLbhxktROQI1h4CkvZj2N-ep7GTrOaohSu-DB1Q&oe=645F83B2',
#    'timestamp': '2023-05-01T15:58:10+0000',
#    'username': 'productminimal',
#    'like_count': 492,
#    'comments_count': 4},
#   {'id': '17994446260820097',
#    'caption': 'The beauty of creating something with your own hands captured in this drill - and digitzed😉🔥This is the Xiaomi Electric Drill designed by @hoto_official for @xiaomi.global \n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent-ord5-1.cdninstagram.com/v/t39.30808-6/344539993_6535548036465663_3104742384559729181_n.jpg?_nc_cat=108&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=Jw9i7SEwjt8AX8vYM46&_nc_ht=scontent-ord5-1.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfDFd015ijolSTUAZOtiTX9xRQoH5l6BETy7oQFcNDqZNg&oe=645FF746',
#    'permalink': 'https://www.instagram.com/p/CrqTW02KFO1/',
#    'timestamp': '2023-04-30T12:52:40+0000',
#    'username': 'productminimal',
#    'like_count': 2433,
#    'comments_count': 15},
#   {'id': '17973253832245873',
#    'caption': 'Fashionable controller 🎮🕹️ Perfect Accessoire for fashion week 😉\n\nWork by @superdesigners.co 🔥\n\n_____\n\nDiscover more on @productminimal 🔥⛈️\n\n#productsdesign #designerstuff #fashiongaming #controler #gamingstuff #designstudy #gamedesign #products #render',
#    'media_type': 'VIDEO',
#    'media_url': 'https://scontent-ord5-2.cdninstagram.com/o1/v/t16/f1/m82/1A4870CEDA4E91294BF4C599BEA786A8_video_dashinit.mp4?efg=eyJ2ZW5jb2RlX3RhZyI6InZ0c192b2RfdXJsZ2VuLjcyMC5jbGlwcyJ9&_nc_ht=scontent-ord5-2.cdninstagram.com&_nc_cat=103&vs=188494073623685_1192649414&_nc_vs=%3D%3D&ccb=9-4&oh=00_AfC89YUruS7EBYViRgG2_jbpyk9UfqJwKDcWmepD7O-t1A&oe=645C1F21&_nc_sid=ea0b6e&_nc_rid=8edb9f0eac',
#    'permalink': 'https://www.instagram.com/reel/CroJJbCIJ83/',
#    'thumbnail_url': 'https://scontent-ord5-1.cdninstagram.com/v/t51.36329-15/343585494_156320694060773_5500594386081621521_n.jpg?_nc_cat=101&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=RaZi9lR34bwAX9dVDUc&_nc_ht=scontent-ord5-1.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfAL0TI260oUpsfIIBoyefnyhoi3S-OJZJ_wuzAw06VHLQ&oe=645FC5B5',
#    'timestamp': '2023-04-29T16:46:30+0000',
#    'username': 'productminimal',
#    'like_count': 945,
#    'comments_count': 10},
#   {'id': '18266609611124685',
#    'caption': "Just recently I got in contact with @inktank.academy and thought it would be a great opportunity to share with you since many are still students or are trying to enter the industry :) \n\nThey offer free online courses for designers and considering that a lot of you are still students, this might be a good way to get into it and start designing staff (and share it on @productminimal 😉)\n\nOn their website, you'll also have the opportunity to share your work/portfolio as part of a platform/social network for designers, reach new people, and maybe also find someone to collaborate with in the future 👀\n\nFor more information you can check out the link in my bio, we've tagged their website there!\n\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesign",
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent-ord5-2.cdninstagram.com/v/t39.30808-6/343947498_6139420089485807_7003979519010646898_n.jpg?_nc_cat=105&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=ITpILYNNvoAAX8Htr2m&_nc_ht=scontent-ord5-2.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfBgJbrk_yHxAqsbrviTetKET_w6UN-rWpkLvYJRCk73dg&oe=645F4EC7',
#    'permalink': 'https://www.instagram.com/p/CrnofieqOZs/',
#    'timestamp': '2023-04-29T11:59:38+0000',
#    'username': 'productminimal',
#    'like_count': 125,
#    'comments_count': 4},
#   {'id': '18220813357169965',
#    'caption': '@medium2studio on his way to make a seemingly uninteresting object stand out in your office - the Ruler_C 😉\n\nRuler_C is a uniquely designed ruler that offers both practicality and style. Its curved shape allows for easy gripping and minimizes contact with the paper, preventing contamination and accidental smudging. Made from durable anodized aluminum alloy, Ruler_C not only withstands everyday use but also adds a touch of sophistication to any workspace with its sleek and modern appearance. It is a chic choice for those who appreciate well-designed tools that effortlessly combine form and function in a subtle and refined manner.\n\nThis design got submitted to our website - check out our link in bio if you also want to be featured! 🔥👀\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesign',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent-ord5-1.cdninstagram.com/v/t39.30808-6/343589915_903339854295051_2158102157077554024_n.jpg?_nc_cat=101&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=PXmT5lX-HjcAX8l8h1z&_nc_ht=scontent-ord5-1.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfCrS5cFOFkCa4n0A004tfIzKSS38KU_fgOFL6lEBtFmrg&oe=645F390B',
#    'permalink': 'https://www.instagram.com/p/Cri3de8os7W/',
#    'timestamp': '2023-04-27T15:34:13+0000',
#    'username': 'productminimal',
#    'like_count': 2119,
#    'comments_count': 9},
#   {'id': '17996161810842529',
#    'caption': 'Francois Mahieu, A.k.a @francois_mahieu_id, shows us something way more beautiful than Golum from "The Lord of the Rings" 💡Golum is a brand of headlamps.\n\nGolum is a brand of headlamps with which we developed a piece of gear that boast great ergonomics, ease of use while adapting electronic components into the overall design. A product that is discreet but with a strong identity subtle yet powerful product, a compromise between functionality and lightness.\n\nThis design got submitted to our website - check out our link in bio if you also want to be featured! 🔥👀\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesign',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent-ord5-1.cdninstagram.com/v/t39.30808-6/343675319_9160514147323152_6373638164576801773_n.jpg?_nc_cat=108&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=3OFp_W5dhR8AX_TFel8&_nc_ht=scontent-ord5-1.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfBUNauSY1bOaLCXX5iOAks7wQccpmV7mgT5nk-L7HZfHg&oe=645F97BA',
#    'permalink': 'https://www.instagram.com/p/CrimPEkKxAS/',
#    'timestamp': '2023-04-27T13:03:42+0000',
#    'username': 'productminimal',
#    'like_count': 1309,
#    'comments_count': 2},
#   {'id': '18359256403021049',
#    'caption': 'An innovative and sleek Audio Interface concept by the talented @rowhaaann \n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent-ord5-1.cdninstagram.com/v/t39.30808-6/342964415_6259555050771591_5255827097909365456_n.jpg?_nc_cat=106&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=G52B7InuRNUAX9MY4V_&_nc_ht=scontent-ord5-1.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfAbwrLY7G4yUnTdH2wAlY0hqPHc1OVoJv06gPPFgmwd7Q&oe=645EBCF5',
#    'permalink': 'https://www.instagram.com/p/CrgUpdcKWs_/',
#    'timestamp': '2023-04-26T15:51:32+0000',
#    'username': 'productminimal',
#    'like_count': 1602,
#    'comments_count': 3},
#   {'id': '17951841629549282',
#    'caption': 'An unboxing that’s definitely worth watching - by @sirbean117 for @mobilepixelsus \n\n____\n\nDiscover more on @productminimal',
#    'media_type': 'VIDEO',
#    'media_url': 'https://scontent-ord5-2.cdninstagram.com/o1/v/t16/f1/m82/CA447D0EA3F9C4063CCB10E2D96293B0_video_dashinit.mp4?efg=eyJ2ZW5jb2RlX3RhZyI6InZ0c192b2RfdXJsZ2VuLjcyMC5jbGlwcyJ9&_nc_ht=scontent-ord5-2.cdninstagram.com&_nc_cat=106&vs=935496087756879_3395639934&_nc_vs=HBksFQIYT2lnX3hwdl9yZWVsc19wZXJtYW5lbnRfcHJvZC9DQTQ0N0QwRUEzRjlDNDA2M0NDQjEwRTJEOTYyOTNCMF92aWRlb19kYXNoaW5pdC5tcDQVAALIAQAVABgkR0lwZmRoUXJ0eWVQTUlNRUFJY1FjT2YtcWRaOWJxX0VBQUFGFQICyAEAKAAYABsBiAd1c2Vfb2lsATEVAAAmmN7n0Pnj%2FD8VAigCQzMsF0Au1P3ztkWiGBJkYXNoX2Jhc2VsaW5lXzFfdjERAHUAAA%3D%3D&ccb=9-4&oh=00_AfB2DmnxXzokTTCLN7MQX1f_jMqhweiwH0o8EpGrrstQlw&oe=645BB02D&_nc_sid=ea0b6e&_nc_rid=c71f61daef',
#    'permalink': 'https://www.instagram.com/reel/Crd1i8woKMF/',
#    'thumbnail_url': 'https://scontent-ord5-1.cdninstagram.com/v/t51.36329-15/343426031_145223075187330_2248145382848023760_n.jpg?_nc_cat=106&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=r0Wy5nQhE-4AX-xyiys&_nc_ht=scontent-ord5-1.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfDkMDVJl41hCp1Hb-t0L7yelLEZnYUexJJNcsGHFTSjhA&oe=646038A1',
#    'timestamp': '2023-04-25T16:41:54+0000',
#    'username': 'productminimal',
#    'like_count': 25576,
#    'comments_count': 73},
#   {'id': '17968079273174835',
#    'caption': '@wearewouq with a (somewhat silly looking😉🔥) fantastic render that does not at all lack details or perspectives - fantastic job!\n\n_______\n\nDiscover more on @productminimal',
#    'media_type': 'VIDEO',
#    'media_url': 'https://scontent-ord5-2.cdninstagram.com/o1/v/t16/f1/m82/1B447FB0E9B9887C35C1474961929484_video_dashinit.mp4?efg=eyJ2ZW5jb2RlX3RhZyI6InZ0c192b2RfdXJsZ2VuLjcyMC5jbGlwcyJ9&_nc_ht=scontent-ord5-2.cdninstagram.com&_nc_cat=104&vs=157850250568595_846451299&_nc_vs=HBksFQIYT2lnX3hwdl9yZWVsc19wZXJtYW5lbnRfcHJvZC8xQjQ0N0ZCMEU5Qjk4ODdDMzVDMTQ3NDk2MTkyOTQ4NF92aWRlb19kYXNoaW5pdC5tcDQVAALIAQAVABgkR0FXbWR4UlNsRG5LdVJVWEFQTnNzSXU3VXJCcmJxX0VBQUFGFQICyAEAKAAYABsBiAd1c2Vfb2lsATEVAAAmzuCO2v2h%2BD8VAigCQzMsF0AsDdLxqfvnGBJkYXNoX2Jhc2VsaW5lXzFfdjERAHUAAA%3D%3D&ccb=9-4&oh=00_AfDniT_iD2lzbiA8TYKEKvpZmMkAFC0z_Idlgwr3mshakQ&oe=645BBB18&_nc_sid=ea0b6e&_nc_rid=bad358ca39',
#    'permalink': 'https://www.instagram.com/reel/CrbFJs6PifO/',
#    'thumbnail_url': 'https://scontent-ord5-2.cdninstagram.com/v/t51.36329-15/343275807_1959253987759561_445367474125503289_n.jpg?_nc_cat=105&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=5RbehIz62l0AX-vRiPe&_nc_ht=scontent-ord5-2.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfAA9-ER9FYNQSTIUHwkm_wOlHedPoflNF3i6xArNhBteA&oe=645F5F32',
#    'timestamp': '2023-04-24T15:00:05+0000',
#    'username': 'productminimal',
#    'like_count': 2013,
#    'comments_count': 9},
#   {'id': '17980665565957055',
#    'caption': 'H4 electric scooter is designed by @oneobjectdesign  with compact, modern and dynamic as its core for urban mobility, by creating a balance between urban lifestyle product and performance driven transport.\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent-ord5-2.cdninstagram.com/v/t39.30808-6/342792393_148199531343217_7638505295484382434_n.jpg?_nc_cat=110&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=q7hLPOX5_aoAX9m00az&_nc_ht=scontent-ord5-2.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfCUyf07iP9QQg45hGKh007dZeSbpjJVjSZTUPv_VrrDyw&oe=645F7492',
#    'permalink': 'https://www.instagram.com/p/CrWb82Jqhm0/',
#    'timestamp': '2023-04-22T19:42:57+0000',
#    'username': 'productminimal',
#    'like_count': 369,
#    'comments_count': 3},
#   {'id': '17981727890101286',
#    'caption': 'Transparent fan render - designed by @anshuman22 \n\nI am always a fan of transparent design, especially the transparent GameBoy by @nintendoamerica, but as you can see it always enhances the design in my opinion\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent-ord5-2.cdninstagram.com/v/t39.30808-6/342816027_176661388644895_6717990521669539008_n.jpg?_nc_cat=105&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=Uu_OHHTmgQ0AX9UGmqr&_nc_ht=scontent-ord5-2.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfBLH7dmROvdo7yBpNjNDbtOEzDovdhSIQ53onpBvZC5Cw&oe=645F04CD',
#    'permalink': 'https://www.instagram.com/p/CrTa94pqxao/',
#    'timestamp': '2023-04-21T15:36:38+0000',
#    'username': 'productminimal',
#    'like_count': 1284,
#    'comments_count': 4},
#   {'id': '17974534514231508',
#    'caption': '@danielsin unpacking the @logitech Pop Keys 🔥\n\n_____\n\nDiscover more on @productminimal',
#    'media_type': 'VIDEO',
#    'media_url': 'https://scontent-ord5-2.cdninstagram.com/o1/v/t16/f1/m82/EB4E2BAA367FF9B722EDD9A28EC55386_video_dashinit.mp4?efg=eyJ2ZW5jb2RlX3RhZyI6InZ0c192b2RfdXJsZ2VuLjcyMC5jbGlwcyJ9&_nc_ht=scontent-ord5-2.cdninstagram.com&_nc_cat=104&vs=606404984704597_967357185&_nc_vs=HBksFQIYT2lnX3hwdl9yZWVsc19wZXJtYW5lbnRfcHJvZC9FQjRFMkJBQTM2N0ZGOUI3MjJFREQ5QTI4RUM1NTM4Nl92aWRlb19kYXNoaW5pdC5tcDQVAALIAQAVABgkR0hxOVRSVFU4bnBkMDdZQUFLV0RGbEJHV1BnYWJxX0VBQUFGFQICyAEAKAAYABsBiAd1c2Vfb2lsATEVAAAmrp2tmryl%2FT8VAigCQzMsF0A1kan752yLGBJkYXNoX2Jhc2VsaW5lXzFfdjERAHUAAA%3D%3D&ccb=9-4&oh=00_AfBaSS0Z1SGqMi3_veFE77kXUeBJ9lIw2d0oqIlc4PtMhQ&oe=645C12B7&_nc_sid=ea0b6e&_nc_rid=26b6ebeac9',
#    'permalink': 'https://www.instagram.com/reel/CrQ77mtoxEr/',
#    'thumbnail_url': 'https://scontent-ord5-2.cdninstagram.com/v/t51.36329-15/342343378_178963925085567_2269869616143980716_n.jpg?_nc_cat=100&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=G6jo951zBEwAX_n6Ti_&_nc_ht=scontent-ord5-2.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfAVz-xE57xtj1NWUAfS1_Q3A34XoCr7cVrl5pxqKDeAhA&oe=645F315C',
#    'timestamp': '2023-04-20T16:27:25+0000',
#    'username': 'productminimal',
#    'like_count': 1545,
#    'comments_count': 13},
#   {'id': '18049112791418793',
#    'caption': 'THE VANGUARD in different colour\nvariations - definitely a strong visualization by\n@makehastecorp\n\n"M.H.C.06\n-\nWe like to take our time to explore different ways to\nexpress ideas into our creations and livery is part of\nthat process too. The Vanguard was the perfect\nplatform to manifest our passion and love for specials\nliveries. Which one is your favorite?\n-\nCreated in @maxonvfx and rendered with/\n@coronarender "\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent-ord5-2.cdninstagram.com/v/t39.30808-6/342177680_1298318464086490_5336875604998967699_n.jpg?_nc_cat=104&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=rvxa3a4hR7gAX9keliP&_nc_ht=scontent-ord5-2.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfCfj1Dcu_ce6RTeKeWa2EDrYueIsFKL1xR6zN5o6wYgZQ&oe=645F8E82',
#    'permalink': 'https://www.instagram.com/p/CrOL-o5KgkU/',
#    'timestamp': '2023-04-19T14:49:27+0000',
#    'username': 'productminimal',
#    'like_count': 1640,
#    'comments_count': 1},
#   {'id': '17897485115788540',
#    'caption': "With @apple being expected to release a mixed-reality headset and @facebook being stubborn about their VR/Metaverse strategy, VR Headsets are probably here to stay - making designs like these by @seoul_id not only nice to look at, but also relevant!\n\n“SWP is a wearable strabismus treatment device that promotes active and effective cure for childhood strabismus patients who are difficult to treat through surgery and other methods.\n\nThe motorized prism lens mounted inside the product continuously adapts the distortion angle according to the user's severity of strabismus. Accordingly, the treatment of strabismus can be further promoted by strengthening the eye movement effect.”\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner",
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent-ord5-2.cdninstagram.com/v/t39.30808-6/337747778_727882099089390_4991700846347472542_n.jpg?_nc_cat=107&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=irh89-7rDPsAX8TqT_y&_nc_ht=scontent-ord5-2.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfCpc4oPaINJH-nSF6SQdSyWy5XZiPcyhwDZf7C9CNN-9Q&oe=645FA8B5',
#    'permalink': 'https://www.instagram.com/p/CrLofM8qFsn/',
#    'timestamp': '2023-04-18T15:00:51+0000',
#    'username': 'productminimal',
#    'like_count': 670,
#    'comments_count': 3},
#   {'id': '17950853369556215',
#    'caption': 'Explore the heat right in front of your eyes 🔥 Definitely a cool idea, although I can imagine that material resistance can be a problem here. Desgined by @pb_designs__ for @renderweekly \n\nCMF (Color-Material-Finish) is a tactical step in the design process of each Industrial Design project, that gives a deeper understanding of our target group, user experience and plays a major factor in how products AND brands stand out.\n\n„I am always curious how things are working, therefore it’s so exciting to see moving parts, blinking lights and get a deep understanding of the functionality.“\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent-ord5-1.cdninstagram.com/v/t39.30808-6/336918685_6120004631368136_1511933705726781811_n.jpg?_nc_cat=108&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=Sp_qB8yd0kcAX_1Nqha&_nc_ht=scontent-ord5-1.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfCT9KhmzRVyi1b6ffCcjKA_92pHw9-wk-_gHt1af6EPsA&oe=645FE3D7',
#    'permalink': 'https://www.instagram.com/p/CrJJPeuKoBu/',
#    'timestamp': '2023-04-17T15:49:20+0000',
#    'username': 'productminimal',
#    'like_count': 3591,
#    'comments_count': 5},
#   {'id': '18040537486453786',
#    'caption': 'Robots are taking over the world, but at least they look fancy. This concept here is called Symbion and is designed by the talented @alpcakindesign\n\nMany different construction machines are used in the construction of a building. But hand tools are generally used to facilitate the work in the interior works of the construction. Since these works are done by people, occupational accidents are frequently experienced in workspace. It also causes cost and time loss. Symbion product family performs floor levelling, drilling holes and wall chasing for installations in the interior of the construction autonomously with bim files. It prevents various work accidents while applying these processes.\n\nThe problems to be encountered during manufacturing are determined previously and corrected in the bim application. Bim file is uploaded to robots then the revisions made in this file are transferred to the robots simultaneously. Thus, the possibility of error is minimized and cost, energy and time savings are achieved.\n\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner',
#    'media_type': 'CAROUSEL_ALBUM',
#    'media_url': 'https://scontent-ord5-1.cdninstagram.com/v/t39.30808-6/336661866_251909807501842_3215654569570654572_n.jpg?_nc_cat=101&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=WqxjSH3Zk_kAX9Ky6Qt&_nc_ht=scontent-ord5-1.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfCJ3GUZt116XEjcTieREQrA6EbYknS5a1YhbYJi0KjuyA&oe=645FCAE2',
#    'permalink': 'https://www.instagram.com/p/CrEhugEKTbs/',
#    'timestamp': '2023-04-15T20:47:05+0000',
#    'username': 'productminimal',
#    'like_count': 731,
#    'comments_count': 5},
#   {'id': '17972780834486774',
#    'caption': '@audiofficial is further stepping towards the modern automotive era with this fantastic concept car - check it out\n\n_______\n\nDiscover more on @productminimal',
#    'media_type': 'VIDEO',
#    'media_url': 'https://scontent-ord5-2.cdninstagram.com/o1/v/t16/f1/m82/654A824F5F29C0917AF7020E1D2DD092_video_dashinit.mp4?efg=eyJ2ZW5jb2RlX3RhZyI6InZ0c192b2RfdXJsZ2VuLjcyMC5jbGlwcyJ9&_nc_ht=scontent-ord5-2.cdninstagram.com&_nc_cat=104&vs=1614136058994856_3925677679&_nc_vs=HBksFQIYT2lnX3hwdl9yZWVsc19wZXJtYW5lbnRfcHJvZC82NTRBODI0RjVGMjlDMDkxN0FGNzAyMEUxRDJERDA5Ml92aWRlb19kYXNoaW5pdC5tcDQVAALIAQAVABgkR0pGc1FCUXlLU0NVc0RFRUFLekRPd3owaFlGQWJxX0VBQUFGFQICyAEAKAAYABsBiAd1c2Vfb2lsATEVAAAmpPT6z8eE5T8VAigCQzMsF0A%2BDAgxJul5GBJkYXNoX2Jhc2VsaW5lXzFfdjERAHUAAA%3D%3D&ccb=9-4&oh=00_AfCaLsD-qlynaMPPd2c0QH9db8Ev79zaFRAPIiBUEnX9uQ&oe=645C41A9&_nc_sid=ea0b6e&_nc_rid=104ddbaaed',
#    'permalink': 'https://www.instagram.com/reel/CrBG-GgoVvE/',
#    'thumbnail_url': 'https://scontent-ord5-2.cdninstagram.com/v/t51.36329-15/341188797_193049923500105_3724174221823964295_n.jpg?_nc_cat=103&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=zopCw_vngaoAX8OPVYe&_nc_ht=scontent-ord5-2.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfDAhP7YXsVxpwr62Xd1tp5eLhei7Zn3gCut9o_IgeNrSw&oe=645E9496',
#    'timestamp': '2023-04-14T12:55:44+0000',
#    'username': 'productminimal',
#    'like_count': 829,
#    'comments_count': 2}],
#  'paging': {'cursors': {'before': 'QVFIUkxZATXBTNl9VWjMwTTB0LVhvc0p2LU03Yl9ZATnppeXEzVHMwRjlEcXdZAM0xvTGFKUFZA5Y2FjUHpXaVM0ZA2hyaWZANUERaYmlTRGpZAYUMyYUt1ZAFNuV2JB',
#    'after': 'QVFIUjBEYnZAsbUFaUGRZAd0t1Q1BRVjFLckdmcGZA6ZAVVHTGlYdVQ0ejhJQzN4bGRLc2RYU2xPZAnZA2LVpNVFFySFMzNkpUNUxqXzZAuSnlicmRFT2IxUHRGV1ZAR'},
#   'next': 'https://graph.facebook.com/v16.0/17841447229527043/media?access_token=EAAG24jaJaYIBAIr6BRiA2dvrC7ppqbyFvvnZB64ZAZChVRXkGU6ZAF5TXZAoWGSvI5SU3S4tZA7RXDDbl18KJX1j833wmISzUMpZB3BvlW6npImwE9zOtzcsX9AyeFFl4AYwaUzGnuAI3XFTSl5PbrLTCAVYZCPq5ZBdtQcgcyllT0GG6IuHGHq0h&fields=id%2Ccaption%2Cmedia_type%2Cmedia_url%2Cpermalink%2Cthumbnail_url%2Ctimestamp%2Cusername%2Clike_count%2Ccomments_count&limit=25&after=QVFIUjBEYnZAsbUFaUGRZAd0t1Q1BRVjFLckdmcGZA6ZAVVHTGlYdVQ0ejhJQzN4bGRLc2RYU2xPZAnZA2LVpNVFFySFMzNkpUNUxqXzZAuSnlicmRFT2IxUHRGV1ZAR'}}

# %% [markdown]
# ## Putting Image data in a Table

# %%
df = pd.DataFrame(basic_insight['data'])
df.columns = ['id', 'Caption', 'Media_Type', 'Media_URL', 'Permalink', 'Timestamp', 'Username', 'Likes', 'Comments', 'thumbnail_url']
df.head()
# Out:
#                   id                                            Caption  \
# 0  17909947517755871  Explore the recent @blender.official project b...
# 1  17975672708217381  Magnificant unboxing by @oliursvisuals fir thi...
# 2  18008280769630676  Clean silver - reminds me of the F1 McLaren in...
# 3  18175144231287171  You can have different opinions about @teslamo...
# 4  18187056487253958  As part of an ongoing collaboration between me...
#
#        Media_Type                                          Media_URL  \
# 0  CAROUSEL_ALBUM  https://scontent-ord5-1.cdninstagram.com/v/t39...
# 1           VIDEO  https://scontent-ord5-2.cdninstagram.com/o1/v/...
# 2  CAROUSEL_ALBUM  https://scontent-ord5-2.cdninstagram.com/v/t39...
# 3           VIDEO  https://scontent-ord5-2.cdninstagram.com/o1/v/...
# 4  CAROUSEL_ALBUM  https://scontent-ord5-2.cdninstagram.com/v/t39...
#
#                                      Permalink                 Timestamp  \
# 0     https://www.instagram.com/p/Cr_LTUJKgqG/  2023-05-08T15:26:20+0000
# 1  https://www.instagram.com/reel/Cr9MQJiIm_L/  2023-05-07T20:58:05+0000
# 2     https://www.instagram.com/p/Cr55ADToQx6/  2023-05-06T14:10:12+0000
# 3  https://www.instagram.com/reel/Cr3kT9ToSRl/  2023-05-05T16:31:42+0000
# 4     https://www.instagram.com/p/Cr23jK3qccH/  2023-05-05T09:59:48+0000
#
#          Username  Likes  Comments  \
# 0  productminimal    503         3
# 1  productminimal   2401        13
# 2  productminimal   3016        13
# 3  productminimal    971        16
# 4  productminimal    101         0
#
#                                        thumbnail_url
# 0                                                NaN
# 1  https://scontent-ord5-2.cdninstagram.com/v/t51...
# 2                                                NaN
# 3  https://scontent-ord5-2.cdninstagram.com/v/t51...
# 4                                                NaN

# %%
media_insight = []

# Loop Over 'Media ID'
for i in basic_insight['data']:
    if i['media_type'] == "CAROUSEL_ALBUM":
      params['latest_media_id'] = i['id']
      print(i)
      # Define URL
      url = params['endpoint_base'] + params['latest_media_id'] + '/insights'

      # Define Endpoint Parameters
      endpointParams = dict() 
      endpointParams['metric'] = 'engagement,impressions,reach,saved'
      endpointParams['access_token'] = params['access_token'] 

      # Requests Data
      data = requests.get(url, endpointParams )
      json_data = json.loads(data.content)
      media_insight.append(list(json_data['data']))
    else:
      None
# Out:
# {'id': '17909947517755871', 'caption': 'Explore the recent @blender.official project by @harryibzdesign 🔥\n\nLearning is a slow but a rewarding process and harry is perfectly demonstrating this here: "I’ve been learning Blender recently to improve my topology workflow when poly modelling. Still learning, but really enjoying it, more to come on this…"\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent-ord5-1.cdninstagram.com/v/t39.30808-6/345622025_239704598736691_9074636169292671434_n.jpg?_nc_cat=109&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=bQvvqrKdu0cAX8h_Aj3&_nc_ht=scontent-ord5-1.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfB1mHC3Bm79_HY_w37C5AS-s4jIzmxmnd2Dl2sBm-cjXw&oe=645EFCC9', 'permalink': 'https://www.instagram.com/p/Cr_LTUJKgqG/', 'timestamp': '2023-05-08T15:26:20+0000', 'username': 'productminimal', 'like_count': 503, 'comments_count': 3}
# {'id': '18008280769630676', 'caption': 'Clean silver - reminds me of the F1 McLaren in 2008 with the silver and red details. You can see here the MNL MK-I, a Premium Film Camera Concept designed by the well-known and talented @acasso_official\u2063\u2063 for Manual NYC\n\n@manual_nyc  is a photography company based in New York that specializes in analogue photography. Unlike most modern camera brands that focus exclusively on digital photography, Manual is dedicated to film photography and has its own lineup of films and reusable film cameras. The high demand for the analogue taste of their film photography in fashion and social media has led them to collaborate with globally renowned brands such as Nike. In 2021, Manual approached us to design an iconic camera to enhance their product line.\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent-ord5-2.cdninstagram.com/v/t39.30808-6/345451210_623191276519707_496282433299896223_n.jpg?_nc_cat=102&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=u54PzBuA9PUAX-7qy3B&_nc_ht=scontent-ord5-2.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfB52sAT-EjuZ55gN8HM2UKoeTi2GPZwDujZ5WrMw8SGgQ&oe=645E5C09', 'permalink': 'https://www.instagram.com/p/Cr55ADToQx6/', 'timestamp': '2023-05-06T14:10:12+0000', 'username': 'productminimal', 'like_count': 3016, 'comments_count': 13}
# {'id': '18187056487253958', 'caption': "As part of an ongoing collaboration between me and @inktank.academy, I also wanted to share with you the possibility to share your work and portfolio on their website to get feedback from experienced designers!\n\nI'm also going to stroll through the shared designs on their platform to occasionally pick some designs to share on here - so take a look, they have offers for both experienced designers and beginners 💡👀\n\nYou can find the link to their website in my bio!\n\n___________\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner", 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent-ord5-2.cdninstagram.com/v/t39.30808-6/345156268_201203685687000_5784977349248684459_n.jpg?_nc_cat=102&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=enSTHo5sslEAX99LjaF&_nc_ht=scontent-ord5-2.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfBOF86YPgqwm_vJ8KsWMDqHozWLLy3osWzohixOQZngBQ&oe=645FC22A', 'permalink': 'https://www.instagram.com/p/Cr23jK3qccH/', 'timestamp': '2023-05-05T09:59:48+0000', 'username': 'productminimal', 'like_count': 101, 'comments_count': 0}
# {'id': '18265650850183643', 'caption': 'Lumia by @mm_products_and_doodles / @matteovilardostudio\n\nLUMIA is a brand new web-based HMI modular system that allows customers to choose among many electronic package solutions to attach to different display size.\nLUMIA family is divided into CABIN PANEL and VESA ARM mounting, both thought as modular system to give extreme personalization based on customer needs\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent-ord5-1.cdninstagram.com/v/t39.30808-6/344821027_2428664713955020_2581272817949503493_n.jpg?_nc_cat=108&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=sBQIAyxgbhYAX9XNXq-&_nc_ht=scontent-ord5-1.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfBE42jTzbb1kdRAmhyob3HrcJFk2xIbm4LEMlOwOzTn4Q&oe=645FA9FD', 'permalink': 'https://www.instagram.com/p/CryjAHpKAuh/', 'timestamp': '2023-05-03T17:43:18+0000', 'username': 'productminimal', 'like_count': 272, 'comments_count': 3}
# {'id': '17860867289937524', 'caption': '@denis___zhuravlev is not only father and traveller, he also creates some stunning designs for Nevs - an automotive company based in Stockholm, Sweden 🔥 \n\nIn this slidedeck you can explore the interior of the Emily GT - their recently shared new car. " I joined #Nevs team where we worked together at the highest pace. Sleepless nights and great team effort to build emily from the sketch to several running prototypes in just 8 months while the design process took only 5 months. Finally can share it today!"\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent-ord5-1.cdninstagram.com/v/t39.30808-6/344743743_780088763424963_5145686029768258844_n.jpg?_nc_cat=108&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=J2w0vZl8guUAX_H0_On&_nc_ht=scontent-ord5-1.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfB12PFbgNU54smi9YGx64fyrekMTaN3iNsa_TRUjZ7yOQ&oe=645FFCB8', 'permalink': 'https://www.instagram.com/p/CrwCiloqOSw/', 'timestamp': '2023-05-02T18:21:10+0000', 'username': 'productminimal', 'like_count': 349, 'comments_count': 2}
# {'id': '17994446260820097', 'caption': 'The beauty of creating something with your own hands captured in this drill - and digitzed😉🔥This is the Xiaomi Electric Drill designed by @hoto_official for @xiaomi.global \n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent-ord5-1.cdninstagram.com/v/t39.30808-6/344539993_6535548036465663_3104742384559729181_n.jpg?_nc_cat=108&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=Jw9i7SEwjt8AX8vYM46&_nc_ht=scontent-ord5-1.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfDFd015ijolSTUAZOtiTX9xRQoH5l6BETy7oQFcNDqZNg&oe=645FF746', 'permalink': 'https://www.instagram.com/p/CrqTW02KFO1/', 'timestamp': '2023-04-30T12:52:40+0000', 'username': 'productminimal', 'like_count': 2433, 'comments_count': 15}
# {'id': '18266609611124685', 'caption': "Just recently I got in contact with @inktank.academy and thought it would be a great opportunity to share with you since many are still students or are trying to enter the industry :) \n\nThey offer free online courses for designers and considering that a lot of you are still students, this might be a good way to get into it and start designing staff (and share it on @productminimal 😉)\n\nOn their website, you'll also have the opportunity to share your work/portfolio as part of a platform/social network for designers, reach new people, and maybe also find someone to collaborate with in the future 👀\n\nFor more information you can check out the link in my bio, we've tagged their website there!\n\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesign", 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent-ord5-2.cdninstagram.com/v/t39.30808-6/343947498_6139420089485807_7003979519010646898_n.jpg?_nc_cat=105&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=ITpILYNNvoAAX8Htr2m&_nc_ht=scontent-ord5-2.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfBgJbrk_yHxAqsbrviTetKET_w6UN-rWpkLvYJRCk73dg&oe=645F4EC7', 'permalink': 'https://www.instagram.com/p/CrnofieqOZs/', 'timestamp': '2023-04-29T11:59:38+0000', 'username': 'productminimal', 'like_count': 125, 'comments_count': 4}
# {'id': '18220813357169965', 'caption': '@medium2studio on his way to make a seemingly uninteresting object stand out in your office - the Ruler_C 😉\n\nRuler_C is a uniquely designed ruler that offers both practicality and style. Its curved shape allows for easy gripping and minimizes contact with the paper, preventing contamination and accidental smudging. Made from durable anodized aluminum alloy, Ruler_C not only withstands everyday use but also adds a touch of sophistication to any workspace with its sleek and modern appearance. It is a chic choice for those who appreciate well-designed tools that effortlessly combine form and function in a subtle and refined manner.\n\nThis design got submitted to our website - check out our link in bio if you also want to be featured! 🔥👀\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesign', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent-ord5-1.cdninstagram.com/v/t39.30808-6/343589915_903339854295051_2158102157077554024_n.jpg?_nc_cat=101&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=PXmT5lX-HjcAX8l8h1z&_nc_ht=scontent-ord5-1.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfCrS5cFOFkCa4n0A004tfIzKSS38KU_fgOFL6lEBtFmrg&oe=645F390B', 'permalink': 'https://www.instagram.com/p/Cri3de8os7W/', 'timestamp': '2023-04-27T15:34:13+0000', 'username': 'productminimal', 'like_count': 2119, 'comments_count': 9}
# {'id': '17996161810842529', 'caption': 'Francois Mahieu, A.k.a @francois_mahieu_id, shows us something way more beautiful than Golum from "The Lord of the Rings" 💡Golum is a brand of headlamps.\n\nGolum is a brand of headlamps with which we developed a piece of gear that boast great ergonomics, ease of use while adapting electronic components into the overall design. A product that is discreet but with a strong identity subtle yet powerful product, a compromise between functionality and lightness.\n\nThis design got submitted to our website - check out our link in bio if you also want to be featured! 🔥👀\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesign', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent-ord5-1.cdninstagram.com/v/t39.30808-6/343675319_9160514147323152_6373638164576801773_n.jpg?_nc_cat=108&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=3OFp_W5dhR8AX_TFel8&_nc_ht=scontent-ord5-1.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfBUNauSY1bOaLCXX5iOAks7wQccpmV7mgT5nk-L7HZfHg&oe=645F97BA', 'permalink': 'https://www.instagram.com/p/CrimPEkKxAS/', 'timestamp': '2023-04-27T13:03:42+0000', 'username': 'productminimal', 'like_count': 1309, 'comments_count': 2}
# {'id': '18359256403021049', 'caption': 'An innovative and sleek Audio Interface concept by the talented @rowhaaann \n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent-ord5-1.cdninstagram.com/v/t39.30808-6/342964415_6259555050771591_5255827097909365456_n.jpg?_nc_cat=106&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=G52B7InuRNUAX9MY4V_&_nc_ht=scontent-ord5-1.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfAbwrLY7G4yUnTdH2wAlY0hqPHc1OVoJv06gPPFgmwd7Q&oe=645EBCF5', 'permalink': 'https://www.instagram.com/p/CrgUpdcKWs_/', 'timestamp': '2023-04-26T15:51:32+0000', 'username': 'productminimal', 'like_count': 1602, 'comments_count': 3}
# {'id': '17980665565957055', 'caption': 'H4 electric scooter is designed by @oneobjectdesign  with compact, modern and dynamic as its core for urban mobility, by creating a balance between urban lifestyle product and performance driven transport.\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent-ord5-2.cdninstagram.com/v/t39.30808-6/342792393_148199531343217_7638505295484382434_n.jpg?_nc_cat=110&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=q7hLPOX5_aoAX9m00az&_nc_ht=scontent-ord5-2.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfCUyf07iP9QQg45hGKh007dZeSbpjJVjSZTUPv_VrrDyw&oe=645F7492', 'permalink': 'https://www.instagram.com/p/CrWb82Jqhm0/', 'timestamp': '2023-04-22T19:42:57+0000', 'username': 'productminimal', 'like_count': 369, 'comments_count': 3}
# {'id': '17981727890101286', 'caption': 'Transparent fan render - designed by @anshuman22 \n\nI am always a fan of transparent design, especially the transparent GameBoy by @nintendoamerica, but as you can see it always enhances the design in my opinion\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent-ord5-2.cdninstagram.com/v/t39.30808-6/342816027_176661388644895_6717990521669539008_n.jpg?_nc_cat=105&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=Uu_OHHTmgQ0AX9UGmqr&_nc_ht=scontent-ord5-2.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfBLH7dmROvdo7yBpNjNDbtOEzDovdhSIQ53onpBvZC5Cw&oe=645F04CD', 'permalink': 'https://www.instagram.com/p/CrTa94pqxao/', 'timestamp': '2023-04-21T15:36:38+0000', 'username': 'productminimal', 'like_count': 1284, 'comments_count': 4}
# {'id': '18049112791418793', 'caption': 'THE VANGUARD in different colour\nvariations - definitely a strong visualization by\n@makehastecorp\n\n"M.H.C.06\n-\nWe like to take our time to explore different ways to\nexpress ideas into our creations and livery is part of\nthat process too. The Vanguard was the perfect\nplatform to manifest our passion and love for specials\nliveries. Which one is your favorite?\n-\nCreated in @maxonvfx and rendered with/\n@coronarender "\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent-ord5-2.cdninstagram.com/v/t39.30808-6/342177680_1298318464086490_5336875604998967699_n.jpg?_nc_cat=104&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=rvxa3a4hR7gAX9keliP&_nc_ht=scontent-ord5-2.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfCfj1Dcu_ce6RTeKeWa2EDrYueIsFKL1xR6zN5o6wYgZQ&oe=645F8E82', 'permalink': 'https://www.instagram.com/p/CrOL-o5KgkU/', 'timestamp': '2023-04-19T14:49:27+0000', 'username': 'productminimal', 'like_count': 1640, 'comments_count': 1}
# {'id': '17897485115788540', 'caption': "With @apple being expected to release a mixed-reality headset and @facebook being stubborn about their VR/Metaverse strategy, VR Headsets are probably here to stay - making designs like these by @seoul_id not only nice to look at, but also relevant!\n\n“SWP is a wearable strabismus treatment device that promotes active and effective cure for childhood strabismus patients who are difficult to treat through surgery and other methods.\n\nThe motorized prism lens mounted inside the product continuously adapts the distortion angle according to the user's severity of strabismus. Accordingly, the treatment of strabismus can be further promoted by strengthening the eye movement effect.”\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner", 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent-ord5-2.cdninstagram.com/v/t39.30808-6/337747778_727882099089390_4991700846347472542_n.jpg?_nc_cat=107&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=irh89-7rDPsAX8TqT_y&_nc_ht=scontent-ord5-2.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfCpc4oPaINJH-nSF6SQdSyWy5XZiPcyhwDZf7C9CNN-9Q&oe=645FA8B5', 'permalink': 'https://www.instagram.com/p/CrLofM8qFsn/', 'timestamp': '2023-04-18T15:00:51+0000', 'username': 'productminimal', 'like_count': 670, 'comments_count': 3}
# {'id': '17950853369556215', 'caption': 'Explore the heat right in front of your eyes 🔥 Definitely a cool idea, although I can imagine that material resistance can be a problem here. Desgined by @pb_designs__ for @renderweekly \n\nCMF (Color-Material-Finish) is a tactical step in the design process of each Industrial Design project, that gives a deeper understanding of our target group, user experience and plays a major factor in how products AND brands stand out.\n\n„I am always curious how things are working, therefore it’s so exciting to see moving parts, blinking lights and get a deep understanding of the functionality.“\n\nWant to be featured? Check out the link in our bio!\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent-ord5-1.cdninstagram.com/v/t39.30808-6/336918685_6120004631368136_1511933705726781811_n.jpg?_nc_cat=108&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=Sp_qB8yd0kcAX_1Nqha&_nc_ht=scontent-ord5-1.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfCT9KhmzRVyi1b6ffCcjKA_92pHw9-wk-_gHt1af6EPsA&oe=645FE3D7', 'permalink': 'https://www.instagram.com/p/CrJJPeuKoBu/', 'timestamp': '2023-04-17T15:49:20+0000', 'username': 'productminimal', 'like_count': 3591, 'comments_count': 5}
# {'id': '18040537486453786', 'caption': 'Robots are taking over the world, but at least they look fancy. This concept here is called Symbion and is designed by the talented @alpcakindesign\n\nMany different construction machines are used in the construction of a building. But hand tools are generally used to facilitate the work in the interior works of the construction. Since these works are done by people, occupational accidents are frequently experienced in workspace. It also causes cost and time loss. Symbion product family performs floor levelling, drilling holes and wall chasing for installations in the interior of the construction autonomously with bim files. It prevents various work accidents while applying these processes.\n\nThe problems to be encountered during manufacturing are determined previously and corrected in the bim application. Bim file is uploaded to robots then the revisions made in this file are transferred to the robots simultaneously. Thus, the possibility of error is minimized and cost, energy and time savings are achieved.\n\n___________\n\nHelp us grow the community and follow\n@productminimal\n\n___________\n.\n.\n.\n.\n.\n.\n.\n#productdesign #product #productdesigner #designer\n#designinspiration #designs #designlife #gooddesign\n#minimaldesign #render #designerlove\n#creativedesign #designlovers #designdetail\n#industrialdesign #keyshot3d #rendering\n#renderlovers #designinspiration #industrialdesigner\n#industrialdesign #designart #renderbox #rendering3d\n#renders #redesign #productshots #productdesigner', 'media_type': 'CAROUSEL_ALBUM', 'media_url': 'https://scontent-ord5-1.cdninstagram.com/v/t39.30808-6/336661866_251909807501842_3215654569570654572_n.jpg?_nc_cat=101&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=WqxjSH3Zk_kAX9Ky6Qt&_nc_ht=scontent-ord5-1.cdninstagram.com&edm=AM6HXa8EAAAA&oh=00_AfCJ3GUZt116XEjcTieREQrA6EbYknS5a1YhbYJi0KjuyA&oe=645FCAE2', 'permalink': 'https://www.instagram.com/p/CrEhugEKTbs/', 'timestamp': '2023-04-15T20:47:05+0000', 'username': 'productminimal', 'like_count': 731, 'comments_count': 5}

# %%
# Initialize Empty Container
engagement_list = []
impressions_list = []
reach_list = []
saved_list = []

# Loop Over Insights to Fill Container
for insight in media_insight:
    engagement_list.append(insight[0]['values'][0]['value'])
    impressions_list.append(insight[1]['values'][0]['value'])
    reach_list.append(insight[2]['values'][0]['value'])
    saved_list.append(insight[3]['values'][0]['value'])
    
# Create DataFrame
df_media_insight = pd.DataFrame(list(zip(engagement_list, impressions_list, reach_list, saved_list)), columns =['Engagement', 'Impressions', 'Reach', 'Saved'])
df_media_insight
# Out:
#     Engagement  Impressions  Reach  Saved
# 0          618         9097   7653    112
# 1         3742        43871  36933    713
# 2          123         6636   5283     22
# 3          318         8934   6970     43
# 4          389        10646   8305     38
# 5         3188        46828  41653    740
# 6          198         9971   7544     69
# 7         2628        39808  33045    500
# 8         1739        25489  22664    428
# 9         2110        37099  32244    505
# 10         469        12933  10199     97
# 11        1632        25054  22047    344
# 12        2039        27388  24155    398
# 13         838        19024  16210    165
# 14        4673        59826  55407   1077
# 15         948        18739  15647    212

# %% [markdown]
# # Demographics data Lifetime

# %%
# Define URL
url = params['endpoint_base'] + params['instagram_account_id'] + '/insights'

# Define Endpoint Parameters
endpointParams = dict()
endpointParams['metric'] = 'audience_city,audience_country,audience_gender_age' 
endpointParams['period'] = 'lifetime' 
endpointParams['access_token'] = params['access_token'] 

# Requests Data
data = requests.get(url, endpointParams )
audience_insight = json.loads(data.content)
audience_insight
# Out:
# {'data': [{'name': 'audience_city',
#    'period': 'lifetime',
#    'values': [{'value': {'Sydney, New South Wales': 323,
#       'London, England': 828,
#       'São Paulo, São Paulo (state)': 537,
#       'Barcelona, Cataluña': 299,
#       'Hong Kong, Hong Kong': 539,
#       'Berlin, Berlin': 405,
#       'Kyiv, Kyiv': 304,
#       'Lagos, Lagos State': 371,
#       'Seoul, Seoul': 1583,
#       'Pune, Maharashtra': 295,
#       'Ahmedabad, Gujarat': 287,
#       'Moscow, Moscow': 770,
#       'Bogotá, Distrito Especial': 620,
#       'Jakarta, Jakarta': 1047,
#       'Paris, Île-de-France': 380,
#       'Buenos Aires, Ciudad Autónoma de Buenos Aires': 549,
#       'Taipei, Taipei': 606,
#       'Ho Chi Minh City, Ho Chi Minh City': 446,
#       'Xinbei, New Taipei City': 462,
#       'Shanghai, Shanghai': 2151,
#       'Melbourne, Victoria': 418,
#       'Delhi, Delhi': 548,
#       'Los Angeles, California': 338,
#       'Madrid, Comunidad de Madrid': 333,
#       'Shahriyar, Tehran Province': 415,
#       'Lima, Lima Region': 299,
#       'Istanbul, Istanbul Province': 1902,
#       'Toronto, Ontario': 281,
#       'Rome, Lazio': 286,
#       'Chennai, Tamil Nadu': 392,
#       'Ankara, Ankara Province': 281,
#       'Milan, Lombardia': 421,
#       'Bangkok, Bangkok': 642,
#       'Mexico City, Distrito Federal': 863,
#       'Riyadh, Riyadh Region': 330,
#       'Saint Petersburg, Saint Petersburg': 345,
#       'New York, New York': 627,
#       'Tehran, Tehran Province': 3003,
#       'Cairo, Cairo Governorate': 409,
#       'Dubai, Dubai': 437,
#       'Santiago, Santiago Metropolitan Region': 488,
#       'Mumbai, Maharashtra': 654,
#       'Bangalore, Karnataka': 876,
#       'Singapore, Singapore': 454,
#       'Tashkent, Tashkent Region': 417}}],
#    'title': 'Stadt der Zielgruppe',
#    'description': 'Städte der Follower dieses Profils',
#    'id': '17841447229527043/insights/audience_city/lifetime'},
#   {'name': 'audience_country',
#    'period': 'lifetime',
#    'values': [{'value': {'DE': 2751,
#       'BE': 444,
#       'HK': 540,
#       'TW': 1865,
#       'RU': 2327,
#       'PT': 728,
#       'JP': 1299,
#       'UA': 867,
#       'FR': 2331,
#       'SA': 765,
#       'BR': 2927,
#       'SE': 609,
#       'MA': 451,
#       'SG': 454,
#       'GB': 3073,
#       'ID': 3094,
#       'CA': 1427,
#       'US': 7386,
#       'EG': 826,
#       'AE': 670,
#       'CH': 495,
#       'UZ': 593,
#       'IN': 7863,
#       'ZA': 631,
#       'KR': 3068,
#       'IQ': 457,
#       'CL': 745,
#       'IR': 5626,
#       'CN': 2429,
#       'MX': 2793,
#       'IT': 3734,
#       'MY': 832,
#       'CO': 1328,
#       'ES': 2083,
#       'KZ': 467,
#       'AR': 1863,
#       'TH': 1026,
#       'AU': 1165,
#       'PH': 490,
#       'VN': 654,
#       'NG': 724,
#       'PK': 761,
#       'PL': 765,
#       'NL': 781,
#       'TR': 3529}}],
#    'title': 'Land der Zielgruppe',
#    'description': 'Länder der Follower dieses Profils',
#    'id': '17841447229527043/insights/audience_country/lifetime'},
#   {'name': 'audience_gender_age',
#    'period': 'lifetime',
#    'values': [{'value': {'F.13-17': 97,
#       'F.18-24': 2954,
#       'F.25-34': 3575,
#       'F.35-44': 1243,
#       'F.45-54': 388,
#       'F.55-64': 125,
#       'F.65+': 84,
#       'M.13-17': 619,
#       'M.18-24': 12413,
#       'M.25-34': 27068,
#       'M.35-44': 13869,
#       'M.45-54': 4118,
#       'M.55-64': 913,
#       'M.65+': 619,
#       'U.13-17': 575,
#       'U.18-24': 7131,
#       'U.25-34': 8622,
#       'U.35-44': 4424,
#       'U.45-54': 1553,
#       'U.55-64': 435,
#       'U.65+': 347}}],
#    'title': 'Geschlecht und Alter',
#    'description': 'Geschlecht und Alter der Follower dieses Profils',
#    'id': '17841447229527043/insights/audience_gender_age/lifetime'}]}

# %% [markdown]
# ## Algorithm to get the data into table format

# %%
#The variables that I search for

audience_city = []
audience_country = []
audience_genderage = []


#Variables for Country
country_short = []
country_number = []

#Variables for City
city_name = []
region_name = []
city_number = []

#Variables for Age and Gender
gender = []
age_bracket = []
age_number = []

for i in audience_insight["data"]:
    if i['name'] == "audience_country":
      for x in i['values']:
        for z in x["value"]:
          country_short.append(z)
          country_number.append(x['value'][z])
    if i['name'] == "audience_city":
      for x in i['values']:
        for z in x["value"]:
          xy = z.split(", ")
          city_name.append(xy[0])
          region_name.append(xy[1])
          city_number.append(x['value'][z])
    if i['name'] == "audience_gender_age":
      for x in i['values']:
        for z in x["value"]:
          gender_age_split = z.split(".")
          gender.append(gender_age_split[0])
          age_bracket.append(gender_age_split[1])
          age_number.append(x['value'][z])



audience_country = pd.DataFrame(list(zip(country_short, country_number)), columns =['Country_ID', 'Count'])
audience_city = pd.DataFrame(list(zip(city_name, region_name, city_number)), columns =['City', 'Region', 'Count'])
audience_genderage = pd.DataFrame(list(zip(gender, age_bracket, age_number)), columns =['Gender', 'Age Bracket', 'Count'])

#audience_country
#audience_city
audience_city = audience_city.sort_values(by = ['Count'],ascending=False)
audience_country = audience_country.sort_values(by = ['Count'],ascending=False)
audience_genderage = audience_genderage.sort_values(by = ['Count'],ascending=False)

audience_country
# Out:
#    Country_ID  Count
# 22         IN   7863
# 17         US   7386
# 27         IR   5626
# 30         IT   3734
# 44         TR   3529
# 15         ID   3094
# 14         GB   3073
# 24         KR   3068
# 10         BR   2927
# 29         MX   2793
# 0          DE   2751
# 28         CN   2429
# 8          FR   2331
# 4          RU   2327
# 33         ES   2083
# 3          TW   1865
# 35         AR   1863
# 16         CA   1427
# 32         CO   1328
# 6          JP   1299
# 37         AU   1165
# 36         TH   1026
# 7          UA    867
# 31         MY    832
# 18         EG    826
# 43         NL    781
# 42         PL    765
# 9          SA    765
# 41         PK    761
# 26         CL    745
# 5          PT    728
# 40         NG    724
# 19         AE    670
# 39         VN    654
# 23         ZA    631
# 11         SE    609
# 21         UZ    593
# 2          HK    540
# 20         CH    495
# 38         PH    490
# 34         KZ    467
# 25         IQ    457
# 13         SG    454
# 12         MA    451
# 1          BE    444

# %%
# !pip install country_converter
# !pip install pycountry
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: country_converter in /usr/local/lib/python3.10/dist-packages (1.0.0)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.10/dist-packages (from country_converter) (1.5.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->country_converter) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->country_converter) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->country_converter) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.0->country_converter) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pycountry
#   Downloading pycountry-22.3.5.tar.gz (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 52.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from pycountry) (67.7.2)
# Building wheels for collected packages: pycountry
#   Building wheel for pycountry (pyproject.toml) ... done
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681847 sha256=adaae63d5ef978c70510f6cf916d092913be3ffa5d33776b8ea8718150951b24
#   Stored in directory: /root/.cache/pip/wheels/03/57/cc/290c5252ec97a6d78d36479a3c5e5ecc76318afcb241ad9dbe
# Successfully built pycountry
# Installing collected packages: pycountry
# Successfully installed pycountry-22.3.5

# %% [markdown]
# ### Country Codes

# %%
import country_converter as coco
import pycountry

country_dict = {country.alpha_2: country.name for country in pycountry.countries}
audience_country['Country'] = audience_country['Country_ID'].map(country_dict)
audience_country = audience_country.reindex(columns=['Country', 'Country_ID', 'Count'])
audience_country
# Out:
#                       Country Country_ID  Count
# 22                      India         IN   7863
# 17              United States         US   7386
# 27  Iran, Islamic Republic of         IR   5626
# 30                      Italy         IT   3734
# 44                     Turkey         TR   3529
# 15                  Indonesia         ID   3094
# 14             United Kingdom         GB   3073
# 24         Korea, Republic of         KR   3068
# 10                     Brazil         BR   2927
# 29                     Mexico         MX   2793
# 0                     Germany         DE   2751
# 28                      China         CN   2429
# 8                      France         FR   2331
# 4          Russian Federation         RU   2327
# 33                      Spain         ES   2083
# 3   Taiwan, Province of China         TW   1865
# 35                  Argentina         AR   1863
# 16                     Canada         CA   1427
# 32                   Colombia         CO   1328
# 6                       Japan         JP   1299
# 37                  Australia         AU   1165
# 36                   Thailand         TH   1026
# 7                     Ukraine         UA    867
# 31                   Malaysia         MY    832
# 18                      Egypt         EG    826
# 43                Netherlands         NL    781
# 42                     Poland         PL    765
# 9                Saudi Arabia         SA    765
# 41                   Pakistan         PK    761
# 26                      Chile         CL    745
# 5                    Portugal         PT    728
# 40                    Nigeria         NG    724
# 19       United Arab Emirates         AE    670
# 39                   Viet Nam         VN    654
# 23               South Africa         ZA    631
# 11                     Sweden         SE    609
# 21                 Uzbekistan         UZ    593
# 2                   Hong Kong         HK    540
# 20                Switzerland         CH    495
# 38                Philippines         PH    490
# 34                 Kazakhstan         KZ    467
# 25                       Iraq         IQ    457
# 13                  Singapore         SG    454
# 12                    Morocco         MA    451
# 1                     Belgium         BE    444

# %%
audience_country
# Out:
#                       Country Country_ID  Count
# 22                      India         IN   7863
# 17              United States         US   7386
# 27  Iran, Islamic Republic of         IR   5626
# 30                      Italy         IT   3734
# 44                     Turkey         TR   3529
# 15                  Indonesia         ID   3094
# 14             United Kingdom         GB   3073
# 24         Korea, Republic of         KR   3068
# 10                     Brazil         BR   2927
# 29                     Mexico         MX   2793
# 0                     Germany         DE   2751
# 28                      China         CN   2429
# 8                      France         FR   2331
# 4          Russian Federation         RU   2327
# 33                      Spain         ES   2083
# 3   Taiwan, Province of China         TW   1865
# 35                  Argentina         AR   1863
# 16                     Canada         CA   1427
# 32                   Colombia         CO   1328
# 6                       Japan         JP   1299
# 37                  Australia         AU   1165
# 36                   Thailand         TH   1026
# 7                     Ukraine         UA    867
# 31                   Malaysia         MY    832
# 18                      Egypt         EG    826
# 43                Netherlands         NL    781
# 42                     Poland         PL    765
# 9                Saudi Arabia         SA    765
# 41                   Pakistan         PK    761
# 26                      Chile         CL    745
# 5                    Portugal         PT    728
# 40                    Nigeria         NG    724
# 19       United Arab Emirates         AE    670
# 39                   Viet Nam         VN    654
# 23               South Africa         ZA    631
# 11                     Sweden         SE    609
# 21                 Uzbekistan         UZ    593
# 2                   Hong Kong         HK    540
# 20                Switzerland         CH    495
# 38                Philippines         PH    490
# 34                 Kazakhstan         KZ    467
# 25                       Iraq         IQ    457
# 13                  Singapore         SG    454
# 12                    Morocco         MA    451
# 1                     Belgium         BE    444

# %%
import pandas as pd
from datetime import datetime

# generate timestamp string for filename
timestamp_str = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# set the name of the CSV file to include the timestamp
filename = f"country_{timestamp_str}.csv"

# save the dataframe as a CSV file
audience_country.to_csv(filename, index=False)

# %% [markdown]
# # Playing around with time frames - for Day timeframe

# %%
# Define URL
url = params['endpoint_base'] + params['instagram_account_id'] + '/insights'

# Define Endpoint Parameters
endpointParams = dict()
endpointParams['metric'] = 'impressions, reach, likes, comments, profile_views' 
endpointParams['period'] = 'day'
endpointParams['metric_type'] = 'total_value'
endpointParams['access_token'] = params['access_token'] 

# Requests Data
day_account_insight_data = requests.get(url, endpointParams )
day_account_insight = json.loads(day_account_insight_data.content)
day_account_insight
# Out:
# {'data': [{'name': 'impressions',
#    'period': 'day',
#    'title': 'Impressionen',
#    'description': 'So oft wurden deine Beiträge, Stories, Reels, Videos und Live-Videos gezeigt (einschließlich Platzierungen in Anzeigen).',
#    'total_value': {'value': 144270},
#    'id': '17841447229527043/insights/impressions/day'},
#   {'name': 'reach',
#    'period': 'day',
#    'title': 'Erreichte Konten',
#    'description': 'So viele individuelle Konten haben deinen Content, auch in Werbeanzeigen, mindestens einmal gesehen. Dazu zählen Beiträge, Stories, Reels, Videos und Live-Videos. Reichweite unterscheidet sich von Impressionen, denn Letztere können auch mehrfache Aufrufe deines Contents durch dieselben Konten umfassen. Bei dieser Kennzahl handelt es sich um einen Schätzwert, der sich noch in der Entwicklung befindet.',
#    'total_value': {'value': 107377},
#    'id': '17841447229527043/insights/reach/day'},
#   {'name': 'likes',
#    'period': 'day',
#    'title': '„Gefällt mir“-Angaben',
#    'description': 'Die Anzahl der „Gefällt mir“-Angaben für deine Inhalte abzüglich der entfernten „Gefällt mir“-Angaben.',
#    'total_value': {'value': 4876},
#    'id': '17841447229527043/insights/likes/day'},
#   {'name': 'comments',
#    'period': 'day',
#    'title': 'Kommentare',
#    'description': 'Die Anzahl der Kommentare zu deinen Inhalten abzüglich der Anzahl der gelöschten Kommentare.',
#    'total_value': {'value': 19},
#    'id': '17841447229527043/insights/comments/day'},
#   {'name': 'profile_views',
#    'period': 'day',
#    'title': 'Profilaufrufe',
#    'description': 'So oft wurde dein Profil besucht.',
#    'total_value': {'value': 2813},
#    'id': '17841447229527043/insights/profile_views/day'}],
#  'paging': {'previous': 'https://graph.facebook.com/v16.0/17841447229527043/insights?access_token=EAAG24jaJaYIBAIr6BRiA2dvrC7ppqbyFvvnZB64ZAZChVRXkGU6ZAF5TXZAoWGSvI5SU3S4tZA7RXDDbl18KJX1j833wmISzUMpZB3BvlW6npImwE9zOtzcsX9AyeFFl4AYwaUzGnuAI3XFTSl5PbrLTCAVYZCPq5ZBdtQcgcyllT0GG6IuHGHq0h&metric=impressions%2C+reach%2C+likes%2C+comments%2C+profile_views&metric_type=total_value&period=day&since=1683295902&until=1683468702',
#   'next': 'https://graph.facebook.com/v16.0/17841447229527043/insights?access_token=EAAG24jaJaYIBAIr6BRiA2dvrC7ppqbyFvvnZB64ZAZChVRXkGU6ZAF5TXZAoWGSvI5SU3S4tZA7RXDDbl18KJX1j833wmISzUMpZB3BvlW6npImwE9zOtzcsX9AyeFFl4AYwaUzGnuAI3XFTSl5PbrLTCAVYZCPq5ZBdtQcgcyllT0GG6IuHGHq0h&metric=impressions%2C+reach%2C+likes%2C+comments%2C+profile_views&metric_type=total_value&period=day&since=1683641504&until=1683814304'}}

# %%
for i in day_account_insight:
  for x in day_account_insight[i]:
    print(x)
    if x['name'] == 'impressions':
      print(x['total_value']['value'])
# Out:
# {'name': 'impressions', 'period': 'day', 'title': 'Impressionen', 'description': 'So oft wurden deine Beiträge, Stories, Reels, Videos und Live-Videos gezeigt (einschließlich Platzierungen in Anzeigen).', 'total_value': {'value': 143448}, 'id': '17841447229527043/insights/impressions/day'}
# 143448
# {'name': 'reach', 'period': 'day', 'title': 'Erreichte Konten', 'description': 'So viele individuelle Konten haben deinen Content, auch in Werbeanzeigen, mindestens einmal gesehen. Dazu zählen Beiträge, Stories, Reels, Videos und Live-Videos. Reichweite unterscheidet sich von Impressionen, denn Letztere können auch mehrfache Aufrufe deines Contents durch dieselben Konten umfassen. Bei dieser Kennzahl handelt es sich um einen Schätzwert, der sich noch in der Entwicklung befindet.', 'total_value': {'value': 107377}, 'id': '17841447229527043/insights/reach/day'}
# {'name': 'likes', 'period': 'day', 'title': '„Gefällt mir“-Angaben', 'description': 'Die Anzahl der „Gefällt mir“-Angaben für deine Inhalte abzüglich der entfernten „Gefällt mir“-Angaben.', 'total_value': {'value': 4876}, 'id': '17841447229527043/insights/likes/day'}
# {'name': 'comments', 'period': 'day', 'title': 'Kommentare', 'description': 'Die Anzahl der Kommentare zu deinen Inhalten abzüglich der Anzahl der gelöschten Kommentare.', 'total_value': {'value': 19}, 'id': '17841447229527043/insights/comments/day'}
# {'name': 'profile_views', 'period': 'day', 'title': 'Profilaufrufe', 'description': 'So oft wurde dein Profil besucht.', 'total_value': {'value': 2773}, 'id': '17841447229527043/insights/profile_views/day'}
# previous
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-ba9500ae8e98> in <cell line: 1>()
#       2   for x in day_account_insight[i]:
#       3     print(x)
# ----> 4     if x['name'] == 'impressions':
#       5       print(x['total_value']['value'])
#
# TypeError: string indices must be integers

# %%
audience_country.to_csv('country_data.csv', index=False)

# %% [markdown]
# # Connecting with BigQuery

# %%
from google.colab import auth
from google.cloud import bigquery
auth.authenticate_user()

#Replace 'project_id' with your BigQuery project ID

# %%
client = bigquery.Client(project='instagram-analytics-384117')

# %%
table_id = 'instagram-analytics-384117.instagramanalyticsdata.analytics1'
schema = [{'name': 'Country', 'type': 'STRING'},		
 {'name': 'Country_ID', 'type': 'STRING'},
 {'name': 'Count', 'type': 'INTEGER'}]
table = bigquery.Table(table_id, schema=schema)
table = client.create_table(table)  # Make an API request.
print(f'Created table {table.project}.{table.dataset_id}.{table.table_id}')
# Out:
# Created table instagram-analytics-384117.instagramanalyticsdata.analytics1

# %%
job_config = bigquery.LoadJobConfig(schema=schema)
job = client.load_table_from_dataframe(audience_country, table_id, job_config=job_config)
job.result()  # Wait for the job to complete.
print(f'Loaded {len(df)} rows into {table_id}')
# Out:
# Loaded 25 rows into instagram-analytics-384117.instagramanalyticsdata.analytics1
